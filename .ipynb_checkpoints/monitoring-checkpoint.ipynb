# %%
### Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
# import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
capital = pd.read_excel('position.xlsx', sheet_name='capital')
eva = pd.read_excel('position.xlsx', sheet_name='eva')
position = pd.read_excel('position.xlsx', sheet_name='position')

ticker = pd.read_excel('position.xlsx', sheet_name='ticker')

tkstring = []

for tk in ticker.TICKER:
    tkstring.append('0' * (6 - len(str(tk))) + str(tk))    
    
ticker.TICKER = tkstring
# ticker.tail()

# %%
daydelta = 360   # 조회될 기간 설정. 일 기준
today = datetime.today()

start = (today + timedelta(days= -1 * daydelta)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

print('----------------------------')
print('최근', daydelta, '일 데이터 조회')
print('----------------------------')
print()

l_perf = []
for i, row in ticker.sort_values(['TYPE', 'MARKET', 'POSITION']).iterrows():
    try:
        if row.MONITOR:
            data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
            data = data / data.iloc[0] * 100
            cmean = int(data.Close.mean()) - 100
            cmax = int(data.Close.max())
            cmin = int(data.Close.min())
            rng = cmax - cmin
            cpv = int(data.Close[-1])
            l_perf.append([row.TICKER, row.NAME, row.MARKET, row.TYPE, cmean, cmax, cmin, rng, cpv])
            
            print('**', row.NAME, '**')
            print('Ticker  :', row.TICKER)
            print('Market  :', row.MARKET)
            print('Type    :', row.TYPE)
            print('MEAN +/-:', cmean, '%')
            print('MAX/MIN :', cmax, '/', cmin)
            print('RANGE.  :', rng)
            print('PV      :', cpv)
            fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, mav=(5, 20))

        # Annotation
#         for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
#             if data.index[0] < pd.to_datetime(prow.DATE):
#                 x = data.reset_index().index[data.index == prow.DATE].item()
# #                 y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
#                 cap = str(prow.CAP * -1)
#                 stocks = str(prow.STOCKS)
#                 sb = 'SELL' if prow.SELL else 'BUY'
#                 axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
            plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
    
performance = pd.DataFrame(data= l_perf, columns= ['TICKER', 'NAME', 'MARKET', 'TYPE', 'MEAN+/-', 'MAX', 'MIN', 'RNG', 'PV'])
performance.set_index(['TICKER'], inplace= True)
# Out:
# ----------------------------
# 최근 360 일 데이터 조회
# ----------------------------
#
# ** ARIRANG 미국단기우량회사채 **
# Ticker  : 332610
# Market  : US
# Type    : Bond
# MEAN +/-: 4 %
# MAX/MIN : 111 / 99
# RANGE.  : 12
# PV      : 111
# ** TIGER 골드선물(H) **
# Ticker  : 319640
# Market  : Global
# Type    : Commodity
# MEAN +/-: 1 %
# MAX/MIN : 110 / 94
# RANGE.  : 16
# PV      : 94
# ** 신한 인버스 옥수수 선물 ETN(H) **
# Ticker  : 500014
# Market  : Global
# Type    : Commodity
# MEAN +/-: -11 %
# MAX/MIN : 111 / 66
# RANGE.  : 45
# PV      : 80
# ** 대신 인버스 아연선물 ETN(H) **
# Ticker  : 510004
# Market  : Global
# Type    : Commodity
# MEAN +/-: -18 %
# MAX/MIN : 101 / 56
# RANGE.  : 45
# PV      : 87
# ** 대신 인버스 니켈선물 ETN(H) **
# Ticker  : 510006
# Market  : Global
# Type    : Commodity
# MEAN +/-: -31 %
# MAX/MIN : 104 / 25
# RANGE.  : 79
# PV      : 40
# ** 대신 인버스 알루미늄 선물 ETN(H) **
# Ticker  : 510018
# Market  : Global
# Type    : Commodity
# MEAN +/-: -14 %
# MAX/MIN : 107 / 64
# RANGE.  : 43
# PV      : 106
# ** ARIRANG 신흥국MSCI(합성 H) **
# Ticker  : 195980
# Market  : Global
# Type    : Index
# MEAN +/-: -12 %
# MAX/MIN : 100 / 72
# RANGE.  : 28
# PV      : 72
# ** KOSEF 인도Nifty50(합성) **
# Ticker  : 200250
# Market  : Global
# Type    : Index
# MEAN +/-: 11 %
# MAX/MIN : 120 / 98
# RANGE.  : 22
# PV      : 105
# ** KINDEX 인도네시아MSCI(합성) **
# Ticker  : 256440
# Market  : Global
# Type    : Index
# MEAN +/-: 21 %
# MAX/MIN : 144 / 99
# RANGE.  : 45
# PV      : 123
# ** ARIRANG 신흥국MSCI인버스(합성 H) **
# Ticker  : 373530
# Market  : Global
# Type    : Index
# MEAN +/-: 8 %
# MAX/MIN : 126 / 98
# RANGE.  : 28
# PV      : 126
# ** TIGER 일본니케이225 **
# Ticker  : 241180
# Market  : JP
# Type    : Index
# MEAN +/-: -1 %
# MAX/MIN : 113 / 87
# RANGE.  : 26
# PV      : 87
# ** KODEX 200 **
# Ticker  : 069500
# Market  : KR
# Type    : Index
# MEAN +/-: -12 %
# MAX/MIN : 101 / 71
# RANGE.  : 30
# PV      : 72
# ** TIGER 인버스 **
# Ticker  : 123310
# Market  : KR
# Type    : Index
# MEAN +/-: 12 %
# MAX/MIN : 136 / 98
# RANGE.  : 38
# PV      : 135
# ** TIGER 미국나스닥100 **
# Ticker  : 133690
# Market  : US
# Type    : Index
# MEAN +/-: 3 %
# MAX/MIN : 117 / 85
# RANGE.  : 32
# PV      : 92
# ** TIGER 미국S&P500 **
# Ticker  : 360750
# Market  : US
# Type    : Index
# MEAN +/-: 7 %
# MAX/MIN : 116 / 96
# RANGE.  : 20
# PV      : 102
# ** 신한 S&P500 VIX S/T 선물 ETN C **
# Ticker  : 500058
# Market  : US
# Type    : Index
# MEAN +/-: -21 %
# MAX/MIN : 109 / 59
# RANGE.  : 50
# PV      : 80
# ** TRUE S&P500 양매도 4% OTM ETN(H) **
# Ticker  : 570049
# Market  : US
# Type    : Index
# MEAN +/-: 4 %
# MAX/MIN : 110 / 99
# RANGE.  : 11
# PV      : 105
# ** KODEX 미국나스닥100선물인버스(H) **
# Ticker  : 409810
# Market  : US
# Type    : Index
# MEAN +/-: 15 %
# MAX/MIN : 137 / 98
# RANGE.  : 39
# PV      : 131
# ** TIGER 차이나전기차SOLACTIVE **
# Ticker  : 371460
# Market  : CN
# Type    : Sector
# MEAN +/-: 5 %
# MAX/MIN : 130 / 69
# RANGE.  : 61
# PV      : 106
# ** TIGER 글로벌리튬&2차전지 SOLACTIVE(합성) **
# Ticker  : 394670
# Market  : CN
# Type    : Sector
# MEAN +/-: 7 %
# MAX/MIN : 127 / 89
# RANGE.  : 38
# PV      : 100
# ** KOSEF 릭소글로벌퓨처모빌리티MSCI **
# Ticker  : 394350
# Market  : Global
# Type    : Sector
# MEAN +/-: 7 %
# MAX/MIN : 128 / 91
# RANGE.  : 37
# PV      : 92
# ** TIGER 경기방어 **
# Ticker  : 139280
# Market  : KR
# Type    : Sector
# MEAN +/-: -16 %
# MAX/MIN : 101 / 72
# RANGE.  : 29
# PV      : 77
# ** TIGER 소프트웨어 **
# Ticker  : 157490
# Market  : KR
# Type    : Sector
# MEAN +/-: -23 %
# MAX/MIN : 100 / 50
# RANGE.  : 50
# PV      : 50
# ** KODEX 필수소비재 **
# Ticker  : 266410
# Market  : KR
# Type    : Sector
# MEAN +/-: -18 %
# MAX/MIN : 100 / 68
# RANGE.  : 32
# PV      : 70
# ** TIGER 2차전지테마 **
# Ticker  : 305540
# Market  : KR
# Type    : Sector
# MEAN +/-: 2 %
# MAX/MIN : 121 / 82
# RANGE.  : 39
# PV      : 82
# ** TIGER 리츠부동산인프라 **
# Ticker  : 329200
# Market  : KR
# Type    : Sector
# MEAN +/-: 4 %
# MAX/MIN : 114 / 95
# RANGE.  : 19
# PV      : 95
# ** KBSTAR Fn수소경제테마 **
# Ticker  : 367770
# Market  : KR
# Type    : Sector
# MEAN +/-: -13 %
# MAX/MIN : 102 / 70
# RANGE.  : 32
# PV      : 70
# ** KODEX 미국S&P에너지(합성) **
# Ticker  : 218420
# Market  : US
# Type    : Sector
# MEAN +/-: 39 %
# MAX/MIN : 209 / 95
# RANGE.  : 114
# PV      : 161
# ** TIGER S&P글로벌인프라(합성) **
# Ticker  : 269370
# Market  : US
# Type    : Sector
# MEAN +/-: 9 %
# MAX/MIN : 123 / 98
# RANGE.  : 25
# PV      : 115
# ** KIDEX 미국WideMoat가치주 **
# Ticker  : 309230
# Market  : US
# Type    : Sector
# MEAN +/-: 4 %
# MAX/MIN : 109 / 94
# RANGE.  : 15
# PV      : 100
# ** TIGER 글로벌클라우드컴퓨팅INDXX **
# Ticker  : 371450
# Market  : US
# Type    : Sector
# MEAN +/-: -8 %
# MAX/MIN : 119 / 64
# RANGE.  : 55
# PV      : 70
# ** KOSEF 미국방어배당성장나스닥 **
# Ticker  : 373790
# Market  : US
# Type    : Sector
# MEAN +/-: 10 %
# MAX/MIN : 124 / 99
# RANGE.  : 25
# PV      : 118
# ** 삼성 미국 대형 가치주 ETN **
# Ticker  : 530020
# Market  : US
# Type    : Sector
# MEAN +/-: 14 %
# MAX/MIN : 129 / 97
# RANGE.  : 32
# PV      : 117

# %%
performance.sort_values(by= ['PV'], ascending= True)
# Out:
#                                   NAME  MARKET       TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006              대신 인버스 니켈선물 ETN(H)  Global  Commodity      -31  104   25
# 157490                     TIGER 소프트웨어      KR     Sector      -23  100   50
# 266410                     KODEX 필수소비재      KR     Sector      -18  100   68
# 367770                 KBSTAR Fn수소경제테마      KR     Sector      -13  102   70
# 371450           TIGER 글로벌클라우드컴퓨팅INDXX      US     Sector       -8  119   64
# 195980           ARIRANG 신흥국MSCI(합성 H)  Global      Index      -12  100   72
# 069500                       KODEX 200      KR      Index      -12  101   71
# 139280                      TIGER 경기방어      KR     Sector      -16  101   72
# 500058      신한 S&P500 VIX S/T 선물 ETN C      US      Index      -21  109   59
# 500014            신한 인버스 옥수수 선물 ETN(H)  Global  Commodity      -11  111   66
# 305540                    TIGER 2차전지테마      KR     Sector        2  121   82
# 510004              대신 인버스 아연선물 ETN(H)  Global  Commodity      -18  101   56
# 241180                  TIGER 일본니케이225      JP      Index       -1  113   87
# 133690                  TIGER 미국나스닥100      US      Index        3  117   85
# 394350           KOSEF 릭소글로벌퓨처모빌리티MSCI  Global     Sector        7  128   91
# 319640                   TIGER 골드선물(H)  Global  Commodity        1  110   94
# 329200                  TIGER 리츠부동산인프라      KR     Sector        4  114   95
# 309230             KIDEX 미국WideMoat가치주      US     Sector        4  109   94
# 394670  TIGER 글로벌리튬&2차전지 SOLACTIVE(합성)      CN     Sector        7  127   89
# 360750                  TIGER 미국S&P500      US      Index        7  116   96
# 200250             KOSEF 인도Nifty50(합성)  Global      Index       11  120   98
# 570049   TRUE S&P500 양매도 4% OTM ETN(H)      US      Index        4  110   99
# 510018           대신 인버스 알루미늄 선물 ETN(H)  Global  Commodity      -14  107   64
# 371460           TIGER 차이나전기차SOLACTIVE      CN     Sector        5  130   69
# 332610               ARIRANG 미국단기우량회사채      US       Bond        4  111   99
# 269370             TIGER S&P글로벌인프라(합성)      US     Sector        9  123   98
# 530020                삼성 미국 대형 가치주 ETN      US     Sector       14  129   97
# 373790               KOSEF 미국방어배당성장나스닥      US     Sector       10  124   99
# 256440            KINDEX 인도네시아MSCI(합성)  Global      Index       21  144   99
# 373530        ARIRANG 신흥국MSCI인버스(합성 H)  Global      Index        8  126   98
# 409810          KODEX 미국나스닥100선물인버스(H)      US      Index       15  137   98
# 123310                       TIGER 인버스      KR      Index       12  136   98
# 218420              KODEX 미국S&P에너지(합성)      US     Sector       39  209   95
#
#         RNG   PV
# TICKER
# 510006   79   40
# 157490   50   50
# 266410   32   70
# 367770   32   70
# 371450   55   70
# 195980   28   72
# 069500   30   72
# 139280   29   77
# 500058   50   80
# 500014   45   80
# 305540   39   82
# 510004   45   87
# 241180   26   87
# 133690   32   92
# 394350   37   92
# 319640   16   94
# 329200   19   95
# 309230   15  100
# 394670   38  100
# 360750   20  102
# 200250   22  105
# 570049   11  105
# 510018   43  106
# 371460   61  106
# 332610   12  111
# 269370   25  115
# 530020   32  117
# 373790   25  118
# 256440   45  123
# 373530   28  126
# 409810   39  131
# 123310   38  135
# 218420  114  161

# %%
performance.sort_values(by= ['RNG'], ascending= True)
# Out:
#                                   NAME  MARKET       TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 570049   TRUE S&P500 양매도 4% OTM ETN(H)      US      Index        4  110   99
# 332610               ARIRANG 미국단기우량회사채      US       Bond        4  111   99
# 309230             KIDEX 미국WideMoat가치주      US     Sector        4  109   94
# 319640                   TIGER 골드선물(H)  Global  Commodity        1  110   94
# 329200                  TIGER 리츠부동산인프라      KR     Sector        4  114   95
# 360750                  TIGER 미국S&P500      US      Index        7  116   96
# 200250             KOSEF 인도Nifty50(합성)  Global      Index       11  120   98
# 269370             TIGER S&P글로벌인프라(합성)      US     Sector        9  123   98
# 373790               KOSEF 미국방어배당성장나스닥      US     Sector       10  124   99
# 241180                  TIGER 일본니케이225      JP      Index       -1  113   87
# 195980           ARIRANG 신흥국MSCI(합성 H)  Global      Index      -12  100   72
# 373530        ARIRANG 신흥국MSCI인버스(합성 H)  Global      Index        8  126   98
# 139280                      TIGER 경기방어      KR     Sector      -16  101   72
# 069500                       KODEX 200      KR      Index      -12  101   71
# 367770                 KBSTAR Fn수소경제테마      KR     Sector      -13  102   70
# 266410                     KODEX 필수소비재      KR     Sector      -18  100   68
# 133690                  TIGER 미국나스닥100      US      Index        3  117   85
# 530020                삼성 미국 대형 가치주 ETN      US     Sector       14  129   97
# 394350           KOSEF 릭소글로벌퓨처모빌리티MSCI  Global     Sector        7  128   91
# 123310                       TIGER 인버스      KR      Index       12  136   98
# 394670  TIGER 글로벌리튬&2차전지 SOLACTIVE(합성)      CN     Sector        7  127   89
# 305540                    TIGER 2차전지테마      KR     Sector        2  121   82
# 409810          KODEX 미국나스닥100선물인버스(H)      US      Index       15  137   98
# 510018           대신 인버스 알루미늄 선물 ETN(H)  Global  Commodity      -14  107   64
# 256440            KINDEX 인도네시아MSCI(합성)  Global      Index       21  144   99
# 510004              대신 인버스 아연선물 ETN(H)  Global  Commodity      -18  101   56
# 500014            신한 인버스 옥수수 선물 ETN(H)  Global  Commodity      -11  111   66
# 500058      신한 S&P500 VIX S/T 선물 ETN C      US      Index      -21  109   59
# 157490                     TIGER 소프트웨어      KR     Sector      -23  100   50
# 371450           TIGER 글로벌클라우드컴퓨팅INDXX      US     Sector       -8  119   64
# 371460           TIGER 차이나전기차SOLACTIVE      CN     Sector        5  130   69
# 510006              대신 인버스 니켈선물 ETN(H)  Global  Commodity      -31  104   25
# 218420              KODEX 미국S&P에너지(합성)      US     Sector       39  209   95
#
#         RNG   PV
# TICKER
# 570049   11  105
# 332610   12  111
# 309230   15  100
# 319640   16   94
# 329200   19   95
# 360750   20  102
# 200250   22  105
# 269370   25  115
# 373790   25  118
# 241180   26   87
# 195980   28   72
# 373530   28  126
# 139280   29   77
# 069500   30   72
# 367770   32   70
# 266410   32   70
# 133690   32   92
# 530020   32  117
# 394350   37   92
# 123310   38  135
# 394670   38  100
# 305540   39   82
# 409810   39  131
# 510018   43  106
# 256440   45  123
# 510004   45   87
# 500014   45   80
# 500058   50   80
# 157490   50   50
# 371450   55   70
# 371460   61  106
# 510006   79   40
# 218420  114  161

# %%
performance.sort_values(by= ['MIN'], ascending= True)
# Out:
#                                   NAME  MARKET       TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006              대신 인버스 니켈선물 ETN(H)  Global  Commodity      -31  104   25
# 157490                     TIGER 소프트웨어      KR     Sector      -23  100   50
# 510004              대신 인버스 아연선물 ETN(H)  Global  Commodity      -18  101   56
# 500058      신한 S&P500 VIX S/T 선물 ETN C      US      Index      -21  109   59
# 510018           대신 인버스 알루미늄 선물 ETN(H)  Global  Commodity      -14  107   64
# 371450           TIGER 글로벌클라우드컴퓨팅INDXX      US     Sector       -8  119   64
# 500014            신한 인버스 옥수수 선물 ETN(H)  Global  Commodity      -11  111   66
# 266410                     KODEX 필수소비재      KR     Sector      -18  100   68
# 371460           TIGER 차이나전기차SOLACTIVE      CN     Sector        5  130   69
# 367770                 KBSTAR Fn수소경제테마      KR     Sector      -13  102   70
# 069500                       KODEX 200      KR      Index      -12  101   71
# 139280                      TIGER 경기방어      KR     Sector      -16  101   72
# 195980           ARIRANG 신흥국MSCI(합성 H)  Global      Index      -12  100   72
# 305540                    TIGER 2차전지테마      KR     Sector        2  121   82
# 133690                  TIGER 미국나스닥100      US      Index        3  117   85
# 241180                  TIGER 일본니케이225      JP      Index       -1  113   87
# 394670  TIGER 글로벌리튬&2차전지 SOLACTIVE(합성)      CN     Sector        7  127   89
# 394350           KOSEF 릭소글로벌퓨처모빌리티MSCI  Global     Sector        7  128   91
# 309230             KIDEX 미국WideMoat가치주      US     Sector        4  109   94
# 319640                   TIGER 골드선물(H)  Global  Commodity        1  110   94
# 218420              KODEX 미국S&P에너지(합성)      US     Sector       39  209   95
# 329200                  TIGER 리츠부동산인프라      KR     Sector        4  114   95
# 360750                  TIGER 미국S&P500      US      Index        7  116   96
# 530020                삼성 미국 대형 가치주 ETN      US     Sector       14  129   97
# 123310                       TIGER 인버스      KR      Index       12  136   98
# 373530        ARIRANG 신흥국MSCI인버스(합성 H)  Global      Index        8  126   98
# 200250             KOSEF 인도Nifty50(합성)  Global      Index       11  120   98
# 409810          KODEX 미국나스닥100선물인버스(H)      US      Index       15  137   98
# 269370             TIGER S&P글로벌인프라(합성)      US     Sector        9  123   98
# 332610               ARIRANG 미국단기우량회사채      US       Bond        4  111   99
# 256440            KINDEX 인도네시아MSCI(합성)  Global      Index       21  144   99
# 373790               KOSEF 미국방어배당성장나스닥      US     Sector       10  124   99
# 570049   TRUE S&P500 양매도 4% OTM ETN(H)      US      Index        4  110   99
#
#         RNG   PV
# TICKER
# 510006   79   40
# 157490   50   50
# 510004   45   87
# 500058   50   80
# 510018   43  106
# 371450   55   70
# 500014   45   80
# 266410   32   70
# 371460   61  106
# 367770   32   70
# 069500   30   72
# 139280   29   77
# 195980   28   72
# 305540   39   82
# 133690   32   92
# 241180   26   87
# 394670   38  100
# 394350   37   92
# 309230   15  100
# 319640   16   94
# 218420  114  161
# 329200   19   95
# 360750   20  102
# 530020   32  117
# 123310   38  135
# 373530   28  126
# 200250   22  105
# 409810   39  131
# 269370   25  115
# 332610   12  111
# 256440   45  123
# 373790   25  118
# 570049   11  105
