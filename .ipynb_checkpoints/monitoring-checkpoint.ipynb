# %%
### Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
# import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
# code: ['NAME', 'MARKET', 'STOCK', 'TYPE', 'MONITORING?']
tickerdict = {
    '005930': ['삼성전자', 'KR', 'stock', 'long', False],
    '000660': ['SK하이닉스', 'KR', 'stock', 'long', False],
    '009830': ['한화솔루션', 'KR', 'stock', 'long', False],
    '035420': ['NAVER', 'KR', 'stock', 'long', False],
    '088980': ['맥쿼리인프라', 'KR', 'stock', 'long', False],
    '091160': ['KODEX 반도체', 'KR', 'stock', 'long', True],
    '102110': ['TIGER 200', 'KR', 'index', 'long', True],
    '105010': ['TIGER 라틴35', 'Global', 'sector', 'long', True],
    '123310': ['TIGER 인버스', 'KR', 'index', 'short', True],
    '133690': ['TIGER 미국나스닥100', 'US', 'index', 'long', True],
    '139280': ['TIGER 경기방어', 'KR', 'sector', 'long', True],
    '157490': ['TIGER 소프트웨어', 'KR', 'sector', 'long', True],
    '169950': ['KODEX 차이나A50', 'Global', 'index', 'long', True],
    '195930': ['TIGER 유로스탁스50(합성 H)', 'Global', 'index', 'long', True],
    '195980': ['ARIRANG 신흥국MSCI(합성 H)', 'Global', 'index', 'long', True],
    '200250': ['KOSEF 인도Nifty50(합성)', 'Global', 'index', 'long', True],
    '218420': ['KODEX 미국S&P에너지(합성)', 'US', 'commodity', 'long', True],
    '219390': ['KBSTAR 미국S&P원유생산기업(합성 H)', 'US','commodity', 'long', True],
    '241180': ['TIGER 일본니케이225', 'JP', 'index', 'long', True],
    '244660': ['KODEX 퀄리티Plus', 'KR', 'sector', 'long', True],
    '256440': ['ACE 인도네시아MSCI(합성)', 'Global', 'index', 'long', True],
    '266420': ['KODEX 미디어&엔터테인먼트', 'KR', 'sector', 'long', True],
    '266410': ['KODEX 필수소비재', 'KR', 'sector', 'long', True],
    '269370': ['TIGER S&P글로벌인프라(합성)', 'US', 'sector', 'long', True],
    '271050': ['KODEX WTI원유선물인버스(H)', 'Global', 'commodity', 'short', False],
    '275280': ['KODEX MSCI모멘텀', 'KR', 'sector', 'long', True],
    '305540': ['TIGER 2차전지테마', 'KR', 'sector', 'long', True],
    '309230': ['ACE 미국WideMoat가치주', 'US', 'sector', 'long', True],
    '319640': ['TIGER 골드선물(H)',  'Global',  'commodity', 'long', True],
    '329200': ['TIGER 리츠부동산인프라', 'KR', 'RealEstate', 'long', True],
    '332610': ['ARIRANG 미국단기우량회사채', 'US',  'bond', 'long', True],
    '334690': ['KBSTAR 팔라듐선물(H)',  'Global',  'commodity', 'long', True],
    '360750': ['TIGER 미국S&P500', 'US', 'index', 'long', True],
    '360770': ['KBSTAR Fn수소경제테마', 'KR', 'sector', 'long', True],
    '371450': ['TIGER 글로벌클라우드컴퓨팅INDXX', 'US', 'sector', 'long', True],
    '371460': ['TIGER 차이나전기차SOLACTIVE', 'CN', 'sector', 'long', True],
    '373530': ['ARIRANG 신흥국MSCI인버스(합성 H)', 'Global', 'index', 'short', True],
    '373790': ['KOSEF 미국방어배당성장나스닥', 'US', 'sector', 'long', True],
    '391600': ['ACE 미국친환경그린테마INDXX', 'US', 'sector', 'long', True],
    '394350': ['KOSEF 릭소글로벌퓨처모빌리티MSCI', 'Global', 'sector', 'long', True],
    '396510': ['TIGER 차이나클린에너지SOLACTIVE', 'Global', 'sector', 'long', True],
    '399580': ['KBSTAR 글로벌클린에너지S&P', 'Global', 'sector', 'long', True],
    '400570': ['KODEX 유럽탄소배출권선물ICE(H)', 'Global', 'sector', 'long', True],
    '402970': ['ACE 미국고배당S&P', 'US', 'sector', 'long', True],
    '407820': ['에셋플러스 코리아플랫폼액티브', 'KR', 'sector', 'long', True],
    '407830': ['에셋플러스 글로벌플랫폼액티브', 'US', 'sector', 'long', True],
    '409810': ['KODEX 미국나스닥100선물인버스(H)', 'US', 'index', 'short', True],
    '411420': ['KODEX 미국메타버스나스닥액티브',  'US',  'sector', 'long', True],
    '413220': ['SOL 차이나태양광CSI(합성)', 'Global', 'sector', 'long', True],
    '417450': ['KBSTAR 글로벌수소경제Indxx', 'Global', 'sector', 'long', True],
    '419650': ['ARIRANG 글로벌수소&차세대연료전지MV', 'Global', 'sector', 'long', True],
    '429000': ['TIGER 미국S&P500배당귀족', 'US', 'sector', 'long', True],
    '500014': ['신한 인버스 옥수수 선물 ETN(H)',  'Global', 'commodity', 'long', False],
    '500058': ['신한 S&P500 VIX S/T 선물 ETN C', 'US', 'index', 'option', True],
    '510004': ['대신 인버스 아연선물 ETN(H)', 'Global', 'commodity', 'short', False],
    '510006': ['대신 인버스 니켈선물 ETN(H)', 'Global', 'commodity', 'short', False],
    '510018': ['대신 인버스 알루미늄 선물 ETN(H)', 'Global', 'commodity', 'short', False],
    '530020': ['삼성 미국 대형 가치주 ETN', 'US', 'sector', 'long', True],
    '570025': ['TRUE 인버스 유로스탁스50 ETN(H)', 'Global', 'index', 'short', True],
    '570049': ['TRUE S&P500 양매도 4% OTM ETN(H)', 'US', 'index', 'option', True],
    '590018': ['미래에셋 중국 심천 100 ETN', 'CN', 'sector', 'long', True]
}

# %%
ticker = pd.DataFrame(tickerdict).T.reset_index()
ticker.columns = ['TICKER', 'NAME', 'MARKET', 'TYPE', 'POSITION', 'MONITOR']

ticker
# Out:
#     TICKER                           NAME  MARKET       TYPE POSITION MONITOR
# 0   005930                           삼성전자      KR      stock     long   False
# 1   000660                         SK하이닉스      KR      stock     long   False
# 2   009830                          한화솔루션      KR      stock     long   False
# 3   035420                          NAVER      KR      stock     long   False
# 4   088980                         맥쿼리인프라      KR      stock     long   False
# ..     ...                            ...     ...        ...      ...     ...
# 56  510018          대신 인버스 알루미늄 선물 ETN(H)  Global  commodity    short   False
# 57  530020               삼성 미국 대형 가치주 ETN      US     sector     long    True
# 58  570025        TRUE 인버스 유로스탁스50 ETN(H)  Global      index    short    True
# 59  570049  TRUE S&P500 양매도 4% OTM ETN(H)      US      index   option    True
# 60  590018             미래에셋 중국 심천 100 ETN      CN     sector     long    True
#
# [61 rows x 6 columns]

# %%
daydelta = 360   # 조회될 기간 설정. 일 기준
today = datetime.today()

start = (today + timedelta(days= -1 * daydelta)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

print('---------------------------------------------')
print('최근', daydelta, '일 데이터 조회', '- MA 20d, 50d')
print('---------------------------------------------')
print()

l_perf = []
for i, row in ticker.sort_values(['TYPE', 'MARKET', 'POSITION']).iterrows():
    try:
        if row.MONITOR:
            data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
            data = data / data.iloc[0] * 100
            cmean = int(data.Close.mean()) - 100
            cmax = int(data.Close.max())
            cmin = int(data.Close.min())
            rng = cmax - cmin
            cpv = int(data.Close[-1])
            l_perf.append([row.TICKER, row.NAME, row.MARKET, row.TYPE, cmean, cmax, cmin, rng, cpv])
            
            print('**', row.NAME, '**')
            print('Ticker  :', row.TICKER)
            print('Market  :', row.MARKET)
            print('Type    :', row.TYPE)
            print('MEAN +/-:', cmean, '%')
            print('MAX/MIN :', cmax, '/', cmin)
            print('RANGE.  :', rng)
            print('PV      :', cpv)
            fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, mav=(20, 50))

        # Annotation
#         for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
#             if data.index[0] < pd.to_datetime(prow.DATE):
#                 x = data.reset_index().index[data.index == prow.DATE].item()
# #                 y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
#                 cap = str(prow.CAP * -1)
#                 stocks = str(prow.STOCKS)
#                 sb = 'SELL' if prow.SELL else 'BUY'
#                 axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
            plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
    
performance = pd.DataFrame(data= l_perf, columns= ['TICKER', 'NAME', 'MARKET', 'TYPE', 'MEAN+/-', 'MAX', 'MIN', 'RNG', 'PV'])
performance.set_index(['TICKER'], inplace= True)
# Out:
# ---------------------------------------------
# 최근 360 일 데이터 조회 - MA 20d, 50d
# ---------------------------------------------
#
# ** TIGER 리츠부동산인프라 **
# Ticker  : 329200
# Market  : KR
# Type    : RealEstate
# MEAN +/-: -5 %
# MAX/MIN : 110 / 73
# RANGE.  : 37
# PV      : 81
# ** ARIRANG 미국단기우량회사채 **
# Ticker  : 332610
# Market  : US
# Type    : bond
# MEAN +/-: 4 %
# MAX/MIN : 115 / 98
# RANGE.  : 17
# PV      : 104
# ** TIGER 골드선물(H) **
# Ticker  : 319640
# Market  : Global
# Type    : commodity
# MEAN +/-: -1 %
# MAX/MIN : 111 / 88
# RANGE.  : 23
# PV      : 98
# ** KBSTAR 팔라듐선물(H) **
# Ticker  : 334690
# Market  : Global
# Type    : commodity
# MEAN +/-: 22 %
# MAX/MIN : 185 / 100
# RANGE.  : 85
# PV      : 109
# ** KODEX 미국S&P에너지(합성) **
# Ticker  : 218420
# Market  : US
# Type    : commodity
# MEAN +/-: 56 %
# MAX/MIN : 203 / 100
# RANGE.  : 103
# PV      : 174
# ** KBSTAR 미국S&P원유생산기업(합성 H) **
# Ticker  : 219390
# Market  : US
# Type    : commodity
# MEAN +/-: 42 %
# MAX/MIN : 187 / 100
# RANGE.  : 87
# PV      : 148
# ** KODEX 차이나A50 **
# Ticker  : 169950
# Market  : Global
# Type    : index
# MEAN +/-: -11 %
# MAX/MIN : 100 / 76
# RANGE.  : 24
# PV      : 83
# ** TIGER 유로스탁스50(합성 H) **
# Ticker  : 195930
# Market  : Global
# Type    : index
# MEAN +/-: -7 %
# MAX/MIN : 106 / 81
# RANGE.  : 25
# PV      : 99
# ** ARIRANG 신흥국MSCI(합성 H) **
# Ticker  : 195980
# Market  : Global
# Type    : index
# MEAN +/-: -14 %
# MAX/MIN : 105 / 69
# RANGE.  : 36
# PV      : 79
# ** KOSEF 인도Nifty50(합성) **
# Ticker  : 200250
# Market  : Global
# Type    : index
# MEAN +/-: 7 %
# MAX/MIN : 118 / 95
# RANGE.  : 23
# PV      : 111
# ** ACE 인도네시아MSCI(합성) **
# Ticker  : 256440
# Market  : Global
# Type    : index
# MEAN +/-: 13 %
# MAX/MIN : 131 / 100
# RANGE.  : 31
# PV      : 114
# ** ARIRANG 신흥국MSCI인버스(합성 H) **
# Ticker  : 373530
# Market  : Global
# Type    : index
# MEAN +/-: 12 %
# MAX/MIN : 134 / 95
# RANGE.  : 39
# PV      : 117
# ** TRUE 인버스 유로스탁스50 ETN(H) **
# Ticker  : 570025
# Market  : Global
# Type    : index
# MEAN +/-: 2 %
# MAX/MIN : 116 / 92
# RANGE.  : 24
# PV      : 92
# ** TIGER 일본니케이225 **
# Ticker  : 241180
# Market  : JP
# Type    : index
# MEAN +/-: -8 %
# MAX/MIN : 103 / 84
# RANGE.  : 19
# PV      : 92
# ** TIGER 200 **
# Ticker  : 102110
# Market  : KR
# Type    : index
# MEAN +/-: -13 %
# MAX/MIN : 102 / 73
# RANGE.  : 29
# PV      : 81
# ** TIGER 인버스 **
# Ticker  : 123310
# Market  : KR
# Type    : index
# MEAN +/-: 14 %
# MAX/MIN : 134 / 97
# RANGE.  : 37
# PV      : 120
# ** TIGER 미국나스닥100 **
# Ticker  : 133690
# Market  : US
# Type    : index
# MEAN +/-: -11 %
# MAX/MIN : 106 / 77
# RANGE.  : 29
# PV      : 82
# ** TIGER 미국S&P500 **
# Ticker  : 360750
# Market  : US
# Type    : index
# MEAN +/-: -2 %
# MAX/MIN : 105 / 87
# RANGE.  : 18
# PV      : 96
# ** 신한 S&P500 VIX S/T 선물 ETN C **
# Ticker  : 500058
# Market  : US
# Type    : index
# MEAN +/-: -8 %
# MAX/MIN : 129 / 65
# RANGE.  : 64
# PV      : 66
# ** TRUE S&P500 양매도 4% OTM ETN(H) **
# Ticker  : 570049
# Market  : US
# Type    : index
# MEAN +/-: 1 %
# MAX/MIN : 107 / 96
# RANGE.  : 11
# PV      : 99
# ** KODEX 미국나스닥100선물인버스(H) **
# Ticker  : 409810
# Market  : US
# Type    : index
# MEAN +/-: 16 %
# MAX/MIN : 134 / 93
# RANGE.  : 41
# PV      : 122
# ** TIGER 차이나전기차SOLACTIVE **
# Ticker  : 371460
# Market  : CN
# Type    : sector
# MEAN +/-: -18 %
# MAX/MIN : 102 / 60
# RANGE.  : 42
# PV      : 69
# ** 미래에셋 중국 심천 100 ETN **
# Ticker  : 590018
# Market  : CN
# Type    : sector
# MEAN +/-: -16 %
# MAX/MIN : 101 / 70
# RANGE.  : 31
# PV      : 75
# ** TIGER 라틴35 **
# Ticker  : 105010
# Market  : Global
# Type    : sector
# MEAN +/-: 20 %
# MAX/MIN : 142 / 98
# RANGE.  : 44
# PV      : 120
# ** KOSEF 릭소글로벌퓨처모빌리티MSCI **
# Ticker  : 394350
# Market  : Global
# Type    : sector
# MEAN +/-: -12 %
# MAX/MIN : 105 / 78
# RANGE.  : 27
# PV      : 78
# ** TIGER 차이나클린에너지SOLACTIVE **
# Ticker  : 396510
# Market  : Global
# Type    : sector
# MEAN +/-: -4 %
# MAX/MIN : 110 / 77
# RANGE.  : 33
# PV      : 83
# ** KBSTAR 글로벌클린에너지S&P **
# Ticker  : 399580
# Market  : Global
# Type    : sector
# MEAN +/-: 4 %
# MAX/MIN : 128 / 83
# RANGE.  : 45
# PV      : 111
# ** KODEX 유럽탄소배출권선물ICE(H) **
# Ticker  : 400570
# Market  : Global
# Type    : sector
# MEAN +/-: 6 %
# MAX/MIN : 128 / 77
# RANGE.  : 51
# PV      : 115
# ** SOL 차이나태양광CSI(합성) **
# Ticker  : 413220
# Market  : Global
# Type    : sector
# MEAN +/-: -9 %
# MAX/MIN : 113 / 64
# RANGE.  : 49
# PV      : 78
# ** KBSTAR 글로벌수소경제Indxx **
# Ticker  : 417450
# Market  : Global
# Type    : sector
# MEAN +/-: 1 %
# MAX/MIN : 122 / 87
# RANGE.  : 35
# PV      : 92
# ** ARIRANG 글로벌수소&차세대연료전지MV **
# Ticker  : 419650
# Market  : Global
# Type    : sector
# MEAN +/-: -3 %
# MAX/MIN : 127 / 75
# RANGE.  : 52
# PV      : 82
# ** TIGER 경기방어 **
# Ticker  : 139280
# Market  : KR
# Type    : sector
# MEAN +/-: -12 %
# MAX/MIN : 100 / 77
# RANGE.  : 23
# PV      : 88
# ** TIGER 소프트웨어 **
# Ticker  : 157490
# Market  : KR
# Type    : sector
# MEAN +/-: -31 %
# MAX/MIN : 102 / 45
# RANGE.  : 57
# PV      : 56
# ** KODEX 퀄리티Plus **
# Ticker  : 244660
# Market  : KR
# Type    : sector
# MEAN +/-: -14 %
# MAX/MIN : 103 / 67
# RANGE.  : 36
# PV      : 77
# ** KODEX 미디어&엔터테인먼트 **
# Ticker  : 266420
# Market  : KR
# Type    : sector
# MEAN +/-: -22 %
# MAX/MIN : 100 / 65
# RANGE.  : 35
# PV      : 73
# ** KODEX 필수소비재 **
# Ticker  : 266410
# Market  : KR
# Type    : sector
# MEAN +/-: -10 %
# MAX/MIN : 100 / 77
# RANGE.  : 23
# PV      : 90
# ** KODEX MSCI모멘텀 **
# Ticker  : 275280
# Market  : KR
# Type    : sector
# MEAN +/-: -15 %
# MAX/MIN : 102 / 72
# RANGE.  : 30
# PV      : 77
# ** TIGER 2차전지테마 **
# Ticker  : 305540
# Market  : KR
# Type    : sector
# MEAN +/-: -12 %
# MAX/MIN : 104 / 73
# RANGE.  : 31
# PV      : 85
# ************* ERROR on KBSTAR Fn수소경제테마
# ** 에셋플러스 코리아플랫폼액티브 **
# Ticker  : 407820
# Market  : KR
# Type    : sector
# MEAN +/-: -25 %
# MAX/MIN : 101 / 53
# RANGE.  : 48
# PV      : 61
# ** TIGER S&P글로벌인프라(합성) **
# Ticker  : 269370
# Market  : US
# Type    : sector
# MEAN +/-: 11 %
# MAX/MIN : 123 / 99
# RANGE.  : 24
# PV      : 114
# ** ACE 미국WideMoat가치주 **
# Ticker  : 309230
# Market  : US
# Type    : sector
# MEAN +/-: 0 %
# MAX/MIN : 110 / 90
# RANGE.  : 20
# PV      : 101
# ** TIGER 글로벌클라우드컴퓨팅INDXX **
# Ticker  : 371450
# Market  : US
# Type    : sector
# MEAN +/-: -22 %
# MAX/MIN : 103 / 66
# RANGE.  : 37
# PV      : 71
# ** KOSEF 미국방어배당성장나스닥 **
# Ticker  : 373790
# Market  : US
# Type    : sector
# MEAN +/-: 7 %
# MAX/MIN : 118 / 94
# RANGE.  : 24
# PV      : 109
# ** ACE 미국친환경그린테마INDXX **
# Ticker  : 391600
# Market  : US
# Type    : sector
# MEAN +/-: 3 %
# MAX/MIN : 126 / 84
# RANGE.  : 42
# PV      : 105
# ** ACE 미국고배당S&P **
# Ticker  : 402970
# Market  : US
# Type    : sector
# MEAN +/-: 5 %
# MAX/MIN : 115 / 96
# RANGE.  : 19
# PV      : 111
# ** 에셋플러스 글로벌플랫폼액티브 **
# Ticker  : 407830
# Market  : US
# Type    : sector
# MEAN +/-: -21 %
# MAX/MIN : 109 / 63
# RANGE.  : 46
# PV      : 65
# ** KODEX 미국메타버스나스닥액티브 **
# Ticker  : 411420
# Market  : US
# Type    : sector
# MEAN +/-: -26 %
# MAX/MIN : 103 / 60
# RANGE.  : 43
# PV      : 62
# ** TIGER 미국S&P500배당귀족 **
# Ticker  : 429000
# Market  : US
# Type    : sector
# MEAN +/-: 2 %
# MAX/MIN : 109 / 92
# RANGE.  : 17
# PV      : 106
# ** 삼성 미국 대형 가치주 ETN **
# Ticker  : 530020
# Market  : US
# Type    : sector
# MEAN +/-: 11 %
# MAX/MIN : 122 / 98
# RANGE.  : 24
# PV      : 113
# ** KODEX 반도체 **
# Ticker  : 091160
# Market  : KR
# Type    : stock
# MEAN +/-: -17 %
# MAX/MIN : 108 / 60
# RANGE.  : 48
# PV      : 66

# %%
performance.sort_values(by= ['PV'], ascending= True)
# Out:
#                                  NAME  MARKET        TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006             대신 인버스 니켈선물 ETN(H)  Global   commodity      -50  100   27
# 035420                          NAVER      KR       stock      -30  103   42
# 157490                    TIGER 소프트웨어      KR      sector      -31  102   45
# 411420             KODEX 미국메타버스나스닥액티브      US      sector      -26  103   60
# 000660                         SK하이닉스      KR       stock      -14  110   65
# 500058     신한 S&P500 VIX S/T 선물 ETN C      US       index       -7  129   65
# 371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector      -22  103   66
# 371460          TIGER 차이나전기차SOLACTIVE      CN      sector      -18  102   60
# 590018             미래에셋 중국 심천 100 ETN      CN      sector      -16  101   70
# 005930                           삼성전자      KR       stock      -16  104   68
# 394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector      -12  105   78
# 195980          ARIRANG 신흥국MSCI(합성 H)  Global       index      -14  105   69
# 088980                         맥쿼리인프라      KR       stock       -8  101   74
# 500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity      -19  100   69
# 069500                      KODEX 200      KR       index      -13  102   73
# 329200                 TIGER 리츠부동산인프라      KR  RealEstate       -5  110   73
# 133690                 TIGER 미국나스닥100      US       index      -11  106   77
# 305540                   TIGER 2차전지테마      KR      sector      -12  104   73
# 169950                   KODEX 차이나A50  Global       index      -11  100   76
# 139280                     TIGER 경기방어      KR      sector      -12  100   77
# 241180                 TIGER 일본니케이225      JP       index       -8  103   84
# 266410                    KODEX 필수소비재      KR      sector      -10  100   77
# 360750                KBSTAR Fn수소경제테마      KR      sector       -2  105   87
# 319640                  TIGER 골드선물(H)  Global   commodity       -1  111   88
# 510004             대신 인버스 아연선물 ETN(H)  Global   commodity      -11  109   66
# 570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index        1  107   96
# 309230           KINDEX 미국WideMoat가치주      US      sector        0  110   90
# 510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity       -3  123   66
# 332610              ARIRANG 미국단기우량회사채      US        bond        4  115   98
# 334690                KBSTAR 팔라듐선물(H)  Global   commodity       22  185  100
# 373790              KOSEF 미국방어배당성장나스닥      US      sector        7  118   94
# 200250            KOSEF 인도Nifty50(합성)  Global       index        7  118   95
# 530020               삼성 미국 대형 가치주 ETN      US      sector       11  122   98
# 269370            TIGER S&P글로벌인프라(합성)      US      sector       11  123   99
# 256440           KINDEX 인도네시아MSCI(합성)  Global       index       13  131  100
# 373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index       12  134   95
# 409810         KODEX 미국나스닥100선물인버스(H)      US       index       16  134   93
# 219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity       42  187  100
# 218420             KODEX 미국S&P에너지(합성)      US   commodity       56  203  100
#
#         RNG   PV
# TICKER
# 510006   73   36
# 035420   61   51
# 157490   57   55
# 411420   43   62
# 000660   45   68
# 500058   64   69
# 371450   37   70
# 371460   42   70
# 590018   31   76
# 005930   36   77
# 394350   27   78
# 195980   36   78
# 088980   27   79
# 500014   31   80
# 069500   29   81
# 329200   37   81
# 133690   29   82
# 305540   31   83
# 169950   24   83
# 139280   23   87
# 241180   19   90
# 266410   23   90
# 360750   18   96
# 319640   23   97
# 510004   43   98
# 570049   11   99
# 309230   20  100
# 510018   57  104
# 332610   17  105
# 334690   85  107
# 373790   24  108
# 200250   23  111
# 530020   24  112
# 269370   24  113
# 256440   31  113
# 373530   39  119
# 409810   41  123
# 219390   87  149
# 218420  103  173

# %%
performance.sort_values(by= ['RNG'], ascending= True)
# Out:
#                                  NAME  MARKET        TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index        1  107   96
# 332610              ARIRANG 미국단기우량회사채      US        bond        4  115   98
# 360750                KBSTAR Fn수소경제테마      KR      sector       -2  105   87
# 241180                 TIGER 일본니케이225      JP       index       -8  103   84
# 309230           KINDEX 미국WideMoat가치주      US      sector        0  110   90
# 319640                  TIGER 골드선물(H)  Global   commodity       -1  111   88
# 266410                    KODEX 필수소비재      KR      sector      -10  100   77
# 139280                     TIGER 경기방어      KR      sector      -12  100   77
# 200250            KOSEF 인도Nifty50(합성)  Global       index        7  118   95
# 530020               삼성 미국 대형 가치주 ETN      US      sector       11  122   98
# 373790              KOSEF 미국방어배당성장나스닥      US      sector        7  118   94
# 269370            TIGER S&P글로벌인프라(합성)      US      sector       11  123   99
# 169950                   KODEX 차이나A50  Global       index      -11  100   76
# 394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector      -12  105   78
# 088980                         맥쿼리인프라      KR       stock       -8  101   74
# 069500                      KODEX 200      KR       index      -13  102   73
# 133690                 TIGER 미국나스닥100      US       index      -11  106   77
# 256440           KINDEX 인도네시아MSCI(합성)  Global       index       13  131  100
# 500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity      -19  100   69
# 305540                   TIGER 2차전지테마      KR      sector      -12  104   73
# 590018             미래에셋 중국 심천 100 ETN      CN      sector      -16  101   70
# 005930                           삼성전자      KR       stock      -16  104   68
# 195980          ARIRANG 신흥국MSCI(합성 H)  Global       index      -14  105   69
# 371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector      -22  103   66
# 329200                 TIGER 리츠부동산인프라      KR  RealEstate       -5  110   73
# 373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index       12  134   95
# 409810         KODEX 미국나스닥100선물인버스(H)      US       index       16  134   93
# 371460          TIGER 차이나전기차SOLACTIVE      CN      sector      -18  102   60
# 510004             대신 인버스 아연선물 ETN(H)  Global   commodity      -11  109   66
# 411420             KODEX 미국메타버스나스닥액티브      US      sector      -26  103   60
# 000660                         SK하이닉스      KR       stock      -14  110   65
# 157490                    TIGER 소프트웨어      KR      sector      -31  102   45
# 510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity       -3  123   66
# 035420                          NAVER      KR       stock      -30  103   42
# 500058     신한 S&P500 VIX S/T 선물 ETN C      US       index       -7  129   65
# 510006             대신 인버스 니켈선물 ETN(H)  Global   commodity      -50  100   27
# 334690                KBSTAR 팔라듐선물(H)  Global   commodity       22  185  100
# 219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity       42  187  100
# 218420             KODEX 미국S&P에너지(합성)      US   commodity       56  203  100
#
#         RNG   PV
# TICKER
# 570049   11   99
# 332610   17  105
# 360750   18   96
# 241180   19   90
# 309230   20  100
# 319640   23   97
# 266410   23   90
# 139280   23   87
# 200250   23  111
# 530020   24  112
# 373790   24  108
# 269370   24  113
# 169950   24   83
# 394350   27   78
# 088980   27   79
# 069500   29   81
# 133690   29   82
# 256440   31  113
# 500014   31   80
# 305540   31   83
# 590018   31   76
# 005930   36   77
# 195980   36   78
# 371450   37   70
# 329200   37   81
# 373530   39  119
# 409810   41  123
# 371460   42   70
# 510004   43   98
# 411420   43   62
# 000660   45   68
# 157490   57   55
# 510018   57  104
# 035420   61   51
# 500058   64   69
# 510006   73   36
# 334690   85  107
# 219390   87  149
# 218420  103  173

# %%
performance.sort_values(by= ['MIN'], ascending= True)
# Out:
#                                  NAME  MARKET        TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006             대신 인버스 니켈선물 ETN(H)  Global   commodity      -50  100   27
# 035420                          NAVER      KR       stock      -30  103   42
# 157490                    TIGER 소프트웨어      KR      sector      -31  102   45
# 411420             KODEX 미국메타버스나스닥액티브      US      sector      -26  103   60
# 371460          TIGER 차이나전기차SOLACTIVE      CN      sector      -18  102   60
# 000660                         SK하이닉스      KR       stock      -14  110   65
# 500058     신한 S&P500 VIX S/T 선물 ETN C      US       index       -7  129   65
# 371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector      -22  103   66
# 510004             대신 인버스 아연선물 ETN(H)  Global   commodity      -11  109   66
# 510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity       -3  123   66
# 005930                           삼성전자      KR       stock      -16  104   68
# 500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity      -19  100   69
# 195980          ARIRANG 신흥국MSCI(합성 H)  Global       index      -14  105   69
# 590018             미래에셋 중국 심천 100 ETN      CN      sector      -16  101   70
# 329200                 TIGER 리츠부동산인프라      KR  RealEstate       -5  110   73
# 305540                   TIGER 2차전지테마      KR      sector      -12  104   73
# 069500                      KODEX 200      KR       index      -13  102   73
# 088980                         맥쿼리인프라      KR       stock       -8  101   74
# 169950                   KODEX 차이나A50  Global       index      -11  100   76
# 133690                 TIGER 미국나스닥100      US       index      -11  106   77
# 266410                    KODEX 필수소비재      KR      sector      -10  100   77
# 139280                     TIGER 경기방어      KR      sector      -12  100   77
# 394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector      -12  105   78
# 241180                 TIGER 일본니케이225      JP       index       -8  103   84
# 360750                KBSTAR Fn수소경제테마      KR      sector       -2  105   87
# 319640                  TIGER 골드선물(H)  Global   commodity       -1  111   88
# 309230           KINDEX 미국WideMoat가치주      US      sector        0  110   90
# 409810         KODEX 미국나스닥100선물인버스(H)      US       index       16  134   93
# 373790              KOSEF 미국방어배당성장나스닥      US      sector        7  118   94
# 373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index       12  134   95
# 200250            KOSEF 인도Nifty50(합성)  Global       index        7  118   95
# 570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index        1  107   96
# 530020               삼성 미국 대형 가치주 ETN      US      sector       11  122   98
# 332610              ARIRANG 미국단기우량회사채      US        bond        4  115   98
# 269370            TIGER S&P글로벌인프라(합성)      US      sector       11  123   99
# 256440           KINDEX 인도네시아MSCI(합성)  Global       index       13  131  100
# 219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity       42  187  100
# 218420             KODEX 미국S&P에너지(합성)      US   commodity       56  203  100
# 334690                KBSTAR 팔라듐선물(H)  Global   commodity       22  185  100
#
#         RNG   PV
# TICKER
# 510006   73   36
# 035420   61   51
# 157490   57   55
# 411420   43   62
# 371460   42   70
# 000660   45   68
# 500058   64   69
# 371450   37   70
# 510004   43   98
# 510018   57  104
# 005930   36   77
# 500014   31   80
# 195980   36   78
# 590018   31   76
# 329200   37   81
# 305540   31   83
# 069500   29   81
# 088980   27   79
# 169950   24   83
# 133690   29   82
# 266410   23   90
# 139280   23   87
# 394350   27   78
# 241180   19   90
# 360750   18   96
# 319640   23   97
# 309230   20  100
# 409810   41  123
# 373790   24  108
# 373530   39  119
# 200250   23  111
# 570049   11   99
# 530020   24  112
# 332610   17  105
# 269370   24  113
# 256440   31  113
# 219390   87  149
# 218420  103  173
# 334690   85  107
