# %%
### Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
# import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
capital = pd.read_excel('position.xlsx', sheet_name='capital')
eva = pd.read_excel('position.xlsx', sheet_name='eva')
position = pd.read_excel('position.xlsx', sheet_name='position')

ticker = pd.read_excel('position.xlsx', sheet_name='ticker')

tkstring = []

for tk in ticker.TICKER:
    tkstring.append('0' * (6 - len(str(tk))) + str(tk))    
    
ticker.TICKER = tkstring
# ticker.tail()

# %%
daydelta = 360   # 조회될 기간 설정. 일 기준
today = datetime.today()

start = (today + timedelta(days= -1 * daydelta)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

print('---------------------------------------------')
print('최근', daydelta, '일 데이터 조회', '- MA 20d, 50d')
print('---------------------------------------------')
print()

l_perf = []
for i, row in ticker.sort_values(['TYPE', 'MARKET', 'POSITION']).iterrows():
    try:
        if row.MONITOR:
            data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
            data = data / data.iloc[0] * 100
            cmean = int(data.Close.mean()) - 100
            cmax = int(data.Close.max())
            cmin = int(data.Close.min())
            rng = cmax - cmin
            cpv = int(data.Close[-1])
            l_perf.append([row.TICKER, row.NAME, row.MARKET, row.TYPE, cmean, cmax, cmin, rng, cpv])
            
            print('**', row.NAME, '**')
            print('Ticker  :', row.TICKER)
            print('Market  :', row.MARKET)
            print('Type    :', row.TYPE)
            print('MEAN +/-:', cmean, '%')
            print('MAX/MIN :', cmax, '/', cmin)
            print('RANGE.  :', rng)
            print('PV      :', cpv)
            fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, mav=(20, 50))

        # Annotation
#         for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
#             if data.index[0] < pd.to_datetime(prow.DATE):
#                 x = data.reset_index().index[data.index == prow.DATE].item()
# #                 y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
#                 cap = str(prow.CAP * -1)
#                 stocks = str(prow.STOCKS)
#                 sb = 'SELL' if prow.SELL else 'BUY'
#                 axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
            plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
    
performance = pd.DataFrame(data= l_perf, columns= ['TICKER', 'NAME', 'MARKET', 'TYPE', 'MEAN+/-', 'MAX', 'MIN', 'RNG', 'PV'])
performance.set_index(['TICKER'], inplace= True)
# Out:
# ---------------------------------------------
# 최근 360 일 데이터 조회 - MA 20d, 50d
# ---------------------------------------------
#
# ** ARIRANG 미국단기우량회사채 **
# Ticker  : 332610
# Market  : US
# Type    : Bond
# MEAN +/-: 3 %
# MAX/MIN : 111 / 98
# RANGE.  : 13
# PV      : 109
# ** TIGER 골드선물(H) **
# Ticker  : 319640
# Market  : Global
# Type    : Commodity
# MEAN +/-: 0 %
# MAX/MIN : 110 / 92
# RANGE.  : 18
# PV      : 94
# ** 신한 인버스 옥수수 선물 ETN(H) **
# Ticker  : 500014
# Market  : Global
# Type    : Commodity
# MEAN +/-: -16 %
# MAX/MIN : 106 / 64
# RANGE.  : 42
# PV      : 82
# ** 대신 인버스 아연선물 ETN(H) **
# Ticker  : 510004
# Market  : Global
# Type    : Commodity
# MEAN +/-: -17 %
# MAX/MIN : 102 / 57
# RANGE.  : 45
# PV      : 88
# ** 대신 인버스 니켈선물 ETN(H) **
# Ticker  : 510006
# Market  : Global
# Type    : Commodity
# MEAN +/-: -31 %
# MAX/MIN : 108 / 26
# RANGE.  : 82
# PV      : 40
# ** 대신 인버스 알루미늄 선물 ETN(H) **
# Ticker  : 510018
# Market  : Global
# Type    : Commodity
# MEAN +/-: -13 %
# MAX/MIN : 108 / 64
# RANGE.  : 44
# PV      : 102
# ** ARIRANG 신흥국MSCI(합성 H) **
# Ticker  : 195980
# Market  : Global
# Type    : Index
# MEAN +/-: -10 %
# MAX/MIN : 102 / 73
# RANGE.  : 29
# PV      : 76
# ** KOSEF 인도Nifty50(합성) **
# Ticker  : 200250
# Market  : Global
# Type    : Index
# MEAN +/-: 10 %
# MAX/MIN : 119 / 100
# RANGE.  : 19
# PV      : 108
# ** KINDEX 인도네시아MSCI(합성) **
# Ticker  : 256440
# Market  : Global
# Type    : Index
# MEAN +/-: 22 %
# MAX/MIN : 144 / 100
# RANGE.  : 44
# PV      : 127
# ** ARIRANG 신흥국MSCI인버스(합성 H) **
# Ticker  : 373530
# Market  : Global
# Type    : Index
# MEAN +/-: 6 %
# MAX/MIN : 124 / 96
# RANGE.  : 28
# PV      : 119
# ** TIGER 일본니케이225 **
# Ticker  : 241180
# Market  : JP
# Type    : Index
# MEAN +/-: -3 %
# MAX/MIN : 112 / 85
# RANGE.  : 27
# PV      : 91
# ** KODEX 200 **
# Ticker  : 069500
# Market  : KR
# Type    : Index
# MEAN +/-: -13 %
# MAX/MIN : 102 / 72
# RANGE.  : 30
# PV      : 76
# ** TIGER 인버스 **
# Ticker  : 123310
# Market  : KR
# Type    : Index
# MEAN +/-: 13 %
# MAX/MIN : 136 / 97
# RANGE.  : 39
# PV      : 128
# ** TIGER 미국나스닥100 **
# Ticker  : 133690
# Market  : US
# Type    : Index
# MEAN +/-: 0 %
# MAX/MIN : 114 / 83
# RANGE.  : 31
# PV      : 93
# ** TIGER 미국S&P500 **
# Ticker  : 360750
# Market  : US
# Type    : Index
# MEAN +/-: 4 %
# MAX/MIN : 113 / 94
# RANGE.  : 19
# PV      : 102
# ** 신한 S&P500 VIX S/T 선물 ETN C **
# Ticker  : 500058
# Market  : US
# Type    : Index
# MEAN +/-: -19 %
# MAX/MIN : 106 / 61
# RANGE.  : 45
# PV      : 73
# ** TRUE S&P500 양매도 4% OTM ETN(H) **
# Ticker  : 570049
# Market  : US
# Type    : Index
# MEAN +/-: 3 %
# MAX/MIN : 109 / 100
# RANGE.  : 9
# PV      : 106
# ** KODEX 미국나스닥100선물인버스(H) **
# Ticker  : 409810
# Market  : US
# Type    : Index
# MEAN +/-: 16 %
# MAX/MIN : 137 / 98
# RANGE.  : 39
# PV      : 125
# ** TIGER 차이나전기차SOLACTIVE **
# Ticker  : 371460
# Market  : CN
# Type    : Sector
# MEAN +/-: -5 %
# MAX/MIN : 118 / 63
# RANGE.  : 55
# PV      : 95
# ** TIGER 글로벌리튬&2차전지 SOLACTIVE(합성) **
# Ticker  : 394670
# Market  : CN
# Type    : Sector
# MEAN +/-: -2 %
# MAX/MIN : 117 / 82
# RANGE.  : 35
# PV      : 97
# ** KOSEF 릭소글로벌퓨처모빌리티MSCI **
# Ticker  : 394350
# Market  : Global
# Type    : Sector
# MEAN +/-: 1 %
# MAX/MIN : 121 / 86
# RANGE.  : 35
# PV      : 92
# ** TIGER 경기방어 **
# Ticker  : 139280
# Market  : KR
# Type    : Sector
# MEAN +/-: -15 %
# MAX/MIN : 103 / 74
# RANGE.  : 29
# PV      : 79
# ** TIGER 소프트웨어 **
# Ticker  : 157490
# Market  : KR
# Type    : Sector
# MEAN +/-: -23 %
# MAX/MIN : 101 / 51
# RANGE.  : 50
# PV      : 54
# ** KODEX 필수소비재 **
# Ticker  : 266410
# Market  : KR
# Type    : Sector
# MEAN +/-: -15 %
# MAX/MIN : 101 / 71
# RANGE.  : 30
# PV      : 75
# ** TIGER 2차전지테마 **
# Ticker  : 305540
# Market  : KR
# Type    : Sector
# MEAN +/-: 3 %
# MAX/MIN : 122 / 83
# RANGE.  : 39
# PV      : 90
# ** TIGER 리츠부동산인프라 **
# Ticker  : 329200
# Market  : KR
# Type    : Sector
# MEAN +/-: 4 %
# MAX/MIN : 114 / 94
# RANGE.  : 20
# PV      : 95
# ** KBSTAR Fn수소경제테마 **
# Ticker  : 367770
# Market  : KR
# Type    : Sector
# MEAN +/-: -12 %
# MAX/MIN : 105 / 71
# RANGE.  : 34
# PV      : 77
# ** KODEX 미국S&P에너지(합성) **
# Ticker  : 218420
# Market  : US
# Type    : Sector
# MEAN +/-: 39 %
# MAX/MIN : 205 / 93
# RANGE.  : 112
# PV      : 167
# ** TIGER S&P글로벌인프라(합성) **
# Ticker  : 269370
# Market  : US
# Type    : Sector
# MEAN +/-: 9 %
# MAX/MIN : 121 / 99
# RANGE.  : 22
# PV      : 118
# ** KIDEX 미국WideMoat가치주 **
# Ticker  : 309230
# Market  : US
# Type    : Sector
# MEAN +/-: 1 %
# MAX/MIN : 106 / 91
# RANGE.  : 15
# PV      : 101
# ** TIGER 글로벌클라우드컴퓨팅INDXX **
# Ticker  : 371450
# Market  : US
# Type    : Sector
# MEAN +/-: -12 %
# MAX/MIN : 115 / 62
# RANGE.  : 53
# PV      : 69
# ** KOSEF 미국방어배당성장나스닥 **
# Ticker  : 373790
# Market  : US
# Type    : Sector
# MEAN +/-: 10 %
# MAX/MIN : 123 / 99
# RANGE.  : 24
# PV      : 118
# ** 삼성 미국 대형 가치주 ETN **
# Ticker  : 530020
# Market  : US
# Type    : Sector
# MEAN +/-: 12 %
# MAX/MIN : 126 / 98
# RANGE.  : 28
# PV      : 116

# %%
performance.sort_values(by= ['PV'], ascending= True)
# Out:
#                                   NAME  MARKET       TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006              대신 인버스 니켈선물 ETN(H)  Global  Commodity      -31  108   26
# 157490                     TIGER 소프트웨어      KR     Sector      -23  101   51
# 371450           TIGER 글로벌클라우드컴퓨팅INDXX      US     Sector      -12  115   62
# 500058      신한 S&P500 VIX S/T 선물 ETN C      US      Index      -19  106   61
# 266410                     KODEX 필수소비재      KR     Sector      -15  101   71
# 195980           ARIRANG 신흥국MSCI(합성 H)  Global      Index      -10  102   73
# 069500                       KODEX 200      KR      Index      -13  102   72
# 367770                 KBSTAR Fn수소경제테마      KR     Sector      -12  105   71
# 139280                      TIGER 경기방어      KR     Sector      -15  103   74
# 500014            신한 인버스 옥수수 선물 ETN(H)  Global  Commodity      -16  106   64
# 510004              대신 인버스 아연선물 ETN(H)  Global  Commodity      -17  102   57
# 305540                    TIGER 2차전지테마      KR     Sector        3  122   83
# 241180                  TIGER 일본니케이225      JP      Index       -3  112   85
# 394350           KOSEF 릭소글로벌퓨처모빌리티MSCI  Global     Sector        1  121   86
# 133690                  TIGER 미국나스닥100      US      Index        0  114   83
# 319640                   TIGER 골드선물(H)  Global  Commodity        0  110   92
# 329200                  TIGER 리츠부동산인프라      KR     Sector        4  114   94
# 371460           TIGER 차이나전기차SOLACTIVE      CN     Sector       -5  118   63
# 394670  TIGER 글로벌리튬&2차전지 SOLACTIVE(합성)      CN     Sector       -2  117   82
# 309230             KIDEX 미국WideMoat가치주      US     Sector        1  106   91
# 360750                  TIGER 미국S&P500      US      Index        4  113   94
# 510018           대신 인버스 알루미늄 선물 ETN(H)  Global  Commodity      -13  108   64
# 570049   TRUE S&P500 양매도 4% OTM ETN(H)      US      Index        3  109  100
# 200250             KOSEF 인도Nifty50(합성)  Global      Index       10  119  100
# 332610               ARIRANG 미국단기우량회사채      US       Bond        3  111   98
# 530020                삼성 미국 대형 가치주 ETN      US     Sector       12  126   98
# 373790               KOSEF 미국방어배당성장나스닥      US     Sector       10  123   99
# 269370             TIGER S&P글로벌인프라(합성)      US     Sector        9  121   99
# 373530        ARIRANG 신흥국MSCI인버스(합성 H)  Global      Index        6  124   96
# 409810          KODEX 미국나스닥100선물인버스(H)      US      Index       16  137   98
# 256440            KINDEX 인도네시아MSCI(합성)  Global      Index       22  144  100
# 123310                       TIGER 인버스      KR      Index       13  136   97
# 218420              KODEX 미국S&P에너지(합성)      US     Sector       39  205   93
#
#         RNG   PV
# TICKER
# 510006   82   40
# 157490   50   54
# 371450   53   69
# 500058   45   73
# 266410   30   75
# 195980   29   76
# 069500   30   76
# 367770   34   77
# 139280   29   79
# 500014   42   82
# 510004   45   88
# 305540   39   90
# 241180   27   91
# 394350   35   92
# 133690   31   93
# 319640   18   94
# 329200   20   95
# 371460   55   95
# 394670   35   97
# 309230   15  101
# 360750   19  102
# 510018   44  102
# 570049    9  106
# 200250   19  108
# 332610   13  109
# 530020   28  116
# 373790   24  118
# 269370   22  118
# 373530   28  119
# 409810   39  125
# 256440   44  127
# 123310   39  128
# 218420  112  167

# %%
performance.sort_values(by= ['RNG'], ascending= True)
# Out:
#                                   NAME  MARKET       TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 570049   TRUE S&P500 양매도 4% OTM ETN(H)      US      Index        3  109  100
# 332610               ARIRANG 미국단기우량회사채      US       Bond        3  111   98
# 309230             KIDEX 미국WideMoat가치주      US     Sector        1  106   91
# 319640                   TIGER 골드선물(H)  Global  Commodity        0  110   92
# 200250             KOSEF 인도Nifty50(합성)  Global      Index       10  119  100
# 360750                  TIGER 미국S&P500      US      Index        4  113   94
# 329200                  TIGER 리츠부동산인프라      KR     Sector        4  114   94
# 269370             TIGER S&P글로벌인프라(합성)      US     Sector        9  121   99
# 373790               KOSEF 미국방어배당성장나스닥      US     Sector       10  123   99
# 241180                  TIGER 일본니케이225      JP      Index       -3  112   85
# 530020                삼성 미국 대형 가치주 ETN      US     Sector       12  126   98
# 373530        ARIRANG 신흥국MSCI인버스(합성 H)  Global      Index        6  124   96
# 139280                      TIGER 경기방어      KR     Sector      -15  103   74
# 195980           ARIRANG 신흥국MSCI(합성 H)  Global      Index      -10  102   73
# 266410                     KODEX 필수소비재      KR     Sector      -15  101   71
# 069500                       KODEX 200      KR      Index      -13  102   72
# 133690                  TIGER 미국나스닥100      US      Index        0  114   83
# 367770                 KBSTAR Fn수소경제테마      KR     Sector      -12  105   71
# 394670  TIGER 글로벌리튬&2차전지 SOLACTIVE(합성)      CN     Sector       -2  117   82
# 394350           KOSEF 릭소글로벌퓨처모빌리티MSCI  Global     Sector        1  121   86
# 305540                    TIGER 2차전지테마      KR     Sector        3  122   83
# 409810          KODEX 미국나스닥100선물인버스(H)      US      Index       16  137   98
# 123310                       TIGER 인버스      KR      Index       13  136   97
# 500014            신한 인버스 옥수수 선물 ETN(H)  Global  Commodity      -16  106   64
# 256440            KINDEX 인도네시아MSCI(합성)  Global      Index       22  144  100
# 510018           대신 인버스 알루미늄 선물 ETN(H)  Global  Commodity      -13  108   64
# 500058      신한 S&P500 VIX S/T 선물 ETN C      US      Index      -19  106   61
# 510004              대신 인버스 아연선물 ETN(H)  Global  Commodity      -17  102   57
# 157490                     TIGER 소프트웨어      KR     Sector      -23  101   51
# 371450           TIGER 글로벌클라우드컴퓨팅INDXX      US     Sector      -12  115   62
# 371460           TIGER 차이나전기차SOLACTIVE      CN     Sector       -5  118   63
# 510006              대신 인버스 니켈선물 ETN(H)  Global  Commodity      -31  108   26
# 218420              KODEX 미국S&P에너지(합성)      US     Sector       39  205   93
#
#         RNG   PV
# TICKER
# 570049    9  106
# 332610   13  109
# 309230   15  101
# 319640   18   94
# 200250   19  108
# 360750   19  102
# 329200   20   95
# 269370   22  118
# 373790   24  118
# 241180   27   91
# 530020   28  116
# 373530   28  119
# 139280   29   79
# 195980   29   76
# 266410   30   75
# 069500   30   76
# 133690   31   93
# 367770   34   77
# 394670   35   97
# 394350   35   92
# 305540   39   90
# 409810   39  125
# 123310   39  128
# 500014   42   82
# 256440   44  127
# 510018   44  102
# 500058   45   73
# 510004   45   88
# 157490   50   54
# 371450   53   69
# 371460   55   95
# 510006   82   40
# 218420  112  167

# %%
performance.sort_values(by= ['MIN'], ascending= True)
# Out:
#                                   NAME  MARKET       TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006              대신 인버스 니켈선물 ETN(H)  Global  Commodity      -31  108   26
# 157490                     TIGER 소프트웨어      KR     Sector      -23  101   51
# 510004              대신 인버스 아연선물 ETN(H)  Global  Commodity      -17  102   57
# 500058      신한 S&P500 VIX S/T 선물 ETN C      US      Index      -19  106   61
# 371450           TIGER 글로벌클라우드컴퓨팅INDXX      US     Sector      -12  115   62
# 371460           TIGER 차이나전기차SOLACTIVE      CN     Sector       -5  118   63
# 500014            신한 인버스 옥수수 선물 ETN(H)  Global  Commodity      -16  106   64
# 510018           대신 인버스 알루미늄 선물 ETN(H)  Global  Commodity      -13  108   64
# 266410                     KODEX 필수소비재      KR     Sector      -15  101   71
# 367770                 KBSTAR Fn수소경제테마      KR     Sector      -12  105   71
# 069500                       KODEX 200      KR      Index      -13  102   72
# 195980           ARIRANG 신흥국MSCI(합성 H)  Global      Index      -10  102   73
# 139280                      TIGER 경기방어      KR     Sector      -15  103   74
# 394670  TIGER 글로벌리튬&2차전지 SOLACTIVE(합성)      CN     Sector       -2  117   82
# 305540                    TIGER 2차전지테마      KR     Sector        3  122   83
# 133690                  TIGER 미국나스닥100      US      Index        0  114   83
# 241180                  TIGER 일본니케이225      JP      Index       -3  112   85
# 394350           KOSEF 릭소글로벌퓨처모빌리티MSCI  Global     Sector        1  121   86
# 309230             KIDEX 미국WideMoat가치주      US     Sector        1  106   91
# 319640                   TIGER 골드선물(H)  Global  Commodity        0  110   92
# 218420              KODEX 미국S&P에너지(합성)      US     Sector       39  205   93
# 360750                  TIGER 미국S&P500      US      Index        4  113   94
# 329200                  TIGER 리츠부동산인프라      KR     Sector        4  114   94
# 373530        ARIRANG 신흥국MSCI인버스(합성 H)  Global      Index        6  124   96
# 123310                       TIGER 인버스      KR      Index       13  136   97
# 332610               ARIRANG 미국단기우량회사채      US       Bond        3  111   98
# 530020                삼성 미국 대형 가치주 ETN      US     Sector       12  126   98
# 409810          KODEX 미국나스닥100선물인버스(H)      US      Index       16  137   98
# 373790               KOSEF 미국방어배당성장나스닥      US     Sector       10  123   99
# 269370             TIGER S&P글로벌인프라(합성)      US     Sector        9  121   99
# 256440            KINDEX 인도네시아MSCI(합성)  Global      Index       22  144  100
# 200250             KOSEF 인도Nifty50(합성)  Global      Index       10  119  100
# 570049   TRUE S&P500 양매도 4% OTM ETN(H)      US      Index        3  109  100
#
#         RNG   PV
# TICKER
# 510006   82   40
# 157490   50   54
# 510004   45   88
# 500058   45   73
# 371450   53   69
# 371460   55   95
# 500014   42   82
# 510018   44  102
# 266410   30   75
# 367770   34   77
# 069500   30   76
# 195980   29   76
# 139280   29   79
# 394670   35   97
# 305540   39   90
# 133690   31   93
# 241180   27   91
# 394350   35   92
# 309230   15  101
# 319640   18   94
# 218420  112  167
# 360750   19  102
# 329200   20   95
# 373530   28  119
# 123310   39  128
# 332610   13  109
# 530020   28  116
# 409810   39  125
# 373790   24  118
# 269370   22  118
# 256440   44  127
# 200250   19  108
# 570049    9  106
