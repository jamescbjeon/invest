# %%
### Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
# import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
# code: ['NAME', 'MARKET', 'STOCK', 'TYPE', 'MONITORING?']
tickerdict = {
    '005930': ['삼성전자', 'KR', 'stock', 'long', True],
    '000660': ['SK하이닉스', 'KR', 'stock', 'long', True],
    '035420': ['NAVER', 'KR', 'stock', 'long', True],
    '069500': ['KODEX 200', 'KR', 'index', 'long', True],
    '088980': ['맥쿼리인프라', 'KR', 'stock', 'long', True],
    '123310': ['TIGER 인버스', 'KR', 'index', 'short', False],
    '133690': ['TIGER 미국나스닥100', 'US', 'index', 'long', True],
    '139280': ['TIGER 경기방어', 'KR', 'sector', 'long', True],
    '157490': ['TIGER 소프트웨어', 'KR', 'sector', 'long', True],
    '169950': ['KODEX 차이나A50', 'Global', 'index', 'long', True],
    '195980': ['ARIRANG 신흥국MSCI(합성 H)', 'Global', 'index', 'long', True],
    '200250': ['KOSEF 인도Nifty50(합성)', 'Global', 'index', 'long', True],
    '218420': ['KODEX 미국S&P에너지(합성)', 'US', 'commodity', 'long', True],
    '219390': ['KBSTAR 미국S&P원유생산기업(합성 H)', 'US','commodity', 'long', True],
    '241180': ['TIGER 일본니케이225', 'JP', 'index', 'long', True],
    '256440': ['KINDEX 인도네시아MSCI(합성)', 'Global', 'index', 'long', True],
    '266410': ['KODEX 필수소비재', 'KR', 'sector', 'long', True],
    '269370': ['TIGER S&P글로벌인프라(합성)', 'US', 'sector', 'long', True],
    '271050': ['KODEX WTI원유선물인버스(H)', 'Global', 'commodity', 'short', False],
    '305540': ['TIGER 2차전지테마', 'KR', 'sector', 'long', True],
    '309230': ['KINDEX 미국WideMoat가치주', 'US', 'sector', 'long', True],
    '319640': ['TIGER 골드선물(H)',  'Global',  'commodity', 'long', True],
    '329200': ['TIGER 리츠부동산인프라', 'KR', 'RealEstate', 'long', True],
    '332610': ['ARIRANG 미국단기우량회사채', 'US',  'bond', 'long', True],
    '334690': ['KBSTAR 팔라듐선물(H)',  'Global',  'commodity', 'long', True],
    '360750': ['TIGER 미국S&P500', 'US', 'index', 'long', True],
    '360750': ['KBSTAR Fn수소경제테마', 'KR', 'sector', 'long', True],
    '371450': ['TIGER 글로벌클라우드컴퓨팅INDXX', 'US', 'sector', 'long', True],
    '371460': ['TIGER 차이나전기차SOLACTIVE', 'CN', 'sector', 'long', True],
    '373530': ['ARIRANG 신흥국MSCI인버스(합성 H)', 'Global', 'index', 'short', True],
    '373790': ['KOSEF 미국방어배당성장나스닥', 'US', 'sector', 'long', True],
    '394350': ['KOSEF 릭소글로벌퓨처모빌리티MSCI', 'Global', 'sector', 'long', True],
    '409810': ['KODEX 미국나스닥100선물인버스(H)', 'US', 'index', 'short', True],
    '411420': ['KODEX 미국메타버스나스닥액티브',  'US',  'sector', 'long', True],
    '500014': ['신한 인버스 옥수수 선물 ETN(H)',  'Global', 'commodity', 'long', True],
    '500058': ['신한 S&P500 VIX S/T 선물 ETN C', 'US', 'index', 'option', True],
    '510004': ['대신 인버스 아연선물 ETN(H)', 'Global', 'commodity', 'short', True],
    '510006': ['대신 인버스 니켈선물 ETN(H)', 'Global', 'commodity', 'short', True],
    '510018': ['대신 인버스 알루미늄 선물 ETN(H)', 'Global', 'commodity', 'short', True],
    '530020': ['삼성 미국 대형 가치주 ETN', 'US', 'sector', 'long', True],
    '570049': ['TRUE S&P500 양매도 4% OTM ETN(H)', 'US', 'index', 'option', True],
    '590018': ['미래에셋 중국 심천 100 ETN', 'CN', 'sector', 'long', True]
}

# %%
ticker = pd.DataFrame(tickerdict).T.reset_index()
ticker.columns = ['TICKER', 'NAME', 'MARKET', 'TYPE', 'POSITION', 'MONITOR']

ticker
# Out:
#     TICKER                           NAME  MARKET        TYPE POSITION MONITOR
# 0   005930                           삼성전자      KR       stock     long    True
# 1   000660                         SK하이닉스      KR       stock     long    True
# 2   035420                          NAVER      KR       stock     long    True
# 3   069500                      KODEX 200      KR       index     long    True
# 4   088980                         맥쿼리인프라      KR       stock     long    True
# 5   123310                      TIGER 인버스      KR       index    short   False
# 6   133690                 TIGER 미국나스닥100      US       index     long    True
# 7   139280                     TIGER 경기방어      KR      sector     long    True
# 8   157490                    TIGER 소프트웨어      KR      sector     long    True
# 9   169950                   KODEX 차이나A50  Global       index     long    True
# 10  195980          ARIRANG 신흥국MSCI(합성 H)  Global       index     long    True
# 11  200250            KOSEF 인도Nifty50(합성)  Global       index     long    True
# 12  218420             KODEX 미국S&P에너지(합성)      US   commodity     long    True
# 13  219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity     long    True
# 14  241180                 TIGER 일본니케이225      JP       index     long    True
# 15  256440           KINDEX 인도네시아MSCI(합성)  Global       index     long    True
# 16  266410                    KODEX 필수소비재      KR      sector     long    True
# 17  269370            TIGER S&P글로벌인프라(합성)      US      sector     long    True
# 18  271050            KODEX WTI원유선물인버스(H)  Global   commodity    short   False
# 19  305540                   TIGER 2차전지테마      KR      sector     long    True
# 20  309230           KINDEX 미국WideMoat가치주      US      sector     long    True
# 21  319640                  TIGER 골드선물(H)  Global   commodity     long    True
# 22  329200                 TIGER 리츠부동산인프라      KR  RealEstate     long    True
# 23  332610              ARIRANG 미국단기우량회사채      US        bond     long    True
# 24  334690                KBSTAR 팔라듐선물(H)  Global   commodity     long    True
# 25  360750                KBSTAR Fn수소경제테마      KR      sector     long    True
# 26  371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector     long    True
# 27  371460          TIGER 차이나전기차SOLACTIVE      CN      sector     long    True
# 28  373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index    short    True
# 29  373790              KOSEF 미국방어배당성장나스닥      US      sector     long    True
# 30  394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector     long    True
# 31  409810         KODEX 미국나스닥100선물인버스(H)      US       index    short    True
# 32  411420             KODEX 미국메타버스나스닥액티브      US      sector     long    True
# 33  500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity     long    True
# 34  500058     신한 S&P500 VIX S/T 선물 ETN C      US       index   option    True
# 35  510004             대신 인버스 아연선물 ETN(H)  Global   commodity    short    True
# 36  510006             대신 인버스 니켈선물 ETN(H)  Global   commodity    short    True
# 37  510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity    short    True
# 38  530020               삼성 미국 대형 가치주 ETN      US      sector     long    True
# 39  570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index   option    True
# 40  590018             미래에셋 중국 심천 100 ETN      CN      sector     long    True

# %%
daydelta = 360   # 조회될 기간 설정. 일 기준
today = datetime.today()

start = (today + timedelta(days= -1 * daydelta)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

print('---------------------------------------------')
print('최근', daydelta, '일 데이터 조회', '- MA 20d, 50d')
print('---------------------------------------------')
print()

l_perf = []
for i, row in ticker.sort_values(['TYPE', 'MARKET', 'POSITION']).iterrows():
    try:
        if row.MONITOR:
            data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
            data = data / data.iloc[0] * 100
            cmean = int(data.Close.mean()) - 100
            cmax = int(data.Close.max())
            cmin = int(data.Close.min())
            rng = cmax - cmin
            cpv = int(data.Close[-1])
            l_perf.append([row.TICKER, row.NAME, row.MARKET, row.TYPE, cmean, cmax, cmin, rng, cpv])
            
            print('**', row.NAME, '**')
            print('Ticker  :', row.TICKER)
            print('Market  :', row.MARKET)
            print('Type    :', row.TYPE)
            print('MEAN +/-:', cmean, '%')
            print('MAX/MIN :', cmax, '/', cmin)
            print('RANGE.  :', rng)
            print('PV      :', cpv)
            fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, mav=(20, 50))

        # Annotation
#         for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
#             if data.index[0] < pd.to_datetime(prow.DATE):
#                 x = data.reset_index().index[data.index == prow.DATE].item()
# #                 y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
#                 cap = str(prow.CAP * -1)
#                 stocks = str(prow.STOCKS)
#                 sb = 'SELL' if prow.SELL else 'BUY'
#                 axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
            plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
    
performance = pd.DataFrame(data= l_perf, columns= ['TICKER', 'NAME', 'MARKET', 'TYPE', 'MEAN+/-', 'MAX', 'MIN', 'RNG', 'PV'])
performance.set_index(['TICKER'], inplace= True)
# Out:
# ---------------------------------------------
# 최근 360 일 데이터 조회 - MA 20d, 50d
# ---------------------------------------------
#
# ** TIGER 리츠부동산인프라 **
# Ticker  : 329200
# Market  : KR
# Type    : RealEstate
# MEAN +/-: 2 %
# MAX/MIN : 113 / 89
# RANGE.  : 24
# PV      : 89
# ** ARIRANG 미국단기우량회사채 **
# Ticker  : 332610
# Market  : US
# Type    : bond
# MEAN +/-: 2 %
# MAX/MIN : 114 / 97
# RANGE.  : 17
# PV      : 111
# ** TIGER 골드선물(H) **
# Ticker  : 319640
# Market  : Global
# Type    : commodity
# MEAN +/-: 2 %
# MAX/MIN : 113 / 91
# RANGE.  : 22
# PV      : 96
# ** KBSTAR 팔라듐선물(H) **
# Ticker  : 334690
# Market  : Global
# Type    : commodity
# MEAN +/-: -1 %
# MAX/MIN : 148 / 77
# RANGE.  : 71
# PV      : 104
# ** 신한 인버스 옥수수 선물 ETN(H) **
# Ticker  : 500014
# Market  : Global
# Type    : commodity
# MEAN +/-: -22 %
# MAX/MIN : 103 / 63
# RANGE.  : 40
# PV      : 69
# ** 대신 인버스 아연선물 ETN(H) **
# Ticker  : 510004
# Market  : Global
# Type    : commodity
# MEAN +/-: -15 %
# MAX/MIN : 101 / 61
# RANGE.  : 40
# PV      : 90
# ** 대신 인버스 니켈선물 ETN(H) **
# Ticker  : 510006
# Market  : Global
# Type    : commodity
# MEAN +/-: -43 %
# MAX/MIN : 100 / 26
# RANGE.  : 74
# PV      : 34
# ** 대신 인버스 알루미늄 선물 ETN(H) **
# Ticker  : 510018
# Market  : Global
# Type    : commodity
# MEAN +/-: -8 %
# MAX/MIN : 120 / 64
# RANGE.  : 56
# PV      : 104
# ** KODEX 미국S&P에너지(합성) **
# Ticker  : 218420
# Market  : US
# Type    : commodity
# MEAN +/-: 29 %
# MAX/MIN : 173 / 92
# RANGE.  : 81
# PV      : 164
# ** KBSTAR 미국S&P원유생산기업(합성 H) **
# Ticker  : 219390
# Market  : US
# Type    : commodity
# MEAN +/-: 19 %
# MAX/MIN : 167 / 89
# RANGE.  : 78
# PV      : 137
# ** KODEX 차이나A50 **
# Ticker  : 169950
# Market  : Global
# Type    : index
# MEAN +/-: -7 %
# MAX/MIN : 105 / 83
# RANGE.  : 22
# PV      : 89
# ** ARIRANG 신흥국MSCI(합성 H) **
# Ticker  : 195980
# Market  : Global
# Type    : index
# MEAN +/-: -13 %
# MAX/MIN : 103 / 68
# RANGE.  : 35
# PV      : 71
# ** KOSEF 인도Nifty50(합성) **
# Ticker  : 200250
# Market  : Global
# Type    : index
# MEAN +/-: -4 %
# MAX/MIN : 107 / 85
# RANGE.  : 22
# PV      : 102
# ** KINDEX 인도네시아MSCI(합성) **
# Ticker  : 256440
# Market  : Global
# Type    : index
# MEAN +/-: 5 %
# MAX/MIN : 126 / 95
# RANGE.  : 31
# PV      : 120
# ** ARIRANG 신흥국MSCI인버스(합성 H) **
# Ticker  : 373530
# Market  : Global
# Type    : index
# MEAN +/-: 8 %
# MAX/MIN : 133 / 95
# RANGE.  : 38
# PV      : 126
# ** TIGER 일본니케이225 **
# Ticker  : 241180
# Market  : JP
# Type    : index
# MEAN +/-: -7 %
# MAX/MIN : 103 / 83
# RANGE.  : 20
# PV      : 89
# ** KODEX 200 **
# Ticker  : 069500
# Market  : KR
# Type    : index
# MEAN +/-: -7 %
# MAX/MIN : 105 / 75
# RANGE.  : 30
# PV      : 78
# ** TIGER 미국나스닥100 **
# Ticker  : 133690
# Market  : US
# Type    : index
# MEAN +/-: -2 %
# MAX/MIN : 112 / 82
# RANGE.  : 30
# PV      : 92
# ** 신한 S&P500 VIX S/T 선물 ETN C **
# Ticker  : 500058
# Market  : US
# Type    : index
# MEAN +/-: -14 %
# MAX/MIN : 119 / 69
# RANGE.  : 50
# PV      : 87
# ** TRUE S&P500 양매도 4% OTM ETN(H) **
# Ticker  : 570049
# Market  : US
# Type    : index
# MEAN +/-: 2 %
# MAX/MIN : 107 / 96
# RANGE.  : 11
# PV      : 98
# ** KODEX 미국나스닥100선물인버스(H) **
# Ticker  : 409810
# Market  : US
# Type    : index
# MEAN +/-: 18 %
# MAX/MIN : 137 / 98
# RANGE.  : 39
# PV      : 131
# ** TIGER 차이나전기차SOLACTIVE **
# Ticker  : 371460
# Market  : CN
# Type    : sector
# MEAN +/-: -5 %
# MAX/MIN : 121 / 64
# RANGE.  : 57
# PV      : 82
# ** 미래에셋 중국 심천 100 ETN **
# Ticker  : 590018
# Market  : CN
# Type    : sector
# MEAN +/-: -9 %
# MAX/MIN : 105 / 74
# RANGE.  : 31
# PV      : 78
# ** KOSEF 릭소글로벌퓨처모빌리티MSCI **
# Ticker  : 394350
# Market  : Global
# Type    : sector
# MEAN +/-: -1 %
# MAX/MIN : 119 / 84
# RANGE.  : 35
# PV      : 92
# ** TIGER 경기방어 **
# Ticker  : 139280
# Market  : KR
# Type    : sector
# MEAN +/-: -10 %
# MAX/MIN : 103 / 79
# RANGE.  : 24
# PV      : 80
# ** TIGER 소프트웨어 **
# Ticker  : 157490
# Market  : KR
# Type    : sector
# MEAN +/-: -16 %
# MAX/MIN : 117 / 52
# RANGE.  : 65
# PV      : 53
# ** KODEX 필수소비재 **
# Ticker  : 266410
# Market  : KR
# Type    : sector
# MEAN +/-: -11 %
# MAX/MIN : 104 / 77
# RANGE.  : 27
# PV      : 78
# ** TIGER 2차전지테마 **
# Ticker  : 305540
# Market  : KR
# Type    : sector
# MEAN +/-: -9 %
# MAX/MIN : 110 / 72
# RANGE.  : 38
# PV      : 78
# ** KBSTAR Fn수소경제테마 **
# Ticker  : 360750
# Market  : KR
# Type    : sector
# MEAN +/-: 3 %
# MAX/MIN : 110 / 91
# RANGE.  : 19
# PV      : 103
# ** TIGER S&P글로벌인프라(합성) **
# Ticker  : 269370
# Market  : US
# Type    : sector
# MEAN +/-: 8 %
# MAX/MIN : 122 / 95
# RANGE.  : 27
# PV      : 110
# ** KINDEX 미국WideMoat가치주 **
# Ticker  : 309230
# Market  : US
# Type    : sector
# MEAN +/-: 0 %
# MAX/MIN : 109 / 89
# RANGE.  : 20
# PV      : 101
# ** TIGER 글로벌클라우드컴퓨팅INDXX **
# Ticker  : 371450
# Market  : US
# Type    : sector
# MEAN +/-: -22 %
# MAX/MIN : 109 / 59
# RANGE.  : 50
# PV      : 70
# ** KOSEF 미국방어배당성장나스닥 **
# Ticker  : 373790
# Market  : US
# Type    : sector
# MEAN +/-: 11 %
# MAX/MIN : 126 / 99
# RANGE.  : 27
# PV      : 117
# ** KODEX 미국메타버스나스닥액티브 **
# Ticker  : 411420
# Market  : US
# Type    : sector
# MEAN +/-: -24 %
# MAX/MIN : 103 / 62
# RANGE.  : 41
# PV      : 69
# ** 삼성 미국 대형 가치주 ETN **
# Ticker  : 530020
# Market  : US
# Type    : sector
# MEAN +/-: 7 %
# MAX/MIN : 118 / 94
# RANGE.  : 24
# PV      : 112
# ** 삼성전자 **
# Ticker  : 005930
# Market  : KR
# Type    : stock
# MEAN +/-: -3 %
# MAX/MIN : 116 / 76
# RANGE.  : 40
# PV      : 81
# ** SK하이닉스 **
# Ticker  : 000660
# Market  : KR
# Type    : stock
# MEAN +/-: 18 %
# MAX/MIN : 145 / 88
# RANGE.  : 57
# PV      : 98
# ** NAVER **
# Ticker  : 035420
# Market  : KR
# Type    : stock
# MEAN +/-: -18 %
# MAX/MIN : 112 / 44
# RANGE.  : 68
# PV      : 44
# ** 맥쿼리인프라 **
# Ticker  : 088980
# Market  : KR
# Type    : stock
# MEAN +/-: 3 %
# MAX/MIN : 110 / 89
# RANGE.  : 21
# PV      : 91

# %%
performance.sort_values(by= ['PV'], ascending= True)
# Out:
#                                  NAME  MARKET        TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006             대신 인버스 니켈선물 ETN(H)  Global   commodity      -43  100   26
# 035420                          NAVER      KR       stock      -18  112   44
# 157490                    TIGER 소프트웨어      KR      sector      -16  117   52
# 411420             KODEX 미국메타버스나스닥액티브      US      sector      -24  103   62
# 500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity      -22  103   63
# 371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector      -22  109   59
# 195980          ARIRANG 신흥국MSCI(합성 H)  Global       index      -13  103   68
# 069500                      KODEX 200      KR       index       -7  105   75
# 305540                   TIGER 2차전지테마      KR      sector       -9  110   72
# 266410                    KODEX 필수소비재      KR      sector      -11  104   77
# 590018             미래에셋 중국 심천 100 ETN      CN      sector       -9  105   74
# 139280                     TIGER 경기방어      KR      sector      -10  103   79
# 005930                           삼성전자      KR       stock       -3  116   76
# 371460          TIGER 차이나전기차SOLACTIVE      CN      sector       -5  121   64
# 500058     신한 S&P500 VIX S/T 선물 ETN C      US       index      -14  119   69
# 241180                 TIGER 일본니케이225      JP       index       -7  103   83
# 169950                   KODEX 차이나A50  Global       index       -7  105   83
# 329200                 TIGER 리츠부동산인프라      KR  RealEstate        2  113   89
# 510004             대신 인버스 아연선물 ETN(H)  Global   commodity      -15  101   61
# 088980                         맥쿼리인프라      KR       stock        3  110   89
# 394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector       -1  119   84
# 133690                 TIGER 미국나스닥100      US       index       -2  112   82
# 319640                  TIGER 골드선물(H)  Global   commodity        2  113   91
# 570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index        2  107   96
# 000660                         SK하이닉스      KR       stock       18  145   88
# 309230           KINDEX 미국WideMoat가치주      US      sector        0  109   89
# 200250            KOSEF 인도Nifty50(합성)  Global       index       -4  107   85
# 360750                KBSTAR Fn수소경제테마      KR      sector        3  110   91
# 334690                KBSTAR 팔라듐선물(H)  Global   commodity       -1  148   77
# 510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity       -8  120   64
# 269370            TIGER S&P글로벌인프라(합성)      US      sector        8  122   95
# 332610              ARIRANG 미국단기우량회사채      US        bond        2  114   97
# 530020               삼성 미국 대형 가치주 ETN      US      sector        7  118   94
# 373790              KOSEF 미국방어배당성장나스닥      US      sector       11  126   99
# 256440           KINDEX 인도네시아MSCI(합성)  Global       index        5  126   95
# 373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index        8  133   95
# 409810         KODEX 미국나스닥100선물인버스(H)      US       index       18  137   98
# 219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity       19  167   89
# 218420             KODEX 미국S&P에너지(합성)      US   commodity       29  173   92
#
#         RNG   PV
# TICKER
# 510006   74   34
# 035420   68   44
# 157490   65   53
# 411420   41   69
# 500014   40   69
# 371450   50   70
# 195980   35   71
# 069500   30   78
# 305540   38   78
# 266410   27   78
# 590018   31   78
# 139280   24   80
# 005930   40   81
# 371460   57   82
# 500058   50   87
# 241180   20   89
# 169950   22   89
# 329200   24   89
# 510004   40   90
# 088980   21   91
# 394350   35   92
# 133690   30   92
# 319640   22   96
# 570049   11   98
# 000660   57   98
# 309230   20  101
# 200250   22  102
# 360750   19  103
# 334690   71  104
# 510018   56  104
# 269370   27  110
# 332610   17  111
# 530020   24  112
# 373790   27  117
# 256440   31  120
# 373530   38  126
# 409810   39  131
# 219390   78  137
# 218420   81  164

# %%
performance.sort_values(by= ['RNG'], ascending= True)
# Out:
#                                  NAME  MARKET        TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index        2  107   96
# 332610              ARIRANG 미국단기우량회사채      US        bond        2  114   97
# 360750                KBSTAR Fn수소경제테마      KR      sector        3  110   91
# 309230           KINDEX 미국WideMoat가치주      US      sector        0  109   89
# 241180                 TIGER 일본니케이225      JP       index       -7  103   83
# 088980                         맥쿼리인프라      KR       stock        3  110   89
# 319640                  TIGER 골드선물(H)  Global   commodity        2  113   91
# 169950                   KODEX 차이나A50  Global       index       -7  105   83
# 200250            KOSEF 인도Nifty50(합성)  Global       index       -4  107   85
# 329200                 TIGER 리츠부동산인프라      KR  RealEstate        2  113   89
# 530020               삼성 미국 대형 가치주 ETN      US      sector        7  118   94
# 139280                     TIGER 경기방어      KR      sector      -10  103   79
# 373790              KOSEF 미국방어배당성장나스닥      US      sector       11  126   99
# 269370            TIGER S&P글로벌인프라(합성)      US      sector        8  122   95
# 266410                    KODEX 필수소비재      KR      sector      -11  104   77
# 133690                 TIGER 미국나스닥100      US       index       -2  112   82
# 069500                      KODEX 200      KR       index       -7  105   75
# 590018             미래에셋 중국 심천 100 ETN      CN      sector       -9  105   74
# 256440           KINDEX 인도네시아MSCI(합성)  Global       index        5  126   95
# 394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector       -1  119   84
# 195980          ARIRANG 신흥국MSCI(합성 H)  Global       index      -13  103   68
# 373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index        8  133   95
# 305540                   TIGER 2차전지테마      KR      sector       -9  110   72
# 409810         KODEX 미국나스닥100선물인버스(H)      US       index       18  137   98
# 005930                           삼성전자      KR       stock       -3  116   76
# 510004             대신 인버스 아연선물 ETN(H)  Global   commodity      -15  101   61
# 500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity      -22  103   63
# 411420             KODEX 미국메타버스나스닥액티브      US      sector      -24  103   62
# 371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector      -22  109   59
# 500058     신한 S&P500 VIX S/T 선물 ETN C      US       index      -14  119   69
# 510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity       -8  120   64
# 000660                         SK하이닉스      KR       stock       18  145   88
# 371460          TIGER 차이나전기차SOLACTIVE      CN      sector       -5  121   64
# 157490                    TIGER 소프트웨어      KR      sector      -16  117   52
# 035420                          NAVER      KR       stock      -18  112   44
# 334690                KBSTAR 팔라듐선물(H)  Global   commodity       -1  148   77
# 510006             대신 인버스 니켈선물 ETN(H)  Global   commodity      -43  100   26
# 219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity       19  167   89
# 218420             KODEX 미국S&P에너지(합성)      US   commodity       29  173   92
#
#         RNG   PV
# TICKER
# 570049   11   98
# 332610   17  111
# 360750   19  103
# 309230   20  101
# 241180   20   89
# 088980   21   91
# 319640   22   96
# 169950   22   89
# 200250   22  102
# 329200   24   89
# 530020   24  112
# 139280   24   80
# 373790   27  117
# 269370   27  110
# 266410   27   78
# 133690   30   92
# 069500   30   78
# 590018   31   78
# 256440   31  120
# 394350   35   92
# 195980   35   71
# 373530   38  126
# 305540   38   78
# 409810   39  131
# 005930   40   81
# 510004   40   90
# 500014   40   69
# 411420   41   69
# 371450   50   70
# 500058   50   87
# 510018   56  104
# 000660   57   98
# 371460   57   82
# 157490   65   53
# 035420   68   44
# 334690   71  104
# 510006   74   34
# 219390   78  137
# 218420   81  164

# %%
performance.sort_values(by= ['MIN'], ascending= True)
# Out:
#                                  NAME  MARKET        TYPE  MEAN+/-  MAX  MIN  \
# TICKER
# 510006             대신 인버스 니켈선물 ETN(H)  Global   commodity      -43  100   26
# 035420                          NAVER      KR       stock      -18  112   44
# 157490                    TIGER 소프트웨어      KR      sector      -16  117   52
# 371450          TIGER 글로벌클라우드컴퓨팅INDXX      US      sector      -22  109   59
# 510004             대신 인버스 아연선물 ETN(H)  Global   commodity      -15  101   61
# 411420             KODEX 미국메타버스나스닥액티브      US      sector      -24  103   62
# 500014           신한 인버스 옥수수 선물 ETN(H)  Global   commodity      -22  103   63
# 371460          TIGER 차이나전기차SOLACTIVE      CN      sector       -5  121   64
# 510018          대신 인버스 알루미늄 선물 ETN(H)  Global   commodity       -8  120   64
# 195980          ARIRANG 신흥국MSCI(합성 H)  Global       index      -13  103   68
# 500058     신한 S&P500 VIX S/T 선물 ETN C      US       index      -14  119   69
# 305540                   TIGER 2차전지테마      KR      sector       -9  110   72
# 590018             미래에셋 중국 심천 100 ETN      CN      sector       -9  105   74
# 069500                      KODEX 200      KR       index       -7  105   75
# 005930                           삼성전자      KR       stock       -3  116   76
# 334690                KBSTAR 팔라듐선물(H)  Global   commodity       -1  148   77
# 266410                    KODEX 필수소비재      KR      sector      -11  104   77
# 139280                     TIGER 경기방어      KR      sector      -10  103   79
# 133690                 TIGER 미국나스닥100      US       index       -2  112   82
# 241180                 TIGER 일본니케이225      JP       index       -7  103   83
# 169950                   KODEX 차이나A50  Global       index       -7  105   83
# 394350          KOSEF 릭소글로벌퓨처모빌리티MSCI  Global      sector       -1  119   84
# 200250            KOSEF 인도Nifty50(합성)  Global       index       -4  107   85
# 000660                         SK하이닉스      KR       stock       18  145   88
# 309230           KINDEX 미국WideMoat가치주      US      sector        0  109   89
# 329200                 TIGER 리츠부동산인프라      KR  RealEstate        2  113   89
# 088980                         맥쿼리인프라      KR       stock        3  110   89
# 219390       KBSTAR 미국S&P원유생산기업(합성 H)      US   commodity       19  167   89
# 360750                KBSTAR Fn수소경제테마      KR      sector        3  110   91
# 319640                  TIGER 골드선물(H)  Global   commodity        2  113   91
# 218420             KODEX 미국S&P에너지(합성)      US   commodity       29  173   92
# 530020               삼성 미국 대형 가치주 ETN      US      sector        7  118   94
# 373530       ARIRANG 신흥국MSCI인버스(합성 H)  Global       index        8  133   95
# 269370            TIGER S&P글로벌인프라(합성)      US      sector        8  122   95
# 256440           KINDEX 인도네시아MSCI(합성)  Global       index        5  126   95
# 570049  TRUE S&P500 양매도 4% OTM ETN(H)      US       index        2  107   96
# 332610              ARIRANG 미국단기우량회사채      US        bond        2  114   97
# 409810         KODEX 미국나스닥100선물인버스(H)      US       index       18  137   98
# 373790              KOSEF 미국방어배당성장나스닥      US      sector       11  126   99
#
#         RNG   PV
# TICKER
# 510006   74   34
# 035420   68   44
# 157490   65   53
# 371450   50   70
# 510004   40   90
# 411420   41   69
# 500014   40   69
# 371460   57   82
# 510018   56  104
# 195980   35   71
# 500058   50   87
# 305540   38   78
# 590018   31   78
# 069500   30   78
# 005930   40   81
# 334690   71  104
# 266410   27   78
# 139280   24   80
# 133690   30   92
# 241180   20   89
# 169950   22   89
# 394350   35   92
# 200250   22  102
# 000660   57   98
# 309230   20  101
# 329200   24   89
# 088980   21   91
# 219390   78  137
# 360750   19  103
# 319640   22   96
# 218420   81  164
# 530020   24  112
# 373530   38  126
# 269370   27  110
# 256440   31  120
# 570049   11   98
# 332610   17  111
# 409810   39  131
# 373790   27  117
