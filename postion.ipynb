# %% [markdown]
# ## Input and Preparation

# %%
### 매주 입력 필요

# 투자금 변화 입력
list_capital = [
    ['2021-12-10', 1500000, 2000000, 0, 17100000, 0],
    ['2022-03-21', 1500000, 2000000, 750000, 17100000, 0],
    ['2022-04-21', 1500000, 2000000, 1000000, 17100000, 0], 
    ['2022-05-11', 1500000, 2000000, 1000000, 17100000, 51411787], 
    ['2022-05-14', 2000000, 2000000, 1000000, 17100000, 51411787],
    ['2022-05-21', 2000000, 2000000, 1250000, 17100000, 51853487],
    ['2022-06-21', 2000000, 2000000, 1500000, 17100000, 52295187]
]

# 주차별 자산평가액 입력
list_eva = [
    ['2021-12-10', 1500000, 2000000, 0, 17100000, 0],
    ['2022-04-01', 1320963, 1815919, 745075, 17169766, 0],
    ['2022-04-08', 1328128, 1824105, 739964, 17110423, 0],
    ['2022-04-20', 1306232, 1843025, 734283, 17122584, 0],
    ['2022-04-26', 1300044, 1825530, 974443, 16710626, 0],
    ['2022-05-04', 1297685, 1810670, 973821, 16818596, 0],
    ['2022-05-11', 1280706, 1787935, 963967, 16557094, 51411787],
    ['2022-05-18', 1747918, 1792125, 963923, 16606513, 51853487],
    ['2022-05-25', 1803813, 1768880, 1203089, 16567673, 51853487],
    ['2022-06-01', 1719094, 1759435, 1218145, 16809988, 51853487],
    ['2022-06-08', 1720456, 1767500, 1215795, 16921678, 51853487],
    ['2022-06-15', 1894061, 1843039, 1199774, 16718468, 51853487],
    ['2022-06-22', 1860821, 1763385, 1446383, 16483969, 52295187]
]

# 종목 정보 - 신규 종목 매수 시, 별도 지정 필요
ticker = {
    '005930': ['삼성전자', 'KR', 'STOCK'],
    '000660': ['SK하이닉스',  'KR',  'STOCK'],
    '035420': ['NAVER',  'KR',  'STOCK'],
    '069500': ['KODEX 200',  'KR',  'ETF'],
    '088980': ['맥쿼리인프라',  'KR',  'STOCK'],
    '123310': ['TIGER 인버스',  'KR',  'ETF'],
    '133690': ['TIGER 미국나스닥100',  'US',  'ETF'],
    '139280': ['TIGER 경기방어',  'KR',  'ETF'],
    '157490': ['TIGER 소프트웨어',  'KR',  'ETF'],
    '195980': ['ARIRANG 신흥국MSCI(합성 H)',  'Global',  'ETF'],
    '218420': ['KODEX 미국S&P에너지(합성)', 'US', 'Commodity'],
    '219390': ['KBSTAR 미국S&P원유생산기업(합성 H)',  'US',  'Commodity'],
    '266410': ['KODEX 필수소비재',  'KR',  'ETF'],
    '271050': ['KODEX WTI원유선물인버스(H)',  'Global',  'Commodity'],
    '319640': ['TIGER 골드선물(H)',  'Global',  'Commodity'],
    '329200': ['TIGER 리츠부동산인프라', 'KR', 'RealEstate'],
    '334690': ['KBSTAR 팔라듐선물(H)',  'Global',  'Commodity'],
    '332610': ['ARIRANG 미국단기우량회사채',  'US',  'Bond'],
    '360750': ['TIGER 미국S&P500',  'US',  'ETF'],
    '371450': ['TIGER 글로벌클라우드컴퓨팅INDXX',  'US',  'ETF'],
    '371460': ['TIGER 차이나전기차SOLACTIVE',  'CN',  'ETF'],
    '373790': ['KOSEF 미국방어배당성장나스닥',  'US',  'ETF'],
    '394350': ['KOSEF 릭소글로벌퓨처모빌리티MSCI',  'Global',  'ETF'],
    '409810': ['KODEX 미국나스닥100선물인버스(H)',  'US',  'ETF'],
    '411420': ['KODEX 미국메타버스나스닥액티브',  'US',  'ETF'],
    '500058': ['신한 S&P500 VIX S/T 선물 ETN C', 'US', 'ETF'],
    '510006': ['대신 인버스 니켈선물 ETN(H)',  'Global',  'Commodity'],
    '530020': ['삼성 미국 대형 가치주 ETN',  'US',  'ETF'],
    '570049': ['TRUE S&P500 양매도 4% OTM ETN(H)',  'US',  'ETF'],
    '590018': ['미래에셋 중국 심천 100 ETN',  'CN',  'ETF']
}

# 일자, Ticker, 주식수, 체결가격, Bank account
# Price: 매수+, 매도-
actions = [
    ['2021-12-13', '005930', 1, 77100, '14'],
    ['2021-12-13', '069500', 2, 40027, '14'],
    ['2020-12-13', '360750', 7, 14028, '14'],
    ['2021-12-21', '005930', 2, 78200, '14'],
    ['2021-12-22', '000660', 1, 128500, '14'],
    ['2021-12-22', '005930', 2, 79100, '14'],
    ['2021-12-22', '035420', 1, 378000, '14'],
    ['2021-12-23', '088980', 7, 14150, '14'],
    ['2021-12-23', '133690', 3, 86165, '01'],
    ['2021-12-24', '005930', 2, 80800, '14'],
    ['2021-12-24', '133690', 3, 86600, '01'],
    ['2021-12-24', '360750', 15, 14125, '01'],
    ['2022-01-03', '411420', 20, 10150, '01'],
    ['2022-01-04', '530020', 9, 17512, '14'],
    ['2022-01-06', '133690', 5, 84920, '14'],
    ['2022-01-06', '530020', 7, 17870, '14'],
    ['2022-01-06', '590018', 15, 20085, '14'],
    ['2022-01-06', '360750', 14, 14215, '14'],
    ['2022-01-06', '005930', -7, 77500, '14'],
    ['2022-01-06', '035420', -1, 346000, '14'],
    ['2022-01-06', '069500', -2, 39435, '14'],
    ['2022-01-06', '088980', -7, 13800, '14'],
    ['2022-01-24', '334690', 19, 12090, '01'],
    ['2022-01-24', '411420', -20, 8475, '01'],
    ['2022-01-28', '510006', 53, 3820, '01'],
    ['2022-01-28', '000660', -1, 119500, '14'],
    ['2022-02-14', '409810', 41, 11230, '01'],
    ['2022-02-14', '133690', -6, 76300, '01'],
    ['2022-02-15', '271050', 17, 5835, '01'],
    ['2022-02-24', '510006', -53, 3360, '01'],
    ['2022-02-24', '360750', -15, 12535, '01'],
    ['2022-02-24', '133690', -5, 70930, '14'],
    ['2022-02-24', '360750', -21, 12552, '14'],
    ['2022-03-04', '195980', 11, 11045, '29'],
    ['2022-03-04', '360750', 9, 13225, '29'],
    ['2022-03-07', '271050', 95, 4249, '14'],
    ['2022-03-10', '334690', -19, 16735, '01'],
    ['2022-03-14', '319640', 14, 14270, '14'],
    ['2022-03-14', '570049', 17, 11670, '14'],
    ['2022-03-14', '123310', 20, 4895, '01'],
    ['2022-03-14', '219390', 180, 5545, '28'],
    ['2022-03-14', '332610', 10, 102840, '28'],
    ['2022-03-14', '373790', 77, 12950, '28'],
    ['2022-03-16', '590018', -15, 16243, '14'],
    ['2022-03-16', '195980', -11, 9865, '29'],
    ['2022-03-23', '123310', -19, 4770, '01'],
    ['2022-03-23', '271050', -94, 4450, '14'],
    ['2022-03-23', '266410', 127, 7910, '28'],
    ['2022-03-30', '409810', -40, 10390, '01'],
    ['2022-03-30', '570049', 25, 11715, '14'],
    ['2022-03-30', '360750', 9, 14115, '29'],
    ['2022-03-30', '133690', 1, 82580, '29'],
    ['2022-03-30', '139280', 99, 10130, '28'],
    ['2022-03-30', '371450', 101, 9900, '28'],
    ['2022-03-30', '157490', 70, 14325, '28'],
    ['2022-03-30', '394350', 91, 10984, '28'],
    ['2022-03-30', '371460', 68, 14720, '28'],
    ['2022-04-21', '329200', 154, 6495, '28'],
    ['2022-04-29', '570049', 42, 11865, '14'],
    ['2022-05-12', '394350', -82, 9360, '28'],
    ['2022-05-12', '371450', -101, 7830, '28'],
    ['2022-05-17', '409810', 80, 12580, '01'],
    ['2022-06-09', '500058', 24, 8550, '01'],
    ['2022-06-09', '500058', 35, 8560, '14'],
    ['2022-06-13', '570049', -84, 11540, '14'],
    ['2022-06-15', '218420', 40, 12555, '14'],
    ['2022-06-15', '530020', 17, 17775, '14'],
    ['2022-06-15', '271050', -17, 3860, '01'],
    ['2022-06-21', '500058', -24, 10045, '01'],
    ['2022-06-21', '409810', -44, 13460, '01'],
    ['2022-06-21', '500058', -35, 10045, '14']   
]

# %%
# Bank Account
account = {
    '01': 'FR',
    '14': 'SA',
    '29': 'RP',
    '28': 'DC',
    'MA': 'MA'
}

# %%
# Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
# capital, eva 데이터프레임 생성
def define_cap(caplist, total):
    df = pd.DataFrame(caplist, columns= ['DATE'] + list(account.values()))
    df.DATE = pd.to_datetime(df.DATE)
    df.set_index(['DATE'], inplace= True)
    df[total] = df.loc[:, df.columns!='EVENT'].sum(axis=1)
    return df

# 개별 계정에 대해 자본 대비 평가액 변화 확인
def cap_change(account_col):
    account_cap = capital[account_col][-1]
    account_eva = eva[account_col][-1]
    account_del = account_eva - account_cap
    return [account_cap, account_eva, account_del, account_del / account_cap * 100]    

# ticker로 해당 종목 이름열인 'NAME'을 생성 - 별도 반환없이 바로 지정된 df에 생성
def tcknaming(df):
  df['NAME'] = df.TICKER.map(lambda x: ticker[x][0])

# %% [markdown]
# ## Capital

# %%
# 투자금 현황
# list_capital = pd.read_excel('position.xlsx', sheet_name='capital')

capital = define_cap(list_capital, 'CAP')
capital['DELTA'] = capital.CAP.diff()

capital.style.format("{:,.0f}")
capital
# Out:
#                  FR       SA       RP        DC        MA       CAP  \
# DATE
# 2021-12-10  1500000  2000000        0  17100000         0  20600000
# 2022-03-21  1500000  2000000   750000  17100000         0  21350000
# 2022-04-21  1500000  2000000  1000000  17100000         0  21600000
# 2022-05-11  1500000  2000000  1000000  17100000  51411787  73011787
# 2022-05-14  2000000  2000000  1000000  17100000  51411787  73511787
# 2022-05-21  2000000  2000000  1250000  17100000  51853487  74203487
# 2022-06-21  2000000  2000000  1500000  17100000  52295187  74895187
#
#                  DELTA
# DATE
# 2021-12-10         NaN
# 2022-03-21    750000.0
# 2022-04-21    250000.0
# 2022-05-11  51411787.0
# 2022-05-14    500000.0
# 2022-05-21    691700.0
# 2022-06-21    691700.0

# %%
capital[list(account.values())].plot(kind='bar', stacked=True, figsize=(12, 3), title= "Total Capital - Won")

# %%
# 100만원 이하 자산변화에 대한 라인 그래프 생성
capital.DELTA[capital.DELTA < 1000000].plot(kind='line', marker='o', figsize= (12, 3), title = 'Capital Change - Won')

# %% [markdown]
# ## Evaluation

# %%
# 입력된 값으로 1) df 생성, 2) capital 내 CAP열 값과 Join, 3) front fill로 없는 행 생성, 4) 불필요 행 삭제
eva = define_cap(list_eva, 'EVA').join(capital.CAP, how= 'outer', sort= True)
eva.CAP = eva.CAP.fillna(method= 'ffill')
eva.dropna(inplace= True)
eva = eva.astype('int')

eva['PROFIT'] = eva.EVA - eva.CAP
eva['PROFIT%'] = eva.PROFIT / eva.CAP * 100

eva.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_e61b5566_f202_11ec_b549_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FR</th>        <th class="col_heading level0 col1" >SA</th>        <th class="col_heading level0 col2" >RP</th>        <th class="col_heading level0 col3" >DC</th>        <th class="col_heading level0 col4" >MA</th>        <th class="col_heading level0 col5" >EVA</th>        <th class="col_heading level0 col6" >CAP</th>        <th class="col_heading level0 col7" >PROFIT</th>        <th class="col_heading level0 col8" >PROFIT%</th>    </tr>    <tr>        <th class="index_name level0" >DATE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e61b5566_f202_11ec_b549_784f438ec1c5level0_row0" class="row_heading level0 row0" >2021-12-10 00:00:00</th>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col0" class="data row0 col0" >1,500,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col1" class="data row0 col1" >2,000,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col3" class="data row0 col3" >17,100,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col5" class="data row0 col5" >20,600,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col6" class="data row0 col6" >20,600,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row0_col8" class="data row0 col8" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_e61b5566_f202_11ec_b549_784f438ec1c5level0_row1" class="row_heading level0 row1" >2022-04-01 00:00:00</th>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col0" class="data row1 col0" >1,320,963</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col1" class="data row1 col1" >1,815,919</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col2" class="data row1 col2" >745,075</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col3" class="data row1 col3" >17,169,766</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col5" class="data row1 col5" >21,051,723</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col6" class="data row1 col6" >21,350,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col7" class="data row1 col7" >-298,277</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row1_col8" class="data row1 col8" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e61b5566_f202_11ec_b549_784f438ec1c5level0_row2" class="row_heading level0 row2" >2022-04-08 00:00:00</th>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col0" class="data row2 col0" >1,328,128</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col1" class="data row2 col1" >1,824,105</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col2" class="data row2 col2" >739,964</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col3" class="data row2 col3" >17,110,423</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col5" class="data row2 col5" >21,002,620</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col6" class="data row2 col6" >21,350,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col7" class="data row2 col7" >-347,380</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row2_col8" class="data row2 col8" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_e61b5566_f202_11ec_b549_784f438ec1c5level0_row3" class="row_heading level0 row3" >2022-04-20 00:00:00</th>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col0" class="data row3 col0" >1,306,232</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col1" class="data row3 col1" >1,843,025</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col2" class="data row3 col2" >734,283</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col3" class="data row3 col3" >17,122,584</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col5" class="data row3 col5" >21,006,124</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col6" class="data row3 col6" >21,350,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col7" class="data row3 col7" >-343,876</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row3_col8" class="data row3 col8" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_e61b5566_f202_11ec_b549_784f438ec1c5level0_row4" class="row_heading level0 row4" >2022-04-26 00:00:00</th>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col0" class="data row4 col0" >1,300,044</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col1" class="data row4 col1" >1,825,530</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col2" class="data row4 col2" >974,443</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col3" class="data row4 col3" >16,710,626</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col5" class="data row4 col5" >20,810,643</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col6" class="data row4 col6" >21,600,000</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col7" class="data row4 col7" >-789,357</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row4_col8" class="data row4 col8" >-4</td>
#             </tr>
#             <tr>
#                         <th id="T_e61b5566_f202_11ec_b549_784f438ec1c5level0_row5" class="row_heading level0 row5" >2022-05-04 00:00:00</th>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row5_col0" class="data row5 col0" >1,297,685</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row5_col1" class="data row5 col1" >1,810,670</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row5_col2" class="data row5 col2" >973,821</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row5_col3" class="data row5 col3" >16,818,596</td>
#                         <td id="T_e61b5566_f202_11ec_b549_784f438ec1c5row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_e61b5566_f202_11ec_b549_7

# %%
print("Latest Position")
print("------------------------------")
print("Capital        ₩", f'{eva.CAP[-1]:,}')
print("Evaluation     ₩", f'{eva.EVA[-1]:,}')
print("Profit         ₩", f'{eva.PROFIT[-1]:,}')
print("Profit%        {:.1f} %".format(eva['PROFIT%'][-1]))
# Out:
# Latest Position
# ------------------------------
# Capital        ₩ 74,895,187
# Evaluation     ₩ 73,849,745
# Profit         ₩ -1,045,442
# Profit%        -1.4 %

# %%
print('EVALUATION BY ACCOUT')
print(' ')
print('Capital    Evaluation    Profit    Profit%    ACC')
print('------------------------------------------------------')
for acc in list(account.values()):
    print('₩', f'{cap_change(acc)[0]:,}', ' ', f'{cap_change(acc)[1]:,}', ' ', f'{cap_change(acc)[2]:,}', ' ',f'{cap_change(acc)[3]:.1f}', '%   ', acc)
# Out:
# EVALUATION BY ACCOUT
#
# Capital    Evaluation    Profit    Profit%    ACC
# ------------------------------------------------------
# ₩ 2,000,000   1,860,821   -139,179   -7.0 %    FR
# ₩ 2,000,000   1,763,385   -236,615   -11.8 %    SA
# ₩ 1,500,000   1,446,383   -53,617   -3.6 %    RP
# ₩ 17,100,000   16,483,969   -616,031   -3.6 %    DC
# ₩ 52,295,187   52,295,187   0   0.0 %    MA

# %%
eva.PROFIT.plot(marker='o', figsize=(12, 3), title = 'PROFIT change - Million ₩')

# %%
eva['PROFIT%'].plot(marker='o', figsize=(12, 3), title = 'PROFIT% change')

# %%
for mycap in account.values():
    eva[mycap].plot(kind='line', marker='o', figsize=(12, 3), title= mycap)
    plt.show()

# %% [markdown]
# ## Evaluation with Benchmark

# %%
# 주요 벤치마크 지표와 Performance 비교
bmticker = {'S&P500': '^GSPC', 'Nasdaq': '^IXIC', 'KOSPI':'^KS11'}
bmdf = pd.DataFrame()

for tk in bmticker:
    tk_yahoo = yf.Ticker(bmticker[tk])
    data = tk_yahoo.history(start= eva.index[0])['Close']
    bmdf[tk] = data
    
bmdf = bmdf.dropna().astype('int32')

evabm = eva[['EVA', 'CAP', 'PROFIT', 'PROFIT%']].join(bmdf, how= 'inner', sort= True)

evabm['BM_SP500'] = evabm['S&P500'] / evabm['S&P500'][0] * 100 - 100
evabm['BM_Nasdaq'] = evabm['Nasdaq'] / evabm['Nasdaq'][0] * 100 - 100
evabm['BM_KOSPI'] = evabm['KOSPI'] / evabm['KOSPI'][0] * 100 - 100

evabm['MY_BM'] = evabm['PROFIT%'] - evabm['PROFIT%'][0]

evabm.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EVA</th>        <th class="col_heading level0 col1" >CAP</th>        <th class="col_heading level0 col2" >PROFIT</th>        <th class="col_heading level0 col3" >PROFIT%</th>        <th class="col_heading level0 col4" >S&P500</th>        <th class="col_heading level0 col5" >Nasdaq</th>        <th class="col_heading level0 col6" >KOSPI</th>        <th class="col_heading level0 col7" >BM_SP500</th>        <th class="col_heading level0 col8" >BM_Nasdaq</th>        <th class="col_heading level0 col9" >BM_KOSPI</th>        <th class="col_heading level0 col10" >MY_BM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5level0_row0" class="row_heading level0 row0" >2021-12-10 00:00:00</th>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col0" class="data row0 col0" >20,600,000</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col1" class="data row0 col1" >20,600,000</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col4" class="data row0 col4" >4,712</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col5" class="data row0 col5" >15,630</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col6" class="data row0 col6" >3,010</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row0_col10" class="data row0 col10" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5level0_row1" class="row_heading level0 row1" >2022-04-01 00:00:00</th>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col0" class="data row1 col0" >21,051,723</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col1" class="data row1 col1" >21,350,000</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col2" class="data row1 col2" >-298,277</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col4" class="data row1 col4" >4,545</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col5" class="data row1 col5" >14,261</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col6" class="data row1 col6" >2,739</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col7" class="data row1 col7" >-4</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col8" class="data row1 col8" >-9</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col9" class="data row1 col9" >-9</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row1_col10" class="data row1 col10" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5level0_row2" class="row_heading level0 row2" >2022-04-08 00:00:00</th>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col0" class="data row2 col0" >21,002,620</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col1" class="data row2 col1" >21,350,000</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col2" class="data row2 col2" >-347,380</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col3" class="data row2 col3" >-2</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col4" class="data row2 col4" >4,488</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col5" class="data row2 col5" >13,711</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col6" class="data row2 col6" >2,700</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col7" class="data row2 col7" >-5</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col8" class="data row2 col8" >-12</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col9" class="data row2 col9" >-10</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row2_col10" class="data row2 col10" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5level0_row3" class="row_heading level0 row3" >2022-04-20 00:00:00</th>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col0" class="data row3 col0" >21,006,124</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col1" class="data row3 col1" >21,350,000</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col2" class="data row3 col2" >-343,876</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col3" class="data row3 col3" >-2</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col4" class="data row3 col4" >4,459</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col5" class="data row3 col5" >13,453</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col6" class="data row3 col6" >2,718</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col7" class="data row3 col7" >-5</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col8" class="data row3 col8" >-14</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col9" class="data row3 col9" >-10</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row3_col10" class="data row3 col10" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5level0_row4" class="row_heading level0 row4" >2022-04-26 00:00:00</th>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col0" class="data row4 col0" >20,810,643</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col1" class="data row4 col1" >21,600,000</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col2" class="data row4 col2" >-789,357</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col3" class="data row4 col3" >-4</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col4" class="data row4 col4" >4,175</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col5" class="data row4 col5" >12,490</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col6" class="data row4 col6" >2,668</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col7" class="data row4 col7" >-11</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col8" class="data row4 col8" >-20</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col9" class="data row4 col9" >-11</td>
#                         <td id="T_2e0d0c02_f203_11ec_b549_784f438ec1c5row4_col10" class

# %%
evabm[['MY_BM', 'BM_SP500', 'BM_Nasdaq', 'BM_KOSPI']].plot(marker='o', figsize=(12, 3))

# %% [markdown]
# ## Trading

# %%
position = pd.DataFrame(actions, columns=['DATE', 'TICKER', 'STOCKS', 'PRICE', 'ACCOUNT'])
# position.set_index('TICKER', inplace= True)

# 총 거래 가격. 현금 유출/유입으로 계산하므로 -1로 부호 반전
position['CAP'] = -1 * position.STOCKS * position.PRICE
# 매도 여부를 Boolean 형태로 별도 열 생성
position['SELL'] = position.STOCKS.apply(lambda x: True if x < 0 else False)

position.tail()
# Out:
#           DATE  TICKER  STOCKS  PRICE ACCOUNT     CAP   SELL
# 66  2022-06-15  530020      17  17775      14 -302175  False
# 67  2022-06-15  271050     -17   3860      01   65620   True
# 68  2022-06-21  500058     -24  10045      01  241080   True
# 69  2022-06-21  409810     -44  13460      01  592240   True
# 70  2022-06-21  500058     -35  10045      14  351575   True

# %%
# 전체 거래횟수
print('Total Transaction:', len(position))
print('    Buy  ', len(position) - position.SELL.sum())
print('    Sell ', position.SELL.sum())
print('  ')

# 거래회전량 계산 - 매도기준

total_buy = position.loc[position.SELL == False, 'CAP'].sum() * -1
rotation_rate_buy = total_buy / eva.CAP[-1] * 100
rotation_days = (pd.Timestamp(position.DATE.iloc[-1]) - capital.index[0]).days

print('-----------------------')
print("Total BUY    ₩", f'{total_buy:,}')
print(" ")
print("Buy Rotation : Target < 100% / year")
print("    {:.1f} %".format(rotation_rate_buy), "over", rotation_days, "days")
print("    {:.1f} %".format(rotation_rate_buy / rotation_days * 365), "/ year")
print('  ')

total_sell = position.loc[position.SELL == True, 'CAP'].sum()
rotation_rate_sell = total_sell / eva.CAP[-1] * 100

print('-----------------------')
print("Total SELL    ₩", f'{total_sell:,}')
print(" ")
print("Sell Rotation : Target < 30% / year")
print("    {:.1f} %".format(rotation_rate_sell), "over", rotation_days, "days")
print("    {:.1f} %".format(rotation_rate_sell / rotation_days * 365), "/ year")


# rotation_per_year = rotation_rate / rotation_days * 365
# Out:
# Total Transaction: 71
#     Buy   47
#     Sell  24
#
# -----------------------
# Total BUY    ₩ 18,960,762
#
# Buy Rotation : Target < 100% / year
#     25.3 % over 193 days
#     47.9 % / year
#
# -----------------------
# Total SELL    ₩ 8,167,997
#
# Sell Rotation : Target < 30% / year
#     10.9 % over 193 days
#     20.6 % / year

# %%
# open - 보유 중인 계약, closed - 종료된 거래을 담기 위한 각각의 df 생성
open = pd.DataFrame(columns=['TICKER', 'STOCKS', 'INVEST', 'AVG_PRICE'])
closed = pd.DataFrame(columns=['TICKER', 'DATE', 'BUY', 'SELL', 'DELTA', 'PROFIT%', 'STOCKS', 'CAP_CHANGE'])

# postion df를 loop하면서 SELL여부를 기준으로 open/closed df에 이력 추가 및 계산
for i, row in position.iterrows():
  # 매도일 경우, 1) closed df에 이력 추가. 2) open df에서는 주식수만 삭감하며 투자금액은 기존 평균가로 재산출
  if row['SELL'] == True:
    # print(i, 'SELL', row['TICKER'], row['TICKER'], row['DATE'], row['PRICE'],row['STOCKS'])
    buy = -1 * int(open.loc[open.TICKER == row['TICKER'], 'AVG_PRICE'])
    delta =  row['PRICE'] - buy
    profitper = delta / buy * 100
    capchange = -1 * delta * row['STOCKS']
    closed.loc[len(closed)] = [row['TICKER'], row['DATE'], buy, row['PRICE'], delta, profitper, row['STOCKS'], capchange]
    # print(closed)
    open.loc[i] = [row['TICKER'], row['STOCKS'], row['CAP'], 0]
    open = open.groupby(['TICKER']).sum().reset_index()
    open = open[open.STOCKS != 0]
    open.INVEST = open.STOCKS * open.AVG_PRICE

  # 매수일 경우, 주식수/거래대금을 기재 후 종목으로 합산 후 평균가 재산출
  else:
    # print(i, 'BUY', row['TICKER'], row['STOCKS'], row['CAP'])
    open.loc[i] = [row['TICKER'], row['STOCKS'], row['CAP'], np.nan]
    open = open.groupby(['TICKER']).sum().reset_index()
    # open = open[open.STOCKS != 0]
    open['AVG_PRICE'] = open.INVEST / open.STOCKS
    # print(open)
    # print("***********")
    # print(" ")

# 용이성을 위해 종목명을 병기하고 열 순서 변경
tcknaming(closed)
closed = closed[['DATE', 'TICKER', 'NAME', 'BUY', 'SELL', 'DELTA', 'PROFIT%', 'STOCKS', 'CAP_CHANGE']]
tcknaming(open)
open = open[['TICKER', 'NAME', 'STOCKS', 'AVG_PRICE', 'INVEST']]

# %% [markdown]
# ## Closed Position

# %%
sell = position.loc[position.SELL == True].copy()
# tcknaming(sell)
# sell = sell[['DATE', 'TICKER', 'NAME', 'CAP', 'ACCOUNT']]

sellcap = sell[['DATE', 'CAP']].groupby(['DATE']).sum()
# sellcap.index = pd.to_datetime(sellcap.index)
sellcap.plot(kind= 'bar', figsize= (12, 3), title= 'Closed Position by Date - Million ₩')

# %%
closed.style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_4efdd982_f203_11ec_b549_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >TICKER</th>        <th class="col_heading level0 col2" >NAME</th>        <th class="col_heading level0 col3" >BUY</th>        <th class="col_heading level0 col4" >SELL</th>        <th class="col_heading level0 col5" >DELTA</th>        <th class="col_heading level0 col6" >PROFIT%</th>        <th class="col_heading level0 col7" >STOCKS</th>        <th class="col_heading level0 col8" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_784f438ec1c5level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col0" class="data row0 col0" >2022-01-06</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col1" class="data row0 col1" >005930</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col2" class="data row0 col2" >삼성전자</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col3" class="data row0 col3" >79042</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col4" class="data row0 col4" >77500</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col5" class="data row0 col5" >-1542</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col6" class="data row0 col6" >-2.0</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col7" class="data row0 col7" >-7</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row0_col8" class="data row0 col8" >-10,794</td>
#             </tr>
#             <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_784f438ec1c5level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col0" class="data row1 col0" >2022-01-06</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col1" class="data row1 col1" >035420</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col2" class="data row1 col2" >NAVER</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col3" class="data row1 col3" >378000</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col4" class="data row1 col4" >346000</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col5" class="data row1 col5" >-32000</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col6" class="data row1 col6" >-8.5</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col7" class="data row1 col7" >-1</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row1_col8" class="data row1 col8" >-32,000</td>
#             </tr>
#             <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_784f438ec1c5level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col0" class="data row2 col0" >2022-01-06</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col1" class="data row2 col1" >069500</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col2" class="data row2 col2" >KODEX 200</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col3" class="data row2 col3" >40027</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col4" class="data row2 col4" >39435</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col5" class="data row2 col5" >-592</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col6" class="data row2 col6" >-1.5</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col7" class="data row2 col7" >-2</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row2_col8" class="data row2 col8" >-1,184</td>
#             </tr>
#             <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_784f438ec1c5level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col0" class="data row3 col0" >2022-01-06</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col1" class="data row3 col1" >088980</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col2" class="data row3 col2" >맥쿼리인프라</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col3" class="data row3 col3" >14150</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col4" class="data row3 col4" >13800</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col5" class="data row3 col5" >-350</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col6" class="data row3 col6" >-2.5</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col7" class="data row3 col7" >-7</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row3_col8" class="data row3 col8" >-2,450</td>
#             </tr>
#             <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_784f438ec1c5level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col0" class="data row4 col0" >2022-01-24</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col1" class="data row4 col1" >411420</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col2" class="data row4 col2" >KODEX 미국메타버스나스닥액티브</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col3" class="data row4 col3" >10150</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col4" class="data row4 col4" >8475</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col5" class="data row4 col5" >-1675</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col6" class="data row4 col6" >-16.5</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col7" class="data row4 col7" >-20</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row4_col8" class="data row4 col8" >-33,500</td>
#             </tr>
#             <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_784f438ec1c5level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col0" class="data row5 col0" >2022-01-28</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col1" class="data row5 col1" >000660</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col2" class="data row5 col2" >SK하이닉스</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col3" class="data row5 col3" >128500</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col4" class="data row5 col4" >119500</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col5" class="data row5 col5" >-9000</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col6" class="data row5 col6" >-7.0</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col7" class="data row5 col7" >-1</td>
#                         <td id="T_4efdd982_f203_11ec_b549_784f438ec1c5row5_col8" class="data row5 col8" >-9,000</td>
#             </tr>
#             <tr>
#                         <th id="T_4efdd982_f203_11ec_b549_78

# %%
print('Total Closed Capital    ₩', f'{sell.CAP.sum():,}')
print('Total Closed Profit     ₩' ,f'{closed.CAP_CHANGE.sum():,}')
print('--------------------------')
print('Total Closed Profit     {:.1f} %'.format(closed.CAP_CHANGE.sum() / sell.CAP.sum() * 100))
# Out:
# Total Closed Capital    ₩ 8,167,997
# Total Closed Profit     ₩ -568,913
# --------------------------
# Total Closed Profit     -7.0 %

# %%
closed[['DATE', 'NAME', 'PROFIT%', 'CAP_CHANGE']].sort_values('CAP_CHANGE', ascending= False).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_4f05908c_f203_11ec_b549_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >NAME</th>        <th class="col_heading level0 col2" >PROFIT%</th>        <th class="col_heading level0 col3" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row0_col0" class="data row0 col0" >2022-03-10</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row0_col1" class="data row0 col1" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row0_col2" class="data row0 col2" >38.4</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row0_col3" class="data row0 col3" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row1_col0" class="data row1 col0" >2022-06-21</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row1_col1" class="data row1 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row1_col2" class="data row1 col2" >17.4</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row1_col3" class="data row1 col3" >52,150</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row2" class="row_heading level0 row2" >22</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row2_col0" class="data row2 col0" >2022-06-21</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row2_col1" class="data row2 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row2_col2" class="data row2 col2" >7.1</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row2_col3" class="data row2 col3" >39,468</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row3" class="row_heading level0 row3" >21</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row3_col0" class="data row3 col0" >2022-06-21</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row3_col1" class="data row3 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row3_col2" class="data row3 col2" >17.4</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row3_col3" class="data row3 col3" >35,760</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row4" class="row_heading level0 row4" >2</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row4_col0" class="data row4 col0" >2022-01-06</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row4_col1" class="data row4 col1" >KODEX 200</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row4_col2" class="data row4 col2" >-1.5</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row4_col3" class="data row4 col3" >-1,184</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row5" class="row_heading level0 row5" >14</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row5_col0" class="data row5 col0" >2022-03-23</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row5_col1" class="data row5 col1" >TIGER 인버스</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row5_col2" class="data row5 col2" >-2.6</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row5_col3" class="data row5 col3" >-2,375</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row6" class="row_heading level0 row6" >3</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row6_col0" class="data row6 col0" >2022-01-06</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row6_col1" class="data row6 col1" >맥쿼리인프라</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row6_col2" class="data row6 col2" >-2.5</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row6_col3" class="data row6 col3" >-2,450</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row7" class="row_heading level0 row7" >15</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row7_col0" class="data row7 col0" >2022-03-23</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row7_col1" class="data row7 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row7_col2" class="data row7 col2" >-0.9</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row7_col3" class="data row7 col3" >-3,666</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row8" class="row_heading level0 row8" >5</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row8_col0" class="data row8 col0" >2022-01-28</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row8_col1" class="data row8 col1" >SK하이닉스</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row8_col2" class="data row8 col2" >-7.0</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row8_col3" class="data row8 col3" >-9,000</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row9" class="row_heading level0 row9" >20</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row9_col0" class="data row9 col0" >2022-06-15</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row9_col1" class="data row9 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row9_col2" class="data row9 col2" >-14.0</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row9_col3" class="data row9 col3" >-10,693</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row10" class="row_heading level0 row10" >0</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row10_col0" class="data row10 col0" >2022-01-06</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row10_col1" class="data row10 col1" >삼성전자</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row10_col2" class="data row10 col2" >-2.0</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row10_col3" class="data row10 col3" >-10,794</td>
#             </tr>
#             <tr>
#                         <th id="T_4f05908c_f203_11ec_b549_784f438ec1c5level0_row11" class="row_heading level0 row11" >13</th>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row11_col0" class="data row11 col0" >2022-03-16</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row11_col1" class="data row11 col1" >ARIRANG 신흥국MSCI(합성 H)</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438ec1c5row11_col2" class="data row11 col2" >-10.7</td>
#                         <td id="T_4f05908c_f203_11ec_b549_784f438e

# %%
closed[['NAME', 'CAP_CHANGE']].set_index('NAME').sort_values('CAP_CHANGE', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Closed Position - ₩')

# %%
closed[['DATE', 'NAME', 'PROFIT%', 'CAP_CHANGE']].sort_values('PROFIT%', ascending= False).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >NAME</th>        <th class="col_heading level0 col2" >PROFIT%</th>        <th class="col_heading level0 col3" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row0_col0" class="data row0 col0" >2022-03-10</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row0_col1" class="data row0 col1" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row0_col2" class="data row0 col2" >38.4</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row0_col3" class="data row0 col3" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row1_col0" class="data row1 col0" >2022-06-21</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row1_col1" class="data row1 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row1_col2" class="data row1 col2" >17.4</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row1_col3" class="data row1 col3" >52,150</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row2" class="row_heading level0 row2" >21</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row2_col0" class="data row2 col0" >2022-06-21</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row2_col1" class="data row2 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row2_col2" class="data row2 col2" >17.4</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row2_col3" class="data row2 col3" >35,760</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row3" class="row_heading level0 row3" >22</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row3_col0" class="data row3 col0" >2022-06-21</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row3_col1" class="data row3 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row3_col2" class="data row3 col2" >7.1</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row3_col3" class="data row3 col3" >39,468</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row4" class="row_heading level0 row4" >15</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row4_col0" class="data row4 col0" >2022-03-23</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row4_col1" class="data row4 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row4_col2" class="data row4 col2" >-0.9</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row4_col3" class="data row4 col3" >-3,666</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row5" class="row_heading level0 row5" >2</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row5_col0" class="data row5 col0" >2022-01-06</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row5_col1" class="data row5 col1" >KODEX 200</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row5_col2" class="data row5 col2" >-1.5</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row5_col3" class="data row5 col3" >-1,184</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row6" class="row_heading level0 row6" >0</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row6_col0" class="data row6 col0" >2022-01-06</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row6_col1" class="data row6 col1" >삼성전자</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row6_col2" class="data row6 col2" >-2.0</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row6_col3" class="data row6 col3" >-10,794</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row7" class="row_heading level0 row7" >19</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row7_col0" class="data row7 col0" >2022-06-13</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row7_col1" class="data row7 col1" >TRUE S&P500 양매도 4% OTM ETN(H)</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row7_col2" class="data row7 col2" >-2.0</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row7_col3" class="data row7 col3" >-20,160</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row8" class="row_heading level0 row8" >3</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row8_col0" class="data row8 col0" >2022-01-06</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row8_col1" class="data row8 col1" >맥쿼리인프라</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row8_col2" class="data row8 col2" >-2.5</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row8_col3" class="data row8 col3" >-2,450</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row9" class="row_heading level0 row9" >14</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row9_col0" class="data row9 col0" >2022-03-23</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row9_col1" class="data row9 col1" >TIGER 인버스</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row9_col2" class="data row9 col2" >-2.6</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row9_col3" class="data row9 col3" >-2,375</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row10" class="row_heading level0 row10" >5</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row10_col0" class="data row10 col0" >2022-01-28</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row10_col1" class="data row10 col1" >SK하이닉스</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row10_col2" class="data row10 col2" >-7.0</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row10_col3" class="data row10 col3" >-9,000</td>
#             </tr>
#             <tr>
#                         <th id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5level0_row11" class="row_heading level0 row11" >16</th>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row11_col0" class="data row11 col0" >2022-03-30</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row11_col1" class="data row11 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549_784f438ec1c5row11_col2" class="data row11 col2" >-7.5</td>
#                         <td id="T_4f45ae1a_f203_11ec_b549

# %%
closed[['NAME', 'PROFIT%']].set_index('NAME').sort_values('PROFIT%', ascending= False).plot(kind= 'bar', figsize= (12, 4))

# %% [markdown]
# ## Open Position

# %%
market = open.copy()
market[['AVG_PRICE', 'INVEST']] = market[['AVG_PRICE', 'INVEST']].astype('int')

marketprice = []

for tk in market.TICKER.to_list():
    tk_yahoo = yf.Ticker(tk + '.KS')
    data = tk_yahoo.history().tail(1)['Close'].iloc[0]
    marketprice.append(data)

# CV: 현재평가액 = 현재가 x 보유수, EVA: 평가증감 = 포지션 - 현재평가액
market['MARKET_PRICE'] = marketprice
market['CV'] = market.MARKET_PRICE * market.STOCKS
market['PROFIT'] = market.CV + market.INVEST
market['PROFIT%'] = market.PROFIT / market.INVEST * -100

# %%
print('Current Portfolio Total')
print('-----------------------------')
print('Values    ₩', f'{int(market.CV.sum()):,}')
print('Profit    ₩', f'{int(market.PROFIT.sum()):,}')
print('Profit%   {:.2f} %'.format(market.PROFIT.sum() / market.INVEST.sum() * -100))
# Out:
# Current Portfolio Total
# -----------------------------
# Values    ₩ 9,668,895
# Profit    ₩ -554,711
# Profit%   -5.43 %

# %%
colformat = {"PROFIT%": "{:,.1f}", 
             "AVG_PRICE": "{:,.0f}", "INVEST": "{:,.0f}", "MARKET_PRICE": "{:,.0f}", 
             "CV": "{:,.0f}", "PROFIT": "{:,.0f}"}
market.style.format(colformat)

# 현재 평가액이 큰 순서대로 배열
market.sort_values(by=['CV'], ascending= False, ignore_index=False)
# Out:
#     TICKER                      NAME  STOCKS  AVG_PRICE   INVEST  \
# 12  371460     TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960
# 10  332610         ARIRANG 미국단기우량회사채      10    -102840 -1028400
# 5   219390  KBSTAR 미국S&P원유생산기업(합성 H)     180      -5545  -998100
# 13  373790         KOSEF 미국방어배당성장나스닥      77     -12950  -997150
# 2   139280                TIGER 경기방어      99     -10130 -1002870
# 9   329200            TIGER 리츠부동산인프라     154      -6495 -1000230
# 6   266410               KODEX 필수소비재     127      -7910 -1004570
# 3   157490               TIGER 소프트웨어      70     -14325 -1002750
# 17  530020          삼성 미국 대형 가치주 ETN      33     -17723  -584873
# 15  409810    KODEX 미국나스닥100선물인버스(H)      37     -12563  -464843
# 4   218420        KODEX 미국S&P에너지(합성)      40     -12555  -502200
# 11  360750            TIGER 미국S&P500      18     -13670  -246060
# 8   319640             TIGER 골드선물(H)      14     -14270  -199780
# 14  394350     KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856
# 1   133690            TIGER 미국나스닥100       1     -82580   -82580
# 0   123310                 TIGER 인버스       1      -4895    -4895
# 7   271050       KODEX WTI원유선물인버스(H)       1      -4489    -4489
#
#     MARKET_PRICE         CV    PROFIT    PROFIT%
# 12       17000.0  1156000.0  155040.0  15.489130
# 10      106205.0  1062050.0   33650.0   3.272073
# 5         5795.0  1043100.0   45000.0   4.508566
# 13       12655.0   974435.0  -22715.0  -2.277992
# 2         9055.0   896445.0 -106425.0 -10.612043
# 9         5700.0   877800.0 -122430.0 -12.240185
# 6         6875.0   873125.0 -131445.0 -13.084703
# 3        10045.0   703150.0 -299600.0 -29.877836
# 17       17390.0   573870.0  -11003.0  -1.881263
# 15       13575.0   502275.0   37432.0   8.052611
# 4        11055.0   442200.0  -60000.0 -11.947431
# 11       12130.0   218340.0  -27720.0 -11.265545
# 8        13125.0   183750.0  -16030.0  -8.023826
# 14        9600.0    86400.0  -12456.0 -12.600146
# 1        66100.0    66100.0  -16480.0 -19.956406
# 0         5600.0     5600.0     705.0  14.402451
# 7         4255.0     4255.0    -234.0  -5.212742

# %%
market[['NAME', 'CV']].set_index('NAME').sort_values('CV', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by CV ₩')

# %%
# 투자수익이 큰 순서대로 배열
market.sort_values(by=['PROFIT'], ascending= False, ignore_index=False)
# Out:
#     TICKER                      NAME  STOCKS  AVG_PRICE   INVEST  \
# 12  371460     TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960
# 5   219390  KBSTAR 미국S&P원유생산기업(합성 H)     180      -5545  -998100
# 15  409810    KODEX 미국나스닥100선물인버스(H)      37     -12563  -464843
# 10  332610         ARIRANG 미국단기우량회사채      10    -102840 -1028400
# 0   123310                 TIGER 인버스       1      -4895    -4895
# 7   271050       KODEX WTI원유선물인버스(H)       1      -4489    -4489
# 17  530020          삼성 미국 대형 가치주 ETN      33     -17723  -584873
# 14  394350     KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856
# 8   319640             TIGER 골드선물(H)      14     -14270  -199780
# 1   133690            TIGER 미국나스닥100       1     -82580   -82580
# 13  373790         KOSEF 미국방어배당성장나스닥      77     -12950  -997150
# 11  360750            TIGER 미국S&P500      18     -13670  -246060
# 4   218420        KODEX 미국S&P에너지(합성)      40     -12555  -502200
# 2   139280                TIGER 경기방어      99     -10130 -1002870
# 9   329200            TIGER 리츠부동산인프라     154      -6495 -1000230
# 6   266410               KODEX 필수소비재     127      -7910 -1004570
# 3   157490               TIGER 소프트웨어      70     -14325 -1002750
#
#     MARKET_PRICE         CV    PROFIT    PROFIT%
# 12       17000.0  1156000.0  155040.0  15.489130
# 5         5795.0  1043100.0   45000.0   4.508566
# 15       13575.0   502275.0   37432.0   8.052611
# 10      106205.0  1062050.0   33650.0   3.272073
# 0         5600.0     5600.0     705.0  14.402451
# 7         4255.0     4255.0    -234.0  -5.212742
# 17       17390.0   573870.0  -11003.0  -1.881263
# 14        9600.0    86400.0  -12456.0 -12.600146
# 8        13125.0   183750.0  -16030.0  -8.023826
# 1        66100.0    66100.0  -16480.0 -19.956406
# 13       12655.0   974435.0  -22715.0  -2.277992
# 11       12130.0   218340.0  -27720.0 -11.265545
# 4        11055.0   442200.0  -60000.0 -11.947431
# 2         9055.0   896445.0 -106425.0 -10.612043
# 9         5700.0   877800.0 -122430.0 -12.240185
# 6         6875.0   873125.0 -131445.0 -13.084703
# 3        10045.0   703150.0 -299600.0 -29.877836

# %%
market[['NAME', 'PROFIT']].set_index('NAME').sort_values('PROFIT', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by Profit ₩')

# %%
market[['NAME', 'PROFIT%']].set_index('NAME').sort_values('PROFIT%', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by Profit%')

# %% [markdown]
# ## Trend - Closed

# %%
today = datetime.today()

start = (today + timedelta(days= -180)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

# start = datetime.now() - relativedelta(days=7)
# end = datetime.now()

# %%
for i, row in closed.iterrows():
    try:
        data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        print('***', row.NAME, '***')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
#                 y = data.loc[data.index == prow.DATE, 'Close'].item()
                y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY'
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** 삼성전자 ***
# *** NAVER ***
# *** KODEX 200 ***
# *** 맥쿼리인프라 ***
# *** KODEX 미국메타버스나스닥액티브 ***
# *** SK하이닉스 ***
# *** TIGER 미국나스닥100 ***
# *** 대신 인버스 니켈선물 ETN(H) ***
# *** TIGER 미국S&P500 ***
# *** TIGER 미국나스닥100 ***
# *** TIGER 미국S&P500 ***
# *** KBSTAR 팔라듐선물(H) ***
# *** 미래에셋 중국 심천 100 ETN ***
# *** ARIRANG 신흥국MSCI(합성 H) ***
# *** TIGER 인버스 ***
# *** KODEX WTI원유선물인버스(H) ***
# *** KODEX 미국나스닥100선물인버스(H) ***
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***
# *** TIGER 글로벌클라우드컴퓨팅INDXX ***
# *** TRUE S&P500 양매도 4% OTM ETN(H) ***
# *** KODEX WTI원유선물인버스(H) ***
# *** 신한 S&P500 VIX S/T 선물 ETN C ***
# *** KODEX 미국나스닥100선물인버스(H) ***
# *** 신한 S&P500 VIX S/T 선물 ETN C ***

# %% [markdown]
# ## Trend - Open

# %%
for i, row in open.iterrows():
    try:
        data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        print('***', row.NAME, '***')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
#                 y = data.loc[data.index == prow.DATE, 'Close'].item()
                y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY'
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** TIGER 인버스 ***
# *** TIGER 미국나스닥100 ***
# *** TIGER 경기방어 ***
# *** TIGER 소프트웨어 ***
# *** KODEX 미국S&P에너지(합성) ***
# *** KBSTAR 미국S&P원유생산기업(합성 H) ***
# *** KODEX 필수소비재 ***
# *** KODEX WTI원유선물인버스(H) ***
# *** TIGER 골드선물(H) ***
# *** TIGER 리츠부동산인프라 ***
# *** ARIRANG 미국단기우량회사채 ***
# *** TIGER 미국S&P500 ***
# *** TIGER 차이나전기차SOLACTIVE ***
# *** KOSEF 미국방어배당성장나스닥 ***
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***
# *** KODEX 미국나스닥100선물인버스(H) ***
# *** 삼성 미국 대형 가치주 ETN ***

# %% [markdown]
# ## Trend with Benchmark

# %%
# KODEX200 : 069500, TIGER 미국S&P500 : 360750, TIGER 미국나스닥100 : 133690

kospi = web.naver.NaverDailyReader('069500', start= start, end= end).read().astype('int')
kospi = kospi / kospi.Close[0] * 100

sp500 = web.naver.NaverDailyReader('360750', start= start, end= end).read().astype('int')
sp500 = sp500 / sp500.Close[0] * 100

# %%
for i, row in open.iterrows():
    try:
        record = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        data = record / record.Close[0] * 100
        
        if ticker[row.TICKER][1] == 'KR':
            apdict = mpf.make_addplot(kospi.Close, type='line')
            bmindex = 'KOSPI'
        else:
            apdict = mpf.make_addplot(sp500.Close)
            bmindex = 'S&P500'
            
        print(row.NAME, ' vs.', bmindex, '(Benchmark)')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, addplot= apdict)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
                y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY'
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))

        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# TIGER 인버스  vs. KOSPI (Benchmark)
# TIGER 미국나스닥100  vs. S&P500 (Benchmark)
# TIGER 경기방어  vs. KOSPI (Benchmark)
# TIGER 소프트웨어  vs. KOSPI (Benchmark)
# KODEX 미국S&P에너지(합성)  vs. S&P500 (Benchmark)
# KBSTAR 미국S&P원유생산기업(합성 H)  vs. S&P500 (Benchmark)
# KODEX 필수소비재  vs. KOSPI (Benchmark)
# KODEX WTI원유선물인버스(H)  vs. S&P500 (Benchmark)
# TIGER 골드선물(H)  vs. S&P500 (Benchmark)
# TIGER 리츠부동산인프라  vs. KOSPI (Benchmark)
# ARIRANG 미국단기우량회사채  vs. S&P500 (Benchmark)
# TIGER 미국S&P500  vs. S&P500 (Benchmark)
# TIGER 차이나전기차SOLACTIVE  vs. S&P500 (Benchmark)
# KOSEF 미국방어배당성장나스닥  vs. S&P500 (Benchmark)
# KOSEF 릭소글로벌퓨처모빌리티MSCI  vs. S&P500 (Benchmark)
# KODEX 미국나스닥100선물인버스(H)  vs. S&P500 (Benchmark)
# 삼성 미국 대형 가치주 ETN  vs. S&P500 (Benchmark)
