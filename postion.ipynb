# %% [markdown]
# ## Input and Preparation

# %%
### 매주 입력 필요

# 투자금 변화 입력
list_capital = [
    ['2021-12-10', 1500000, 2000000, 0, 17100000, 0],
    ['2022-03-21', 1500000, 2000000, 750000, 17100000, 0],
    ['2022-04-21', 1500000, 2000000, 1000000, 17100000, 0], 
    ['2022-05-11', 1500000, 2000000, 1000000, 17100000, 51411787], 
    ['2022-05-14', 2000000, 2000000, 1000000, 17100000, 51411787],
    ['2022-05-21', 2000000, 2000000, 1250000, 17100000, 51853487],
    ['2022-06-21', 2000000, 2000000, 1500000, 17100000, 52295187],
    ['2022-07-21', 2000000, 2000000, 1750000, 17100000, 52769107]
]

# 주차별 자산평가액 입력
list_eva = [
    ['2021-12-10', 1500000, 2000000, 0, 17100000, 0],
    ['2022-04-01', 1320963, 1815919, 745075, 17169766, 0],
    ['2022-04-08', 1328128, 1824105, 739964, 17110423, 0],
    ['2022-04-20', 1306232, 1843025, 734283, 17122584, 0],
    ['2022-04-26', 1300044, 1825530, 974443, 16710626, 0],
    ['2022-05-04', 1297685, 1810670, 973821, 16818596, 0],
    ['2022-05-11', 1280706, 1787935, 963967, 16557094, 51411787],
    ['2022-05-18', 1747918, 1792125, 963923, 16606513, 51853487],
    ['2022-05-25', 1803813, 1768880, 1203089, 16567673, 51853487],
    ['2022-06-01', 1719094, 1759435, 1218145, 16809988, 51853487],
    ['2022-06-08', 1720456, 1767500, 1215795, 16921678, 51853487],
    ['2022-06-15', 1894061, 1843039, 1199774, 16718468, 51853487],
    ['2022-06-22', 1860821, 1763385, 1446383, 16483969, 52295187],
    ['2022-06-29', 1849339, 1805846, 1460028, 16608526, 52295187],
    ['2022-07-06', 1925886, 1856331, 1457095, 16564777, 52295187],
    ['2022-07-12', 1889401, 1880419, 1461671, 16486370, 52295187],
    ['2022-07-20', 1897198, 1913519, 1462364, 16516645, 52295187],
    ['2022-07-26', 1889500, 1861224, 1721987, 16491020, 52791059]
]

# 종목 정보 - 신규 종목 매수 시, 별도 지정 필요
ticker = {
    '005930': ['삼성전자', 'KR', 'STOCK'],
    '000660': ['SK하이닉스',  'KR',  'STOCK'],
    '035420': ['NAVER',  'KR',  'STOCK'],
    '069500': ['KODEX 200',  'KR',  'ETF'],
    '088980': ['맥쿼리인프라',  'KR',  'STOCK'],
    '123310': ['TIGER 인버스',  'KR',  'ETF'],
    '133690': ['TIGER 미국나스닥100',  'US',  'ETF'],
    '139280': ['TIGER 경기방어',  'KR',  'ETF'],
    '157490': ['TIGER 소프트웨어',  'KR',  'ETF'],
    '169950': ['KODEX 차이나A50', 'KR', 'ETF'],
    '195980': ['ARIRANG 신흥국MSCI(합성 H)',  'Global',  'ETF'],
    '218420': ['KODEX 미국S&P에너지(합성)', 'US', 'Commodity'],
    '219390': ['KBSTAR 미국S&P원유생산기업(합성 H)',  'US',  'Commodity'],
    '241180': ['TIGER 일본니케이225', 'JP', 'ETF'],
    '266410': ['KODEX 필수소비재',  'KR',  'ETF'],
    '271050': ['KODEX WTI원유선물인버스(H)',  'Global',  'Commodity'],
    '278530': ['KODEX 200TR', 'KR', 'ETF'],
    '319640': ['TIGER 골드선물(H)',  'Global',  'Commodity'],
    '329200': ['TIGER 리츠부동산인프라', 'KR', 'RealEstate'],
    '334690': ['KBSTAR 팔라듐선물(H)',  'Global',  'Commodity'],
    '332610': ['ARIRANG 미국단기우량회사채',  'US',  'Bond'],
    '360750': ['TIGER 미국S&P500',  'US',  'ETF'],
    '371450': ['TIGER 글로벌클라우드컴퓨팅INDXX',  'US',  'ETF'],
    '371460': ['TIGER 차이나전기차SOLACTIVE',  'CN',  'ETF'],
    '373790': ['KOSEF 미국방어배당성장나스닥',  'US',  'ETF'],
    '379800': ['KODEX 미국S&P500TR', 'US', 'ETF'],
    '379810': ['KODEX 미국나스닥100TR', 'US', 'ETF'],
    '394350': ['KOSEF 릭소글로벌퓨처모빌리티MSCI',  'Global',  'ETF'],
    '409810': ['KODEX 미국나스닥100선물인버스(H)',  'US',  'ETF'],
    '411420': ['KODEX 미국메타버스나스닥액티브',  'US',  'ETF'],
    '500014': ['신한 인버스 옥수수 선물 ETN(H)',  'Global',  'Commodity'],
    '500058': ['신한 S&P500 VIX S/T 선물 ETN C', 'US', 'ETF'],
    '510004': ['대신 인버스 아연선물 ETN(H)',  'Global',  'Commodity'],
    '510006': ['대신 인버스 니켈선물 ETN(H)',  'Global',  'Commodity'],
    '510018': ['대신 인버스 알루미늄 선물 ETN(H)',  'Global',  'Commodity'],
    '530020': ['삼성 미국 대형 가치주 ETN',  'US',  'ETF'],
    '570049': ['TRUE S&P500 양매도 4% OTM ETN(H)',  'US',  'ETF'],
    '590018': ['미래에셋 중국 심천 100 ETN',  'CN',  'ETF']
}

# 일자, Ticker, 주식수, 체결가격, Bank account
# Price: 매수+, 매도-
actions = [
    ['2021-12-13', '005930', 1, 77100, '14'],
    ['2021-12-13', '069500', 2, 40027, '14'],
    ['2020-12-13', '360750', 7, 14028, '14'],
    ['2021-12-21', '005930', 2, 78200, '14'],
    ['2021-12-22', '000660', 1, 128500, '14'],
    ['2021-12-22', '005930', 2, 79100, '14'],
    ['2021-12-22', '035420', 1, 378000, '14'],
    ['2021-12-23', '088980', 7, 14150, '14'],
    ['2021-12-23', '133690', 3, 86165, '01'],
    ['2021-12-24', '005930', 2, 80800, '14'],
    ['2021-12-24', '133690', 3, 86600, '01'],
    ['2021-12-24', '360750', 15, 14125, '01'],
    ['2022-01-03', '411420', 20, 10150, '01'],
    ['2022-01-04', '530020', 9, 17512, '14'],
    ['2022-01-06', '133690', 5, 84920, '14'],
    ['2022-01-06', '530020', 7, 17870, '14'],
    ['2022-01-06', '590018', 15, 20085, '14'],
    ['2022-01-06', '360750', 14, 14215, '14'],
    ['2022-01-06', '005930', -7, 77500, '14'],
    ['2022-01-06', '035420', -1, 346000, '14'],
    ['2022-01-06', '069500', -2, 39435, '14'],
    ['2022-01-06', '088980', -7, 13800, '14'],
    ['2022-01-24', '334690', 19, 12090, '01'],
    ['2022-01-24', '411420', -20, 8475, '01'],
    ['2022-01-28', '510006', 53, 3820, '01'],
    ['2022-01-28', '000660', -1, 119500, '14'],
    ['2022-02-14', '409810', 41, 11230, '01'],
    ['2022-02-14', '133690', -6, 76300, '01'],
    ['2022-02-15', '271050', 17, 5835, '01'],
    ['2022-02-24', '510006', -53, 3360, '01'],
    ['2022-02-24', '360750', -15, 12535, '01'],
    ['2022-02-24', '133690', -5, 70930, '14'],
    ['2022-02-24', '360750', -21, 12552, '14'],
    ['2022-03-04', '195980', 11, 11045, '29'],
    ['2022-03-04', '360750', 9, 13225, '29'],
    ['2022-03-07', '271050', 95, 4249, '14'],
    ['2022-03-10', '334690', -19, 16735, '01'],
    ['2022-03-14', '319640', 14, 14270, '14'],
    ['2022-03-14', '570049', 17, 11670, '14'],
    ['2022-03-14', '123310', 20, 4895, '01'],
    ['2022-03-14', '219390', 180, 5545, '28'],
    ['2022-03-14', '332610', 10, 102840, '28'],
    ['2022-03-14', '373790', 77, 12950, '28'],
    ['2022-03-16', '590018', -15, 16243, '14'],
    ['2022-03-16', '195980', -11, 9865, '29'],
    ['2022-03-23', '123310', -19, 4770, '01'],
    ['2022-03-23', '271050', -94, 4450, '14'],
    ['2022-03-23', '266410', 127, 7910, '28'],
    ['2022-03-30', '409810', -40, 10390, '01'],
    ['2022-03-30', '570049', 25, 11715, '14'],
    ['2022-03-30', '360750', 9, 14115, '29'],
    ['2022-03-30', '133690', 1, 82580, '29'],
    ['2022-03-30', '139280', 99, 10130, '28'],
    ['2022-03-30', '371450', 101, 9900, '28'],
    ['2022-03-30', '157490', 70, 14325, '28'],
    ['2022-03-30', '394350', 91, 10984, '28'],
    ['2022-03-30', '371460', 68, 14720, '28'],
    ['2022-04-21', '329200', 154, 6495, '28'],
    ['2022-04-29', '570049', 42, 11865, '14'],
    ['2022-05-12', '394350', -82, 9360, '28'],
    ['2022-05-12', '371450', -101, 7830, '28'],
    ['2022-05-17', '409810', 80, 12580, '01'],
    ['2022-06-09', '500058', 24, 8550, '01'],
    ['2022-06-09', '500058', 35, 8560, '14'],
    ['2022-06-13', '570049', -84, 11540, '14'],
    ['2022-06-15', '218420', 40, 12555, '14'],
    ['2022-06-15', '530020', 17, 17775, '14'],
    ['2022-06-15', '271050', -17, 3860, '01'],
    ['2022-06-21', '500058', -24, 10045, '01'],
    ['2022-06-21', '409810', -44, 13460, '01'],
    ['2022-06-21', '500058', -35, 10045, '14'],
    ['2022-06-23', '219390', -180, 5570, '28'],
    ['2022-06-23', '218420', -40, 10900, '14'],
    ['2022-06-23', '510006', 289, 1735, '14'],
    ['2022-06-23', '510018', 50, 9960, '01'],
    ['2022-06-24', '510004', 74, 6450, '14'],
    ['2022-06-24', '500014', 72, 6326, '01'],
    ['2022-06-29', '319640', -14, 13085, '14'],
    ['2022-07-21', '278530', 10, 10675, '29'],
    ['2022-07-21', '379800', 9, 11530, '29'],
    ['2022-07-21', '379810', 10, 10730, '29'],
    ['2022-07-21', '379800', 87, 11530, 'MA'],
    ['2022-07-21', '379810', 93, 10730, 'MA'],
    ['2022-07-21', '278530', 94, 10620, 'MA'],
    ['2022-07-21', '241180', 65, 15490, 'MA'],
    ['2022-07-21', '169950', 47, 21200, 'MA']
]

# %%
# Bank Account
account = {
    '01': 'FR',
    '14': 'SA',
    '29': 'RP',
    '28': 'DC',
    'MA': 'MA'
}

# %%
# Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
# capital, eva 데이터프레임 생성
def define_cap(caplist, total):
    df = pd.DataFrame(caplist, columns= ['DATE'] + list(account.values()))
    df.DATE = pd.to_datetime(df.DATE)
    df.set_index(['DATE'], inplace= True)
    df[total] = df.loc[:, df.columns!='EVENT'].sum(axis=1)
    return df

# 개별 계정에 대해 자본 대비 평가액 변화 확인
def cap_change(account_col):
    account_cap = capital[account_col][-1]
    account_eva = eva[account_col][-1]
    account_del = account_eva - account_cap
    return [account_cap, account_eva, account_del, account_del / account_cap * 100]    

# ticker로 해당 종목 이름열인 'NAME'을 생성 - 별도 반환없이 바로 지정된 df에 생성
def tcknaming(df):
  df['NAME'] = df.TICKER.map(lambda x: ticker[x][0])

# %% [markdown]
# ## Capital

# %%
# 투자금 현황
# list_capital = pd.read_excel('position.xlsx', sheet_name='capital')

capital = define_cap(list_capital, 'CAP')
capital['DELTA'] = capital.CAP.diff()

capital.style.format("{:,.0f}")
capital
# Out:
#                  FR       SA       RP        DC        MA       CAP  \
# DATE
# 2021-12-10  1500000  2000000        0  17100000         0  20600000
# 2022-03-21  1500000  2000000   750000  17100000         0  21350000
# 2022-04-21  1500000  2000000  1000000  17100000         0  21600000
# 2022-05-11  1500000  2000000  1000000  17100000  51411787  73011787
# 2022-05-14  2000000  2000000  1000000  17100000  51411787  73511787
# 2022-05-21  2000000  2000000  1250000  17100000  51853487  74203487
# 2022-06-21  2000000  2000000  1500000  17100000  52295187  74895187
# 2022-07-21  2000000  2000000  1750000  17100000  52769107  75619107
#
#                  DELTA
# DATE
# 2021-12-10         NaN
# 2022-03-21    750000.0
# 2022-04-21    250000.0
# 2022-05-11  51411787.0
# 2022-05-14    500000.0
# 2022-05-21    691700.0
# 2022-06-21    691700.0
# 2022-07-21    723920.0

# %%
capital[list(account.values())].plot(kind='bar', stacked=True, figsize=(12, 3), title= "Total Capital - Won")

# %%
# 100만원 이하 자산변화에 대한 라인 그래프 생성
# capital.DELTA[capital.DELTA < 1000000].plot(kind='line', marker='o', figsize= (12, 3), title = 'Capital Change - Won')

# %% [markdown]
# ## Evaluation

# %%
# 입력된 값으로 1) df 생성, 2) capital 내 CAP열 값과 Join, 3) front fill로 없는 행 생성, 4) 불필요 행 삭제
eva = define_cap(list_eva, 'EVA').join(capital.CAP, how= 'outer', sort= True)
eva.CAP = eva.CAP.fillna(method= 'ffill')
eva.dropna(inplace= True)
eva = eva.astype('int')

eva['PROFIT'] = eva.EVA - eva.CAP
eva['PROFIT%'] = eva.PROFIT / eva.CAP * 100

eva.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_338768fc_0cd5_11ed_a893_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FR</th>        <th class="col_heading level0 col1" >SA</th>        <th class="col_heading level0 col2" >RP</th>        <th class="col_heading level0 col3" >DC</th>        <th class="col_heading level0 col4" >MA</th>        <th class="col_heading level0 col5" >EVA</th>        <th class="col_heading level0 col6" >CAP</th>        <th class="col_heading level0 col7" >PROFIT</th>        <th class="col_heading level0 col8" >PROFIT%</th>    </tr>    <tr>        <th class="index_name level0" >DATE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_338768fc_0cd5_11ed_a893_784f438ec1c5level0_row0" class="row_heading level0 row0" >2021-12-10 00:00:00</th>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col0" class="data row0 col0" >1,500,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col1" class="data row0 col1" >2,000,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col3" class="data row0 col3" >17,100,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col5" class="data row0 col5" >20,600,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col6" class="data row0 col6" >20,600,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row0_col8" class="data row0 col8" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_338768fc_0cd5_11ed_a893_784f438ec1c5level0_row1" class="row_heading level0 row1" >2022-04-01 00:00:00</th>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col0" class="data row1 col0" >1,320,963</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col1" class="data row1 col1" >1,815,919</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col2" class="data row1 col2" >745,075</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col3" class="data row1 col3" >17,169,766</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col5" class="data row1 col5" >21,051,723</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col6" class="data row1 col6" >21,350,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col7" class="data row1 col7" >-298,277</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row1_col8" class="data row1 col8" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_338768fc_0cd5_11ed_a893_784f438ec1c5level0_row2" class="row_heading level0 row2" >2022-04-08 00:00:00</th>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col0" class="data row2 col0" >1,328,128</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col1" class="data row2 col1" >1,824,105</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col2" class="data row2 col2" >739,964</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col3" class="data row2 col3" >17,110,423</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col5" class="data row2 col5" >21,002,620</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col6" class="data row2 col6" >21,350,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col7" class="data row2 col7" >-347,380</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row2_col8" class="data row2 col8" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_338768fc_0cd5_11ed_a893_784f438ec1c5level0_row3" class="row_heading level0 row3" >2022-04-20 00:00:00</th>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col0" class="data row3 col0" >1,306,232</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col1" class="data row3 col1" >1,843,025</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col2" class="data row3 col2" >734,283</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col3" class="data row3 col3" >17,122,584</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col5" class="data row3 col5" >21,006,124</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col6" class="data row3 col6" >21,350,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col7" class="data row3 col7" >-343,876</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row3_col8" class="data row3 col8" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_338768fc_0cd5_11ed_a893_784f438ec1c5level0_row4" class="row_heading level0 row4" >2022-04-26 00:00:00</th>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col0" class="data row4 col0" >1,300,044</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col1" class="data row4 col1" >1,825,530</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col2" class="data row4 col2" >974,443</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col3" class="data row4 col3" >16,710,626</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col5" class="data row4 col5" >20,810,643</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col6" class="data row4 col6" >21,600,000</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col7" class="data row4 col7" >-789,357</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row4_col8" class="data row4 col8" >-4</td>
#             </tr>
#             <tr>
#                         <th id="T_338768fc_0cd5_11ed_a893_784f438ec1c5level0_row5" class="row_heading level0 row5" >2022-05-04 00:00:00</th>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row5_col0" class="data row5 col0" >1,297,685</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row5_col1" class="data row5 col1" >1,810,670</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row5_col2" class="data row5 col2" >973,821</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row5_col3" class="data row5 col3" >16,818,596</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_784f438ec1c5row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_338768fc_0cd5_11ed_a893_7

# %%
print("Latest Position")
print("------------------------------")
print("Capital        ₩", f'{eva.CAP[-1]:,}')
print("Evaluation     ₩", f'{eva.EVA[-1]:,}')
print("Profit         ₩", f'{eva.PROFIT[-1]:,}')
print("Profit%        {:.1f} %".format(eva['PROFIT%'][-1]))
# Out:
# Latest Position
# ------------------------------
# Capital        ₩ 75,619,107
# Evaluation     ₩ 74,754,790
# Profit         ₩ -864,317
# Profit%        -1.1 %

# %%
print('EVALUATION BY ACCOUT')
print(' ')
print('ACC   Capital      Evaluation   Profit    Profit%')
print('------------------------------------------------------')
for acc in list(account.values()):
    print(acc, '   ₩', f'{cap_change(acc)[0]:,}', ' ', f'{cap_change(acc)[1]:,}', ' ', f'{cap_change(acc)[2]:,}', ' ',f'{cap_change(acc)[3]:.1f}', '%')
# Out:
# EVALUATION BY ACCOUT
#
# ACC   Capital      Evaluation   Profit    Profit%
# ------------------------------------------------------
# FR    ₩ 2,000,000   1,889,500   -110,500   -5.5 %
# SA    ₩ 2,000,000   1,861,224   -138,776   -6.9 %
# RP    ₩ 1,750,000   1,721,987   -28,013   -1.6 %
# DC    ₩ 17,100,000   16,491,020   -608,980   -3.6 %
# MA    ₩ 52,769,107   52,791,059   21,952   0.0 %

# %%
eva.PROFIT.plot(marker='o', figsize=(12, 3), title = 'PROFIT change - Million ₩')

# %%
eva['PROFIT%'].plot(marker='o', figsize=(12, 3), title = 'PROFIT% change')

# %%
for mycap in account.values():
    eva[mycap].plot(kind='line', marker='o', figsize=(12, 3), title= mycap)
    plt.show()

# %% [markdown]
# ## Evaluation with Benchmark

# %%
# 주요 벤치마크 지표와 Performance 비교
bmticker = {'S&P500': '^GSPC', 'Nasdaq': '^IXIC', 'KOSPI':'^KS11'}
bmdf = pd.DataFrame()

for tk in bmticker:
    tk_yahoo = yf.Ticker(bmticker[tk])
    data = tk_yahoo.history(start= eva.index[0])['Close']
    bmdf[tk] = data
    
bmdf = bmdf.dropna().astype('int32')

evabm = eva[['EVA', 'CAP', 'PROFIT', 'PROFIT%']].join(bmdf, how= 'inner', sort= True)

evabm['BM_SP500'] = evabm['S&P500'] / evabm['S&P500'][0] * 100 - 100
evabm['BM_Nasdaq'] = evabm['Nasdaq'] / evabm['Nasdaq'][0] * 100 - 100
evabm['BM_KOSPI'] = evabm['KOSPI'] / evabm['KOSPI'][0] * 100 - 100

evabm['MY_BM'] = evabm['PROFIT%'] - evabm['PROFIT%'][0]

evabm.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EVA</th>        <th class="col_heading level0 col1" >CAP</th>        <th class="col_heading level0 col2" >PROFIT</th>        <th class="col_heading level0 col3" >PROFIT%</th>        <th class="col_heading level0 col4" >S&P500</th>        <th class="col_heading level0 col5" >Nasdaq</th>        <th class="col_heading level0 col6" >KOSPI</th>        <th class="col_heading level0 col7" >BM_SP500</th>        <th class="col_heading level0 col8" >BM_Nasdaq</th>        <th class="col_heading level0 col9" >BM_KOSPI</th>        <th class="col_heading level0 col10" >MY_BM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5level0_row0" class="row_heading level0 row0" >2021-12-10 00:00:00</th>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col0" class="data row0 col0" >20,600,000</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col1" class="data row0 col1" >20,600,000</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col4" class="data row0 col4" >4,712</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col5" class="data row0 col5" >15,630</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col6" class="data row0 col6" >3,010</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row0_col10" class="data row0 col10" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5level0_row1" class="row_heading level0 row1" >2022-04-01 00:00:00</th>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col0" class="data row1 col0" >21,051,723</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col1" class="data row1 col1" >21,350,000</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col2" class="data row1 col2" >-298,277</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col4" class="data row1 col4" >4,545</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col5" class="data row1 col5" >14,261</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col6" class="data row1 col6" >2,739</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col7" class="data row1 col7" >-4</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col8" class="data row1 col8" >-9</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col9" class="data row1 col9" >-9</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row1_col10" class="data row1 col10" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5level0_row2" class="row_heading level0 row2" >2022-04-08 00:00:00</th>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col0" class="data row2 col0" >21,002,620</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col1" class="data row2 col1" >21,350,000</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col2" class="data row2 col2" >-347,380</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col3" class="data row2 col3" >-2</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col4" class="data row2 col4" >4,488</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col5" class="data row2 col5" >13,711</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col6" class="data row2 col6" >2,700</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col7" class="data row2 col7" >-5</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col8" class="data row2 col8" >-12</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col9" class="data row2 col9" >-10</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row2_col10" class="data row2 col10" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5level0_row3" class="row_heading level0 row3" >2022-04-20 00:00:00</th>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col0" class="data row3 col0" >21,006,124</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col1" class="data row3 col1" >21,350,000</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col2" class="data row3 col2" >-343,876</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col3" class="data row3 col3" >-2</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col4" class="data row3 col4" >4,459</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col5" class="data row3 col5" >13,453</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col6" class="data row3 col6" >2,718</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col7" class="data row3 col7" >-5</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col8" class="data row3 col8" >-14</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col9" class="data row3 col9" >-10</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row3_col10" class="data row3 col10" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5level0_row4" class="row_heading level0 row4" >2022-04-26 00:00:00</th>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col0" class="data row4 col0" >20,810,643</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col1" class="data row4 col1" >21,600,000</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col2" class="data row4 col2" >-789,357</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col3" class="data row4 col3" >-4</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col4" class="data row4 col4" >4,175</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col5" class="data row4 col5" >12,490</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col6" class="data row4 col6" >2,668</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col7" class="data row4 col7" >-11</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col8" class="data row4 col8" >-20</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col9" class="data row4 col9" >-11</td>
#                         <td id="T_34ea42be_0cd5_11ed_a893_784f438ec1c5row4_col10" class

# %%
evabm[['MY_BM', 'BM_SP500', 'BM_Nasdaq', 'BM_KOSPI']].plot(marker='o', figsize=(12, 3))

# %% [markdown]
# ## Trading

# %%
position = pd.DataFrame(actions, columns=['DATE', 'TICKER', 'STOCKS', 'PRICE', 'ACCOUNT'])
# position.set_index('TICKER', inplace= True)

# 총 거래 가격. 현금 유출/유입으로 계산하므로 -1로 부호 반전
position['CAP'] = -1 * position.STOCKS * position.PRICE
# 매도 여부를 Boolean 형태로 별도 열 생성
position['SELL'] = position.STOCKS.apply(lambda x: True if x < 0 else False)

position.tail()
# Out:
#           DATE  TICKER  STOCKS  PRICE ACCOUNT      CAP   SELL
# 81  2022-07-21  379800      87  11530      MA -1003110  False
# 82  2022-07-21  379810      93  10730      MA  -997890  False
# 83  2022-07-21  278530      94  10620      MA  -998280  False
# 84  2022-07-21  241180      65  15490      MA -1006850  False
# 85  2022-07-21  169950      47  21200      MA  -996400  False

# %%
# 전체 거래횟수
print('Total Transaction:', len(position))
print('    Buy  ', len(position) - position.SELL.sum())
print('    Sell ', position.SELL.sum())

# 거래회전량 계산 - 매도기준
total_buy = position.loc[position.SELL == False, 'CAP'].sum() * -1
rotation_rate_buy = total_buy / eva.CAP[-1] * 100
rotation_days = (pd.Timestamp(position.DATE.iloc[-1]) - capital.index[0]).days

print('-----------------------')
print('  ')
print("Total BUY    ₩", f'{total_buy:,}')
print(" ")
print("Buy Rotation")
print("    {:.1f} %".format(rotation_rate_buy), "over", rotation_days, "days")
print("    {:.1f} %".format(rotation_rate_buy / rotation_days * 365), "/ year    (Target < 100%/year)")

total_sell = position.loc[position.SELL == True, 'CAP'].sum()
rotation_rate_sell = total_sell / eva.CAP[-1] * 100

print('-----------------------')
print('  ')
print("Total SELL    ₩", f'{total_sell:,}')
print(" ")
print("Sell Rotation")
print("    {:.1f} %".format(rotation_rate_sell), "over", rotation_days, "days")
print("    {:.1f} %".format(rotation_rate_sell / rotation_days * 365), "/ year   (Target < 30%/year)")


# rotation_per_year = rotation_rate / rotation_days * 365
# Out:
# Total Transaction: 86
#     Buy   59
#     Sell  27
# -----------------------
#
# Total BUY    ₩ 26,213,299
#
# Buy Rotation
#     34.7 % over 223 days
#     56.7 % / year    (Target < 100%/year)
# -----------------------
#
# Total SELL    ₩ 9,789,787
#
# Sell Rotation
#     12.9 % over 223 days
#     21.2 % / year   (Target < 30%/year)

# %%
# open - 보유 중인 계약, closed - 종료된 거래을 담기 위한 각각의 df 생성
open = pd.DataFrame(columns=['TICKER', 'STOCKS', 'INVEST', 'AVG_PRICE'])
closed = pd.DataFrame(columns=['TICKER', 'DATE', 'BUY', 'SELL', 'DELTA', 'PROFIT%', 'STOCKS', 'CAP_CHANGE'])

# postion df를 loop하면서 SELL여부를 기준으로 open/closed df에 이력 추가 및 계산
for i, row in position.iterrows():
  # 매도일 경우, 1) closed df에 이력 추가. 2) open df에서는 주식수만 삭감하며 투자금액은 기존 평균가로 재산출
  if row['SELL'] == True:
    # print(i, 'SELL', row['TICKER'], row['TICKER'], row['DATE'], row['PRICE'],row['STOCKS'])
    buy = -1 * int(open.loc[open.TICKER == row['TICKER'], 'AVG_PRICE'])
    delta =  row['PRICE'] - buy
    profitper = delta / buy * 100
    capchange = -1 * delta * row['STOCKS']
    closed.loc[len(closed)] = [row['TICKER'], row['DATE'], buy, row['PRICE'], delta, profitper, row['STOCKS'], capchange]
    # print(closed)
    open.loc[i] = [row['TICKER'], row['STOCKS'], row['CAP'], 0]
    open = open.groupby(['TICKER']).sum().reset_index()
    open = open[open.STOCKS != 0]
    open.INVEST = open.STOCKS * open.AVG_PRICE

  # 매수일 경우, 주식수/거래대금을 기재 후 종목으로 합산 후 평균가 재산출
  else:
    # print(i, 'BUY', row['TICKER'], row['STOCKS'], row['CAP'])
    open.loc[i] = [row['TICKER'], row['STOCKS'], row['CAP'], np.nan]
    open = open.groupby(['TICKER']).sum().reset_index()
    # open = open[open.STOCKS != 0]
    open['AVG_PRICE'] = open.INVEST / open.STOCKS
    # print(open)
    # print("***********")
    # print(" ")

# 용이성을 위해 종목명을 병기하고 열 순서 변경
tcknaming(closed)
closed = closed[['DATE', 'TICKER', 'NAME', 'BUY', 'SELL', 'DELTA', 'PROFIT%', 'STOCKS', 'CAP_CHANGE']]
for col in ['BUY', 'SELL', 'DELTA', 'STOCKS', 'CAP_CHANGE']:
    closed[col] = closed[col].astype('int')

tcknaming(open)
open = open[['TICKER', 'NAME', 'STOCKS', 'AVG_PRICE', 'INVEST']]

# %% [markdown]
# ## Closed Position

# %%
sell = position.loc[position.SELL == True].copy()
# tcknaming(sell)
# sell = sell[['DATE', 'TICKER', 'NAME', 'CAP', 'ACCOUNT']]

sellcap = sell[['DATE', 'CAP']].groupby(['DATE']).sum()
# sellcap.index = pd.to_datetime(sellcap.index)
sellcap.plot(kind= 'bar', figsize= (12, 3), title= 'Closed Position by Date - Million ₩')

# %%
sellcap.index = pd.to_datetime(sellcap.index)
sellcap_month = sellcap.groupby([lambda x: x.year, lambda x: x.month]).sum()
sellcap_month.plot(kind= 'bar', figsize= (12, 3), title= 'Closed Position by Month - Million ₩')

# %%
closed.tail(20).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >TICKER</th>        <th class="col_heading level0 col2" >NAME</th>        <th class="col_heading level0 col3" >BUY</th>        <th class="col_heading level0 col4" >SELL</th>        <th class="col_heading level0 col5" >DELTA</th>        <th class="col_heading level0 col6" >PROFIT%</th>        <th class="col_heading level0 col7" >STOCKS</th>        <th class="col_heading level0 col8" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5level0_row0" class="row_heading level0 row0" >7</th>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col0" class="data row0 col0" >2022-02-24</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col1" class="data row0 col1" >510006</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col2" class="data row0 col2" >대신 인버스 니켈선물 ETN(H)</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col3" class="data row0 col3" >3820</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col4" class="data row0 col4" >3360</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col5" class="data row0 col5" >-460</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col6" class="data row0 col6" >-12.0</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col7" class="data row0 col7" >-53</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row0_col8" class="data row0 col8" >-24,380</td>
#             </tr>
#             <tr>
#                         <th id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5level0_row1" class="row_heading level0 row1" >8</th>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col0" class="data row1 col0" >2022-02-24</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col1" class="data row1 col1" >360750</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col2" class="data row1 col2" >TIGER 미국S&P500</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col3" class="data row1 col3" >14141</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col4" class="data row1 col4" >12535</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col5" class="data row1 col5" >-1606</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col6" class="data row1 col6" >-11.4</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col7" class="data row1 col7" >-15</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row1_col8" class="data row1 col8" >-24,090</td>
#             </tr>
#             <tr>
#                         <th id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5level0_row2" class="row_heading level0 row2" >9</th>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col0" class="data row2 col0" >2022-02-24</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col1" class="data row2 col1" >133690</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col2" class="data row2 col2" >TIGER 미국나스닥100</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col3" class="data row2 col3" >85717</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col4" class="data row2 col4" >70930</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col5" class="data row2 col5" >-14787</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col6" class="data row2 col6" >-17.3</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col7" class="data row2 col7" >-5</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row2_col8" class="data row2 col8" >-73,935</td>
#             </tr>
#             <tr>
#                         <th id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5level0_row3" class="row_heading level0 row3" >10</th>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col0" class="data row3 col0" >2022-02-24</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col1" class="data row3 col1" >360750</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col2" class="data row3 col2" >TIGER 미국S&P500</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col3" class="data row3 col3" >14141</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col4" class="data row3 col4" >12552</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col5" class="data row3 col5" >-1589</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col6" class="data row3 col6" >-11.2</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col7" class="data row3 col7" >-21</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row3_col8" class="data row3 col8" >-33,369</td>
#             </tr>
#             <tr>
#                         <th id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5level0_row4" class="row_heading level0 row4" >11</th>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col0" class="data row4 col0" >2022-03-10</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col1" class="data row4 col1" >334690</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col2" class="data row4 col2" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col3" class="data row4 col3" >12090</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col4" class="data row4 col4" >16735</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col5" class="data row4 col5" >4645</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col6" class="data row4 col6" >38.4</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col7" class="data row4 col7" >-19</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row4_col8" class="data row4 col8" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5level0_row5" class="row_heading level0 row5" >12</th>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col0" class="data row5 col0" >2022-03-16</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col1" class="data row5 col1" >590018</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col2" class="data row5 col2" >미래에셋 중국 심천 100 ETN</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col3" class="data row5 col3" >20085</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col4" class="data row5 col4" >16243</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col5" class="data row5 col5" >-3842</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col6" class="data row5 col6" >-19.1</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col7" class="data row5 col7" >-15</td>
#                         <td id="T_35ccf23a_0cd5_11ed_a893_784f438ec1c5row5_col8" class="data row5 col8" >-57,630</td>
#             </tr>
#             <tr>

# %%
print('Total Closed Capital    ₩', f'{sell.CAP.sum():,}')
print('Total Closed Profit     ₩' ,f'{closed.CAP_CHANGE.sum():,}')
print('--------------------------')
print('Total Closed Profit     {:.1f} %'.format(closed.CAP_CHANGE.sum() / sell.CAP.sum() * 100))
# Out:
# Total Closed Capital    ₩ 9,789,787
# Total Closed Profit     ₩ -647,203
# --------------------------
# Total Closed Profit     -6.6 %

# %%
closed.DATE = pd.to_datetime(closed.DATE)
closed_month = closed.set_index('DATE').groupby([lambda x: x.year, lambda x: x.month]).sum()
closed_month
# Out:
#            BUY    SELL  DELTA    PROFIT%  STOCKS  CAP_CHANGE
# 2022 1  649869  604710 -45159 -37.875324     -38      -88928
#      2  203536  175677 -27859 -62.872867    -100     -212276
#      3   63834   62453  -1381  -2.294469    -198      -21996
#      5   20884   17190  -3694 -35.694233    -183     -342238
#      6   78312   78505    193   4.888787    -438       18235

# %%
closed_month['CAP_CHANGE'].plot(kind= 'bar', figsize= (12, 3), title= 'CLOSED - Monthlys PROFIT%')

# %%
closed_month['PROFIT%'].plot(kind= 'line', marker= 'o', figsize= (12, 3), title= 'CLOSED - Monthlys PROFIT%')

# %%
closed[['DATE', 'NAME', 'PROFIT%', 'CAP_CHANGE']].sort_values('CAP_CHANGE', ascending= False).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >NAME</th>        <th class="col_heading level0 col2" >PROFIT%</th>        <th class="col_heading level0 col3" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row0_col0" class="data row0 col0" >2022-03-10 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row0_col1" class="data row0 col1" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row0_col2" class="data row0 col2" >38.4</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row0_col3" class="data row0 col3" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row1_col0" class="data row1 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row1_col1" class="data row1 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row1_col2" class="data row1 col2" >17.4</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row1_col3" class="data row1 col3" >52,150</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row2" class="row_heading level0 row2" >22</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row2_col0" class="data row2 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row2_col1" class="data row2 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row2_col2" class="data row2 col2" >7.1</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row2_col3" class="data row2 col3" >39,468</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row3" class="row_heading level0 row3" >21</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row3_col0" class="data row3 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row3_col1" class="data row3 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row3_col2" class="data row3 col2" >17.4</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row3_col3" class="data row3 col3" >35,760</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row4" class="row_heading level0 row4" >24</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row4_col0" class="data row4 col0" >2022-06-23 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row4_col1" class="data row4 col1" >KBSTAR 미국S&P원유생산기업(합성 H)</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row4_col2" class="data row4 col2" >0.5</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row4_col3" class="data row4 col3" >4,500</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row5" class="row_heading level0 row5" >2</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row5_col0" class="data row5 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row5_col1" class="data row5 col1" >KODEX 200</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row5_col2" class="data row5 col2" >-1.5</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row5_col3" class="data row5 col3" >-1,184</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row6" class="row_heading level0 row6" >14</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row6_col0" class="data row6 col0" >2022-03-23 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row6_col1" class="data row6 col1" >TIGER 인버스</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row6_col2" class="data row6 col2" >-2.6</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row6_col3" class="data row6 col3" >-2,375</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row7" class="row_heading level0 row7" >3</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row7_col0" class="data row7 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row7_col1" class="data row7 col1" >맥쿼리인프라</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row7_col2" class="data row7 col2" >-2.5</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row7_col3" class="data row7 col3" >-2,450</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row8" class="row_heading level0 row8" >15</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row8_col0" class="data row8 col0" >2022-03-23 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row8_col1" class="data row8 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row8_col2" class="data row8 col2" >-0.9</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row8_col3" class="data row8 col3" >-3,666</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row9" class="row_heading level0 row9" >5</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row9_col0" class="data row9 col0" >2022-01-28 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row9_col1" class="data row9 col1" >SK하이닉스</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row9_col2" class="data row9 col2" >-7.0</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row9_col3" class="data row9 col3" >-9,000</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row10" class="row_heading level0 row10" >20</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row10_col0" class="data row10 col0" >2022-06-15 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row10_col1" class="data row10 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row10_col2" class="data row10 col2" >-14.0</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row10_col3" class="data row10 col3" >-10,693</td>
#             </tr>
#             <tr>
#                         <th id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5level0_row11" class="row_heading level0 row11" >0</th>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row11_col0" class="data row11 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row11_col1" class="data row11 col1" >삼성전자</td>
#                         <td id="T_360eddf8_0cd5_11ed_a893_784f438ec1c5row11_

# %%
closed[['NAME', 'CAP_CHANGE']].set_index('NAME').sort_values('CAP_CHANGE', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Closed Position - ₩')

# %%
closed[['DATE', 'NAME', 'PROFIT%', 'CAP_CHANGE']].sort_values('PROFIT%', ascending= False).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_3642a746_0cd5_11ed_a893_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >NAME</th>        <th class="col_heading level0 col2" >PROFIT%</th>        <th class="col_heading level0 col3" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row0_col0" class="data row0 col0" >2022-03-10 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row0_col1" class="data row0 col1" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row0_col2" class="data row0 col2" >38.4</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row0_col3" class="data row0 col3" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row1_col0" class="data row1 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row1_col1" class="data row1 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row1_col2" class="data row1 col2" >17.4</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row1_col3" class="data row1 col3" >52,150</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row2" class="row_heading level0 row2" >21</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row2_col0" class="data row2 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row2_col1" class="data row2 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row2_col2" class="data row2 col2" >17.4</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row2_col3" class="data row2 col3" >35,760</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row3" class="row_heading level0 row3" >22</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row3_col0" class="data row3 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row3_col1" class="data row3 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row3_col2" class="data row3 col2" >7.1</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row3_col3" class="data row3 col3" >39,468</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row4" class="row_heading level0 row4" >24</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row4_col0" class="data row4 col0" >2022-06-23 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row4_col1" class="data row4 col1" >KBSTAR 미국S&P원유생산기업(합성 H)</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row4_col2" class="data row4 col2" >0.5</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row4_col3" class="data row4 col3" >4,500</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row5" class="row_heading level0 row5" >15</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row5_col0" class="data row5 col0" >2022-03-23 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row5_col1" class="data row5 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row5_col2" class="data row5 col2" >-0.9</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row5_col3" class="data row5 col3" >-3,666</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row6" class="row_heading level0 row6" >2</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row6_col0" class="data row6 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row6_col1" class="data row6 col1" >KODEX 200</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row6_col2" class="data row6 col2" >-1.5</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row6_col3" class="data row6 col3" >-1,184</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row7" class="row_heading level0 row7" >0</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row7_col0" class="data row7 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row7_col1" class="data row7 col1" >삼성전자</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row7_col2" class="data row7 col2" >-2.0</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row7_col3" class="data row7 col3" >-10,794</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row8" class="row_heading level0 row8" >19</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row8_col0" class="data row8 col0" >2022-06-13 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row8_col1" class="data row8 col1" >TRUE S&P500 양매도 4% OTM ETN(H)</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row8_col2" class="data row8 col2" >-2.0</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row8_col3" class="data row8 col3" >-20,160</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row9" class="row_heading level0 row9" >3</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row9_col0" class="data row9 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row9_col1" class="data row9 col1" >맥쿼리인프라</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row9_col2" class="data row9 col2" >-2.5</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row9_col3" class="data row9 col3" >-2,450</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row10" class="row_heading level0 row10" >14</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row10_col0" class="data row10 col0" >2022-03-23 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row10_col1" class="data row10 col1" >TIGER 인버스</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row10_col2" class="data row10 col2" >-2.6</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row10_col3" class="data row10 col3" >-2,375</td>
#             </tr>
#             <tr>
#                         <th id="T_3642a746_0cd5_11ed_a893_784f438ec1c5level0_row11" class="row_heading level0 row11" >5</th>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row11_col0" class="data row11 col0" >2022-01-28 00:00:00</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438ec1c5row11_col1" class="data row11 col1" >SK하이닉스</td>
#                         <td id="T_3642a746_0cd5_11ed_a893_784f438e

# %%
closed[['NAME', 'PROFIT%']].set_index('NAME').sort_values('PROFIT%', ascending= False).plot(kind= 'bar', figsize= (12, 4))

# %% [markdown]
# ## Open Position

# %%
market = open.copy()
market[['AVG_PRICE', 'INVEST']] = market[['AVG_PRICE', 'INVEST']].astype('int')

marketprice = []

for tk in market.TICKER.to_list():
    tk_yahoo = yf.Ticker(tk + '.KS')
    data = tk_yahoo.history().tail(1)['Close'].iloc[0]
    marketprice.append(data)

# CV: 현재평가액 = 현재가 x 보유수, EVA: 평가증감 = 포지션 - 현재평가액
market['MARKET_PRICE'] = marketprice
market['CV'] = market.MARKET_PRICE * market.STOCKS
market['PROFIT'] = market.CV + market.INVEST
market['PROFIT%'] = market.PROFIT / market.INVEST * -100

# %%
print('Current Portfolio Total')
print('-----------------------------')
print('Values    ₩', f'{int(market.CV.sum()):,}')
print('Profit    ₩', f'{int(market.PROFIT.sum()):,}')
print('Profit%   {:.2f} %'.format(market.PROFIT.sum() / market.INVEST.sum() * -100))
# Out:
# Current Portfolio Total
# -----------------------------
# Values    ₩ 15,537,050
# Profit    ₩ -239,013
# Profit%   -1.52 %

# %%
colformat = {"PROFIT%": "{:,.1f}", 
             "AVG_PRICE": "{:,.0f}", "INVEST": "{:,.0f}", "MARKET_PRICE": "{:,.0f}", 
             "CV": "{:,.0f}", "PROFIT": "{:,.0f}"}
market.style.format(colformat)

# 현재 평가액이 큰 순서대로 배열
market.sort_values(by=['CV'], ascending= False, ignore_index=False)
# Out:
#     TICKER                    NAME  STOCKS  AVG_PRICE   INVEST  MARKET_PRICE  \
# 12  371460   TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960       16460.0
# 8   278530             KODEX 200TR     104     -10625 -1105030       10685.0
# 14  379800        KODEX 미국S&P500TR      96     -11530 -1106880       11505.0
# 15  379810        KODEX 미국나스닥100TR     103     -10730 -1105190       10600.0
# 10  332610       ARIRANG 미국단기우량회사채      10    -102840 -1028400      107770.0
# 13  373790       KOSEF 미국방어배당성장나스닥      77     -12950  -997150       13525.0
# 5   241180          TIGER 일본니케이225      65     -15490 -1006850       15560.0
# 4   169950            KODEX 차이나A50      47     -21200  -996400       21180.0
# 2   139280              TIGER 경기방어      99     -10130 -1002870        9725.0
# 6   266410             KODEX 필수소비재     127      -7910 -1004570        7280.0
# 9   329200          TIGER 리츠부동산인프라     154      -6495 -1000230        5375.0
# 3   157490             TIGER 소프트웨어      70     -14325 -1002750       10305.0
# 22  530020        삼성 미국 대형 가치주 ETN      33     -17723  -584873       18035.0
# 19  510004      대신 인버스 아연선물 ETN(H)      74      -6450  -477300        7270.0
# 20  510006      대신 인버스 니켈선물 ETN(H)     289      -1735  -501415        1850.0
# 21  510018   대신 인버스 알루미늄 선물 ETN(H)      50      -9960  -498000       10205.0
# 18  500014    신한 인버스 옥수수 선물 ETN(H)      72      -6326  -455472        6975.0
# 17  409810  KODEX 미국나스닥100선물인버스(H)      37     -12563  -464843       12505.0
# 11  360750          TIGER 미국S&P500      18     -13670  -246060       13030.0
# 16  394350   KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856        9855.0
# 1   133690          TIGER 미국나스닥100       1     -82580   -82580       71975.0
# 0   123310               TIGER 인버스       1      -4895    -4895        5370.0
# 7   271050     KODEX WTI원유선물인버스(H)       1      -4489    -4489        4330.0
#
#            CV    PROFIT    PROFIT%
# 12  1119280.0  118320.0  11.820652
# 8   1111240.0    6210.0   0.561976
# 14  1104480.0   -2400.0  -0.216826
# 15  1091800.0  -13390.0  -1.211556
# 10  1077700.0   49300.0   4.793855
# 13  1041425.0   44275.0   4.440154
# 5   1011400.0    4550.0   0.451904
# 4    995460.0    -940.0  -0.094340
# 2    962775.0  -40095.0  -3.998026
# 6    924560.0  -80010.0  -7.964602
# 9    827750.0 -172480.0 -17.244034
# 3    721350.0 -281400.0 -28.062827
# 22   595155.0   10282.0   1.757988
# 19   537980.0   60680.0  12.713178
# 20   534650.0   33235.0   6.628242
# 21   510250.0   12250.0   2.459839
# 18   502200.0   46728.0  10.259248
# 17   462685.0   -2158.0  -0.464243
# 11   234540.0  -11520.0  -4.681785
# 16    88695.0  -10161.0 -10.278587
# 1     71975.0  -10605.0 -12.842093
# 0      5370.0     475.0   9.703779
# 7      4330.0    -159.0  -3.541992

# %%
market[['NAME', 'CV']].set_index('NAME').sort_values('CV', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by CV ₩')

# %%
# 투자수익이 큰 순서대로 배열
market.sort_values(by=['PROFIT'], ascending= False, ignore_index=False)
# Out:
#     TICKER                    NAME  STOCKS  AVG_PRICE   INVEST  MARKET_PRICE  \
# 12  371460   TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960       16460.0
# 19  510004      대신 인버스 아연선물 ETN(H)      74      -6450  -477300        7270.0
# 10  332610       ARIRANG 미국단기우량회사채      10    -102840 -1028400      107770.0
# 18  500014    신한 인버스 옥수수 선물 ETN(H)      72      -6326  -455472        6975.0
# 13  373790       KOSEF 미국방어배당성장나스닥      77     -12950  -997150       13525.0
# 20  510006      대신 인버스 니켈선물 ETN(H)     289      -1735  -501415        1850.0
# 21  510018   대신 인버스 알루미늄 선물 ETN(H)      50      -9960  -498000       10205.0
# 22  530020        삼성 미국 대형 가치주 ETN      33     -17723  -584873       18035.0
# 8   278530             KODEX 200TR     104     -10625 -1105030       10685.0
# 5   241180          TIGER 일본니케이225      65     -15490 -1006850       15560.0
# 0   123310               TIGER 인버스       1      -4895    -4895        5370.0
# 7   271050     KODEX WTI원유선물인버스(H)       1      -4489    -4489        4330.0
# 4   169950            KODEX 차이나A50      47     -21200  -996400       21180.0
# 17  409810  KODEX 미국나스닥100선물인버스(H)      37     -12563  -464843       12505.0
# 14  379800        KODEX 미국S&P500TR      96     -11530 -1106880       11505.0
# 16  394350   KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856        9855.0
# 1   133690          TIGER 미국나스닥100       1     -82580   -82580       71975.0
# 11  360750          TIGER 미국S&P500      18     -13670  -246060       13030.0
# 15  379810        KODEX 미국나스닥100TR     103     -10730 -1105190       10600.0
# 2   139280              TIGER 경기방어      99     -10130 -1002870        9725.0
# 6   266410             KODEX 필수소비재     127      -7910 -1004570        7280.0
# 9   329200          TIGER 리츠부동산인프라     154      -6495 -1000230        5375.0
# 3   157490             TIGER 소프트웨어      70     -14325 -1002750       10305.0
#
#            CV    PROFIT    PROFIT%
# 12  1119280.0  118320.0  11.820652
# 19   537980.0   60680.0  12.713178
# 10  1077700.0   49300.0   4.793855
# 18   502200.0   46728.0  10.259248
# 13  1041425.0   44275.0   4.440154
# 20   534650.0   33235.0   6.628242
# 21   510250.0   12250.0   2.459839
# 22   595155.0   10282.0   1.757988
# 8   1111240.0    6210.0   0.561976
# 5   1011400.0    4550.0   0.451904
# 0      5370.0     475.0   9.703779
# 7      4330.0    -159.0  -3.541992
# 4    995460.0    -940.0  -0.094340
# 17   462685.0   -2158.0  -0.464243
# 14  1104480.0   -2400.0  -0.216826
# 16    88695.0  -10161.0 -10.278587
# 1     71975.0  -10605.0 -12.842093
# 11   234540.0  -11520.0  -4.681785
# 15  1091800.0  -13390.0  -1.211556
# 2    962775.0  -40095.0  -3.998026
# 6    924560.0  -80010.0  -7.964602
# 9    827750.0 -172480.0 -17.244034
# 3    721350.0 -281400.0 -28.062827

# %%
market[['NAME', 'PROFIT']].set_index('NAME').sort_values('PROFIT', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by Profit ₩')

# %%
market[['NAME', 'PROFIT%']].set_index('NAME').sort_values('PROFIT%', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by Profit%')

# %% [markdown]
# ## Trend - Closed

# %%
today = datetime.today()

start = (today + timedelta(days= -180)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

# start = datetime.now() - relativedelta(days=7)
# end = datetime.now()

# %%
for i, row in closed.iterrows():
    try:
        data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        print('***', row.NAME, '***')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
#                 y = data.loc[data.index == prow.DATE, 'Close'].item()
                y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY '
                print('  ', sb, prow.DATE, prow.PRICE, stocks)
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        print('   PV             ', int(data.Close[-1]))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** 삼성전자 ***
#    PV              61700
# *** NAVER ***
#    PV              245000
# *** KODEX 200 ***
#    PV              32095
# *** 맥쿼리인프라 ***
#    PV              12650
# *** KODEX 미국메타버스나스닥액티브 ***
#    PV              6850
# *** SK하이닉스 ***
#    SELL 2022-01-28 119500 -1
#    PV              100500
# *** TIGER 미국나스닥100 ***
#    SELL 2022-02-14 76300 -6
#    SELL 2022-02-24 70930 -5
#    BUY  2022-03-30 82580 1
#    PV              71975
# *** 대신 인버스 니켈선물 ETN(H) ***
#    BUY  2022-01-28 3820 53
#    SELL 2022-02-24 3360 -53
#    BUY  2022-06-23 1735 289
#    PV              1850
# *** TIGER 미국S&P500 ***
#    SELL 2022-02-24 12535 -15
#    SELL 2022-02-24 12552 -21
#    BUY  2022-03-04 13225 9
#    BUY  2022-03-30 14115 9
#    PV              13030
# *** TIGER 미국나스닥100 ***
#    SELL 2022-02-14 76300 -6
#    SELL 2022-02-24 70930 -5
#    BUY  2022-03-30 82580 1
#    PV              71975
# *** TIGER 미국S&P500 ***
#    SELL 2022-02-24 12535 -15
#    SELL 2022-02-24 12552 -21
#    BUY  2022-03-04 13225 9
#    BUY  2022-03-30 14115 9
#    PV              13030
# *** KBSTAR 팔라듐선물(H) ***
#    SELL 2022-03-10 16735 -19
#    PV              11260
# *** 미래에셋 중국 심천 100 ETN ***
#    SELL 2022-03-16 16243 -15
#    PV              17765
# *** ARIRANG 신흥국MSCI(합성 H) ***
#    BUY  2022-03-04 11045 11
#    SELL 2022-03-16 9865 -11
#    PV              9440
# *** TIGER 인버스 ***
#    BUY  2022-03-14 4895 20
#    SELL 2022-03-23 4770 -19
#    PV              5370
# *** KODEX WTI원유선물인버스(H) ***
#    BUY  2022-02-15 5835 17
#    BUY  2022-03-07 4249 95
#    SELL 2022-03-23 4450 -94
#    SELL 2022-06-15 3860 -17
#    PV              4330
# *** KODEX 미국나스닥100선물인버스(H) ***
#    BUY  2022-02-14 11230 41
#    SELL 2022-03-30 10390 -40
#    BUY  2022-05-17 12580 80
#    SELL 2022-06-21 13460 -44
#    PV              12505
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***
#    BUY  2022-03-30 10984 91
#    SELL 2022-05-12 9360 -82
#    PV              9855
# *** TIGER 글로벌클라우드컴퓨팅INDXX ***
#    BUY  2022-03-30 9900 101
#    SELL 2022-05-12 7830 -101
#    PV              8100
# *** TRUE S&P500 양매도 4% OTM ETN(H) ***
#    BUY  2022-03-14 11670 17
#    BUY  2022-03-30 11715 25
#    BUY  2022-04-29 11865 42
#    SELL 2022-06-13 11540 -84
#    PV              11640
# *** KODEX WTI원유선물인버스(H) ***
#    BUY  2022-02-15 5835 17
#    BUY  2022-03-07 4249 95
#    SELL 2022-03-23 4450 -94
#    SELL 2022-06-15 3860 -17
#    PV              4330
# *** 신한 S&P500 VIX S/T 선물 ETN C ***
#    BUY  2022-06-09 8550 24
#    BUY  2022-06-09 8560 35
#    SELL 2022-06-21 10045 -24
#    SELL 2022-06-21 10045 -35
#    PV              8445
# *** KODEX 미국나스닥100선물인버스(H) ***
#    BUY  2022-02-14 11230 41
#    SELL 2022-03-30 10390 -40
#    BUY  2022-05-17 12580 80
#    SELL 2022-06-21 13460 -44
#    PV              12505
# *** 신한 S&P500 VIX S/T 선물 ETN C ***
#    BUY  2022-06-09 8550 24
#    BUY  2022-06-09 8560 35
#    SELL 2022-06-21 10045 -24
#    SELL 2022-06-21 10045 -35
#    PV              8445
# *** KBSTAR 미국S&P원유생산기업(합성 H) ***
#    BUY  2022-03-14 5545 180
#    SELL 2022-06-23 5570 -180
#    PV              5905
# *** KODEX 미국S&P에너지(합성) ***
#    BUY  2022-06-15 12555 40
#    SELL 2022-06-23 10900 -40
#    PV              11210
# *** TIGER 골드선물(H) ***
#    BUY  2022-03-14 14270 14
#    SELL 2022-06-29 13085 -14
#    PV              12350

# %% [markdown]
# ## Trend - Open

# %%
for i, row in open.iterrows():
    try:
        data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        print('***', row.NAME, '***')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
#                 y = data.loc[data.index == prow.DATE, 'Close'].item()
                y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY '
                print('  ', sb, prow.DATE, prow.PRICE, stocks)
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** TIGER 인버스 ***
#    BUY  2022-03-14 4895 20
#    SELL 2022-03-23 4770 -19
# *** TIGER 미국나스닥100 ***
#    SELL 2022-02-14 76300 -6
#    SELL 2022-02-24 70930 -5
#    BUY  2022-03-30 82580 1
# *** TIGER 경기방어 ***
#    BUY  2022-03-30 10130 99
# *** TIGER 소프트웨어 ***
#    BUY  2022-03-30 14325 70
# *** KODEX 차이나A50 ***
#    BUY  2022-07-21 21200 47
# *** TIGER 일본니케이225 ***
#    BUY  2022-07-21 15490 65
# *** KODEX 필수소비재 ***
#    BUY  2022-03-23 7910 127
# *** KODEX WTI원유선물인버스(H) ***
#    BUY  2022-02-15 5835 17
#    BUY  2022-03-07 4249 95
#    SELL 2022-03-23 4450 -94
#    SELL 2022-06-15 3860 -17
# *** KODEX 200TR ***
#    BUY  2022-07-21 10675 10
#    BUY  2022-07-21 10620 94
# *** TIGER 리츠부동산인프라 ***
#    BUY  2022-04-21 6495 154
# *** ARIRANG 미국단기우량회사채 ***
#    BUY  2022-03-14 102840 10
# *** TIGER 미국S&P500 ***
#    SELL 2022-02-24 12535 -15
#    SELL 2022-02-24 12552 -21
#    BUY  2022-03-04 13225 9
#    BUY  2022-03-30 14115 9
# *** TIGER 차이나전기차SOLACTIVE ***
#    BUY  2022-03-30 14720 68
# *** KOSEF 미국방어배당성장나스닥 ***
#    BUY  2022-03-14 12950 77
# *** KODEX 미국S&P500TR ***
#    BUY  2022-07-21 11530 9
#    BUY  2022-07-21 11530 87
# *** KODEX 미국나스닥100TR ***
#    BUY  2022-07-21 10730 10
#    BUY  2022-07-21 10730 93
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***
#    BUY  2022-03-30 10984 91
#    SELL 2022-05-12 9360 -82
# *** KODEX 미국나스닥100선물인버스(H) ***
#    BUY  2022-02-14 11230 41
#    SELL 2022-03-30 10390 -40
#    BUY  2022-05-17 12580 80
#    SELL 2022-06-21 13460 -44
# *** 신한 인버스 옥수수 선물 ETN(H) ***
#    BUY  2022-06-24 6326 72
# *** 대신 인버스 아연선물 ETN(H) ***
#    BUY  2022-06-24 6450 74
# *** 대신 인버스 니켈선물 ETN(H) ***
#    BUY  2022-01-28 3820 53
#    SELL 2022-02-24 3360 -53
#    BUY  2022-06-23 1735 289
# *** 대신 인버스 알루미늄 선물 ETN(H) ***
#    BUY  2022-06-23 9960 50
# *** 삼성 미국 대형 가치주 ETN ***
#    BUY  2022-06-15 17775 17

# %% [markdown]
# ## Trend with Benchmark

# %%
# KODEX200 : 069500, TIGER 미국S&P500 : 360750, TIGER 미국나스닥100 : 133690

kospi = web.naver.NaverDailyReader('069500', start= start, end= end).read().astype('int')
kospi = kospi / kospi.Close[0] * 100

sp500 = web.naver.NaverDailyReader('360750', start= start, end= end).read().astype('int')
sp500 = sp500 / sp500.Close[0] * 100

# %%
for i, row in open.iterrows():
    try:
        record = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        data = record / record.Close[0] * 100
        
        if ticker[row.TICKER][1] == 'KR':
            apdict = mpf.make_addplot(kospi.Close, type='line')
            bmindex = 'KOSPI'
        else:
            apdict = mpf.make_addplot(sp500.Close)
            bmindex = 'S&P500'
            
        print(row.NAME, ' vs.', bmindex, '(Benchmark)')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, addplot= apdict)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
                y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY'
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))

        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# TIGER 인버스  vs. KOSPI (Benchmark)
# TIGER 미국나스닥100  vs. S&P500 (Benchmark)
# TIGER 경기방어  vs. KOSPI (Benchmark)
# TIGER 소프트웨어  vs. KOSPI (Benchmark)
# KODEX 차이나A50  vs. KOSPI (Benchmark)
# TIGER 일본니케이225  vs. S&P500 (Benchmark)
# KODEX 필수소비재  vs. KOSPI (Benchmark)
# KODEX WTI원유선물인버스(H)  vs. S&P500 (Benchmark)
# KODEX 200TR  vs. KOSPI (Benchmark)
# TIGER 리츠부동산인프라  vs. KOSPI (Benchmark)
# ARIRANG 미국단기우량회사채  vs. S&P500 (Benchmark)
# TIGER 미국S&P500  vs. S&P500 (Benchmark)
# TIGER 차이나전기차SOLACTIVE  vs. S&P500 (Benchmark)
# KOSEF 미국방어배당성장나스닥  vs. S&P500 (Benchmark)
# KODEX 미국S&P500TR  vs. S&P500 (Benchmark)
# KODEX 미국나스닥100TR  vs. S&P500 (Benchmark)
# KOSEF 릭소글로벌퓨처모빌리티MSCI  vs. S&P500 (Benchmark)
# KODEX 미국나스닥100선물인버스(H)  vs. S&P500 (Benchmark)
# 신한 인버스 옥수수 선물 ETN(H)  vs. S&P500 (Benchmark)
# 대신 인버스 아연선물 ETN(H)  vs. S&P500 (Benchmark)
# 대신 인버스 니켈선물 ETN(H)  vs. S&P500 (Benchmark)
# 대신 인버스 알루미늄 선물 ETN(H)  vs. S&P500 (Benchmark)
# 삼성 미국 대형 가치주 ETN  vs. S&P500 (Benchmark)
