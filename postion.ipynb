# %% [markdown]
# ## Input and Preparation

# %%
### 매주 입력 필요

# 투자금 변화 입력
list_capital = [
    ['2021-12-10', 1500000, 2000000, 0, 17100000, 0],
    ['2022-03-21', 1500000, 2000000, 750000, 17100000, 0],
    ['2022-04-21', 1500000, 2000000, 1000000, 17100000, 0], 
    ['2022-05-11', 1500000, 2000000, 1000000, 17100000, 51411787], 
    ['2022-05-14', 2000000, 2000000, 1000000, 17100000, 51411787],
    ['2022-05-21', 2000000, 2000000, 1250000, 17100000, 51853487],
    ['2022-06-21', 2000000, 2000000, 1500000, 17100000, 52295187],
    ['2022-07-21', 2000000, 2000000, 1750000, 17100000, 52769107],
    ['2022-08-21', 2000000, 2000000, 2000000, 17100000, 53243027],
    ['2022-09-21', 2000000, 2000000, 2250000, 17100000, 53716937],
    ['2022-10-21', 2000000, 2000000, 2500000, 17100000, 54190867],
    ['2022-11-21', 2000000, 2000000, 2750000, 17100000, 54664787]
]

# 주차별 자산평가액 입력
list_eva = [
    ['2021-12-10', 1500000, 2000000, 0, 17100000, 0],
    ['2022-04-01', 1320963, 1815919, 745075, 17169766, 0],
    ['2022-04-08', 1328128, 1824105, 739964, 17110423, 0],
    ['2022-04-20', 1306232, 1843025, 734283, 17122584, 0],
    ['2022-04-26', 1300044, 1825530, 974443, 16710626, 0],
    ['2022-05-04', 1297685, 1810670, 973821, 16818596, 0],
    ['2022-05-11', 1280706, 1787935, 963967, 16557094, 51411787],
    ['2022-05-18', 1747918, 1792125, 963923, 16606513, 51853487],
    ['2022-05-25', 1803813, 1768880, 1203089, 16567673, 51853487],
    ['2022-06-01', 1719094, 1759435, 1218145, 16809988, 51853487],
    ['2022-06-08', 1720456, 1767500, 1215795, 16921678, 51853487],
    ['2022-06-15', 1894061, 1843039, 1199774, 16718468, 51853487],
    ['2022-06-22', 1860821, 1763385, 1446383, 16483969, 52295187],
    ['2022-06-29', 1849339, 1805846, 1460028, 16608526, 52295187],
    ['2022-07-06', 1925886, 1856331, 1457095, 16564777, 52295187],
    ['2022-07-12', 1889401, 1880419, 1461671, 16486370, 52295187],
    ['2022-07-20', 1897198, 1913519, 1462364, 16516645, 52295187],
    ['2022-07-26', 1889500, 1861224, 1721987, 16491020, 52791059],
    ['2022-08-10', 1831948, 1804432, 1750602, 16656457, 52876329],
    ['2022-08-21', 1832843, 1766612, 2021934, 16689561, 53529599],
    ['2022-08-24', 1818083, 1861257, 2008247, 16636641, 53427984],
    ['2022-08-31', 1829822, 1867367, 1998334, 16528521, 53344304],
    ['2022-09-17', 1842738, 1823766, 2001200, 16416279, 53240334],
    ['2022-09-27', 1853692, 1793406, 2219034, 16241586, 53382579],
    ['2022-10-06', 1850421, 1817166, 2230513, 16141623, 53580684],
    ['2022-11-11', 1835677, 1827352, 2460247, 16046844, 53914437],
    ['2022-11-24', 1830185, 1848967, 2761536, 16124193, 54580032]
]

# 종목 정보 - 신규 종목 매수 시, 별도 지정 필요
ticker = {
    '005930': ['삼성전자', 'KR', 'STOCK'],
    '000660': ['SK하이닉스',  'KR',  'STOCK'],
    '035420': ['NAVER',  'KR',  'STOCK'],
    '069500': ['KODEX 200',  'KR',  'ETF'],
    '088980': ['맥쿼리인프라',  'KR',  'STOCK'],
    '123310': ['TIGER 인버스',  'KR',  'ETF'],
    '133690': ['TIGER 미국나스닥100',  'US',  'ETF'],
    '139280': ['TIGER 경기방어',  'KR',  'ETF'],
    '157490': ['TIGER 소프트웨어',  'KR',  'ETF'],
    '169950': ['KODEX 차이나A50', 'KR', 'ETF'],
    '195980': ['ARIRANG 신흥국MSCI(합성 H)',  'Global',  'ETF'],
    '218420': ['KODEX 미국S&P에너지(합성)', 'US', 'Commodity'],
    '219390': ['KBSTAR 미국S&P원유생산기업(합성 H)',  'US',  'Commodity'],
    '241180': ['TIGER 일본니케이225', 'JP', 'ETF'],
    '266410': ['KODEX 필수소비재',  'KR',  'ETF'],
    '271050': ['KODEX WTI원유선물인버스(H)',  'Global',  'Commodity'],
    '278530': ['KODEX 200TR', 'KR', 'ETF'],
    '319640': ['TIGER 골드선물(H)',  'Global',  'Commodity'],
    '329200': ['TIGER 리츠부동산인프라', 'KR', 'RealEstate'],
    '334690': ['KBSTAR 팔라듐선물(H)',  'Global',  'Commodity'],
    '332610': ['ARIRANG 미국단기우량회사채',  'US',  'Bond'],
    '360750': ['TIGER 미국S&P500',  'US',  'ETF'],
    '371450': ['TIGER 글로벌클라우드컴퓨팅INDXX',  'US',  'ETF'],
    '371460': ['TIGER 차이나전기차SOLACTIVE',  'CN',  'ETF'],
    '373790': ['KOSEF 미국방어배당성장나스닥',  'US',  'ETF'],
    '379800': ['KODEX 미국S&P500TR', 'US', 'ETF'],
    '379810': ['KODEX 미국나스닥100TR', 'US', 'ETF'],
    '394350': ['KOSEF 릭소글로벌퓨처모빌리티MSCI',  'Global',  'ETF'],
    '409810': ['KODEX 미국나스닥100선물인버스(H)',  'US',  'ETF'],
    '411420': ['KODEX 미국메타버스나스닥액티브',  'US',  'ETF'],
    '500014': ['신한 인버스 옥수수 선물 ETN(H)',  'Global',  'Commodity'],
    '500058': ['신한 S&P500 VIX S/T 선물 ETN C', 'US', 'ETF'],
    '510004': ['대신 인버스 아연선물 ETN(H)',  'Global',  'Commodity'],
    '510006': ['대신 인버스 니켈선물 ETN(H)',  'Global',  'Commodity'],
    '510018': ['대신 인버스 알루미늄 선물 ETN(H)',  'Global',  'Commodity'],
    '530020': ['삼성 미국 대형 가치주 ETN',  'US',  'ETF'],
    '570049': ['TRUE S&P500 양매도 4% OTM ETN(H)',  'US',  'ETF'],
    '590018': ['미래에셋 중국 심천 100 ETN',  'CN',  'ETF']
}

# 일자, Ticker, 주식수, 체결가격, Bank account
# Price: 매수+, 매도-
actions = [
    ['2021-12-13', '005930', 1, 77100, '14'],
    ['2021-12-13', '069500', 2, 40027, '14'],
    ['2020-12-13', '360750', 7, 14028, '14'],
    ['2021-12-21', '005930', 2, 78200, '14'],
    ['2021-12-22', '000660', 1, 128500, '14'],
    ['2021-12-22', '005930', 2, 79100, '14'],
    ['2021-12-22', '035420', 1, 378000, '14'],
    ['2021-12-23', '088980', 7, 14150, '14'],
    ['2021-12-23', '133690', 3, 86165, '01'],
    ['2021-12-24', '005930', 2, 80800, '14'],
    ['2021-12-24', '133690', 3, 86600, '01'],
    ['2021-12-24', '360750', 15, 14125, '01'],
    ['2022-01-03', '411420', 20, 10150, '01'],
    ['2022-01-04', '530020', 9, 17512, '14'],
    ['2022-01-06', '133690', 5, 84920, '14'],
    ['2022-01-06', '530020', 7, 17870, '14'],
    ['2022-01-06', '590018', 15, 20085, '14'],
    ['2022-01-06', '360750', 14, 14215, '14'],
    ['2022-01-06', '005930', -7, 77500, '14'],
    ['2022-01-06', '035420', -1, 346000, '14'],
    ['2022-01-06', '069500', -2, 39435, '14'],
    ['2022-01-06', '088980', -7, 13800, '14'],
    ['2022-01-24', '334690', 19, 12090, '01'],
    ['2022-01-24', '411420', -20, 8475, '01'],
    ['2022-01-28', '510006', 53, 3820, '01'],
    ['2022-01-28', '000660', -1, 119500, '14'],
    ['2022-02-14', '409810', 41, 11230, '01'],
    ['2022-02-14', '133690', -6, 76300, '01'],
    ['2022-02-15', '271050', 17, 5835, '01'],
    ['2022-02-24', '510006', -53, 3360, '01'],
    ['2022-02-24', '360750', -15, 12535, '01'],
    ['2022-02-24', '133690', -5, 70930, '14'],
    ['2022-02-24', '360750', -21, 12552, '14'],
    ['2022-03-04', '195980', 11, 11045, '29'],
    ['2022-03-04', '360750', 9, 13225, '29'],
    ['2022-03-07', '271050', 95, 4249, '14'],
    ['2022-03-10', '334690', -19, 16735, '01'],
    ['2022-03-14', '319640', 14, 14270, '14'],
    ['2022-03-14', '570049', 17, 11670, '14'],
    ['2022-03-14', '123310', 20, 4895, '01'],
    ['2022-03-14', '219390', 180, 5545, '28'],
    ['2022-03-14', '332610', 10, 102840, '28'],
    ['2022-03-14', '373790', 77, 12950, '28'],
    ['2022-03-16', '590018', -15, 16243, '14'],
    ['2022-03-16', '195980', -11, 9865, '29'],
    ['2022-03-23', '123310', -19, 4770, '01'],
    ['2022-03-23', '271050', -94, 4450, '14'],
    ['2022-03-23', '266410', 127, 7910, '28'],
    ['2022-03-30', '409810', -40, 10390, '01'],
    ['2022-03-30', '570049', 25, 11715, '14'],
    ['2022-03-30', '360750', 9, 14115, '29'],
    ['2022-03-30', '133690', 1, 82580, '29'],
    ['2022-03-30', '139280', 99, 10130, '28'],
    ['2022-03-30', '371450', 101, 9900, '28'],
    ['2022-03-30', '157490', 70, 14325, '28'],
    ['2022-03-30', '394350', 91, 10984, '28'],
    ['2022-03-30', '371460', 68, 14720, '28'],
    ['2022-04-21', '329200', 154, 6495, '28'],
    ['2022-04-29', '570049', 42, 11865, '14'],
    ['2022-05-12', '394350', -82, 9360, '28'],
    ['2022-05-12', '371450', -101, 7830, '28'],
    ['2022-05-17', '409810', 80, 12580, '01'],
    ['2022-06-09', '500058', 24, 8550, '01'],
    ['2022-06-09', '500058', 35, 8560, '14'],
    ['2022-06-13', '570049', -84, 11540, '14'],
    ['2022-06-15', '218420', 40, 12555, '14'],
    ['2022-06-15', '530020', 17, 17775, '14'],
    ['2022-06-15', '271050', -17, 3860, '01'],
    ['2022-06-21', '500058', -24, 10045, '01'],
    ['2022-06-21', '409810', -44, 13460, '01'],
    ['2022-06-21', '500058', -35, 10045, '14'],
    ['2022-06-23', '219390', -180, 5570, '28'],
    ['2022-06-23', '218420', -40, 10900, '14'],
    ['2022-06-23', '510006', 289, 1735, '14'],
    ['2022-06-23', '510018', 50, 9960, '01'],
    ['2022-06-24', '510004', 74, 6450, '14'],
    ['2022-06-24', '500014', 72, 6326, '01'],
    ['2022-06-29', '319640', -14, 13085, '14'],
    ['2022-07-21', '278530', 10, 10675, '29'],
    ['2022-07-21', '379800', 9, 11530, '29'],
    ['2022-07-21', '379810', 10, 10730, '29'],
    ['2022-07-21', '379800', 87, 11530, 'MA'],
    ['2022-07-21', '379810', 93, 10730, 'MA'],
    ['2022-07-21', '278530', 94, 10620, 'MA'],
    ['2022-07-21', '241180', 65, 15490, 'MA'],
    ['2022-07-21', '169950', 47, 21200, 'MA'],
    ['2022-07-27', '123310', -1, 5390, '01'],
    ['2022-07-27', '271050', -1, 4435, '14'],
    ['2022-08-10', '500014', -6, 6710, '01'],
    ['2022-08-10', '510018', -1, 10030, '01'],
    ['2022-08-10', '510004', -74, 6170, '14'],
    ['2022-08-10', '510006', -289, 1885, '14'],
    ['2022-08-10', '500058', 130, 7690, '14'],
    ['2022-09-08', '500014', -7, 6090, '01'],
    ['2022-09-13', '500014', -59, 5880, '01'],
    ['2022-09-13', '409810', -37, 11915, '01'],
    ['2022-09-13', '510018', -49, 10780, '01'],
    ['2022-09-13', '500058', -130, 7680, '14'],
    ['2022-09-26', '241180', 13, 15405,'28'],
    ['2022-09-26', '278530', 21, 9745,'29'],
    ['2022-09-26', '379800', 18, 11650,'29'],
    ['2022-09-26', '379810', 19, 10595,'29'],
    ['2022-09-07', '379810', 92, 10935, 'MA'],
    ['2022-09-07', '379800', 84, 12000, 'MA'],
    ['2022-09-07', '278530', 97, 10270, 'MA'],
    ['2022-09-07', '241180', 64, 15525, 'MA'],
    ['2022-09-07', '169950', 49, 20430, 'MA'],  
    ['2022-09-21', '379810', 92, 10910, 'MA'],
    ['2022-09-21', '379800', 84, 11970, 'MA'],
    ['2022-09-21', '278530', 98, 10190, 'MA'],
    ['2022-09-21', '241180', 64, 15600, 'MA'],
    ['2022-09-21', '169950', 45, 20130, 'MA'],
    ['2022-09-26', '379810', 190, 10590, 'MA'],
    ['2022-09-26', '379800', 86, 11650, 'MA'],
    ['2022-09-26', '278530', 103, 9745, 'MA'],
    ['2022-09-26', '241180', 65, 15400, 'MA']
]

# %%
# Bank Account
account = {
    '01': 'FR',
    '14': 'SA',
    '29': 'RP',
    '28': 'DC',
    'MA': 'MA'
}

# %%
# Import libraries
from datetime import datetime, timedelta

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic' # Matplotlib 한글서체 오류처리
plt.rc('axes', unicode_minus=False)

# !pip install yfinance
import yfinance as yf  # Yahoo Finance API

# !pip install pykrx
# from pykrx import stock  # 네이버금융

# !pip install pandas-datareader # 주식 데이터 조회
import pandas_datareader as web

# !pip install mplfinance # 금융차트
import mplfinance as mpf
# 한국식 캔들차트 생성을 위한 스타일 지정 (상승-빨강, 하락-파랑)
colorset = mpf.make_marketcolors(up='tab:red', down='tab:blue', volume='tab:blue')
s = mpf.make_mpf_style(marketcolors= colorset)

# %%
# capital, eva 데이터프레임 생성
def define_cap(caplist, total):
    df = pd.DataFrame(caplist, columns= ['DATE'] + list(account.values()))
    df.DATE = pd.to_datetime(df.DATE)
    df.set_index(['DATE'], inplace= True)
    df[total] = df.loc[:, df.columns!='EVENT'].sum(axis=1)
    return df

# 개별 계정에 대해 자본 대비 평가액 변화 확인
def cap_change(account_col):
    account_cap = capital[account_col][-1]
    account_eva = eva[account_col][-1]
    account_del = account_eva - account_cap
    return [account_cap, account_eva, account_del, account_del / account_cap * 100]    

# ticker로 해당 종목 이름열인 'NAME'을 생성 - 별도 반환없이 바로 지정된 df에 생성
def tcknaming(df):
    df['NAME'] = df.TICKER.map(lambda x: ticker[x][0])

# %% [markdown]
# ## Capital

# %%
# 투자금 현황
# list_capital = pd.read_excel('position.xlsx', sheet_name='capital')

capital = define_cap(list_capital, 'CAP')
capital['DELTA'] = capital.CAP.diff()

capital.style.format("{:,.0f}")
capital
# Out:
#                  FR       SA       RP        DC        MA       CAP  \
# DATE
# 2021-12-10  1500000  2000000        0  17100000         0  20600000
# 2022-03-21  1500000  2000000   750000  17100000         0  21350000
# 2022-04-21  1500000  2000000  1000000  17100000         0  21600000
# 2022-05-11  1500000  2000000  1000000  17100000  51411787  73011787
# 2022-05-14  2000000  2000000  1000000  17100000  51411787  73511787
# 2022-05-21  2000000  2000000  1250000  17100000  51853487  74203487
# 2022-06-21  2000000  2000000  1500000  17100000  52295187  74895187
# 2022-07-21  2000000  2000000  1750000  17100000  52769107  75619107
# 2022-08-21  2000000  2000000  2000000  17100000  53243027  76343027
# 2022-09-21  2000000  2000000  2250000  17100000  53716937  77066937
# 2022-10-21  2000000  2000000  2500000  17100000  54190867  77790867
# 2022-11-21  2000000  2000000  2750000  17100000  54664787  78514787
#
#                  DELTA
# DATE
# 2021-12-10         NaN
# 2022-03-21    750000.0
# 2022-04-21    250000.0
# 2022-05-11  51411787.0
# 2022-05-14    500000.0
# 2022-05-21    691700.0
# 2022-06-21    691700.0
# 2022-07-21    723920.0
# 2022-08-21    723920.0
# 2022-09-21    723910.0
# 2022-10-21    723930.0
# 2022-11-21    723920.0

# %%
capital[list(account.values())].plot(kind='bar', stacked=True, figsize=(12, 3), title= "Total Capital - Won")

# %%
# 100만원 이하 자산변화에 대한 라인 그래프 생성
# capital.DELTA[capital.DELTA < 1000000].plot(kind='line', marker='o', figsize= (12, 3), title = 'Capital Change - Won')

# %% [markdown]
# ## Evaluation

# %%
# 입력된 값으로 1) df 생성, 2) capital 내 CAP열 값과 Join, 3) front fill로 없는 행 생성, 4) 불필요 행 삭제
eva = define_cap(list_eva, 'EVA').join(capital.CAP, how= 'outer', sort= True)
eva.CAP = eva.CAP.fillna(method= 'ffill')
eva.dropna(inplace= True)
eva = eva.astype('int')

eva['PROFIT'] = eva.EVA - eva.CAP
eva['PROFIT%'] = eva.PROFIT / eva.CAP * 100

eva.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >FR</th>        <th class="col_heading level0 col1" >SA</th>        <th class="col_heading level0 col2" >RP</th>        <th class="col_heading level0 col3" >DC</th>        <th class="col_heading level0 col4" >MA</th>        <th class="col_heading level0 col5" >EVA</th>        <th class="col_heading level0 col6" >CAP</th>        <th class="col_heading level0 col7" >PROFIT</th>        <th class="col_heading level0 col8" >PROFIT%</th>    </tr>    <tr>        <th class="index_name level0" >DATE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5level0_row0" class="row_heading level0 row0" >2021-12-10 00:00:00</th>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col0" class="data row0 col0" >1,500,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col1" class="data row0 col1" >2,000,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col3" class="data row0 col3" >17,100,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col5" class="data row0 col5" >20,600,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col6" class="data row0 col6" >20,600,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row0_col8" class="data row0 col8" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5level0_row1" class="row_heading level0 row1" >2022-04-01 00:00:00</th>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col0" class="data row1 col0" >1,320,963</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col1" class="data row1 col1" >1,815,919</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col2" class="data row1 col2" >745,075</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col3" class="data row1 col3" >17,169,766</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col5" class="data row1 col5" >21,051,723</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col6" class="data row1 col6" >21,350,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col7" class="data row1 col7" >-298,277</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row1_col8" class="data row1 col8" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5level0_row2" class="row_heading level0 row2" >2022-04-08 00:00:00</th>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col0" class="data row2 col0" >1,328,128</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col1" class="data row2 col1" >1,824,105</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col2" class="data row2 col2" >739,964</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col3" class="data row2 col3" >17,110,423</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col5" class="data row2 col5" >21,002,620</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col6" class="data row2 col6" >21,350,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col7" class="data row2 col7" >-347,380</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row2_col8" class="data row2 col8" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5level0_row3" class="row_heading level0 row3" >2022-04-20 00:00:00</th>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col0" class="data row3 col0" >1,306,232</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col1" class="data row3 col1" >1,843,025</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col2" class="data row3 col2" >734,283</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col3" class="data row3 col3" >17,122,584</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col5" class="data row3 col5" >21,006,124</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col6" class="data row3 col6" >21,350,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col7" class="data row3 col7" >-343,876</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row3_col8" class="data row3 col8" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5level0_row4" class="row_heading level0 row4" >2022-04-26 00:00:00</th>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col0" class="data row4 col0" >1,300,044</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col1" class="data row4 col1" >1,825,530</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col2" class="data row4 col2" >974,443</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col3" class="data row4 col3" >16,710,626</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col5" class="data row4 col5" >20,810,643</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col6" class="data row4 col6" >21,600,000</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col7" class="data row4 col7" >-789,357</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row4_col8" class="data row4 col8" >-4</td>
#             </tr>
#             <tr>
#                         <th id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5level0_row5" class="row_heading level0 row5" >2022-05-04 00:00:00</th>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row5_col0" class="data row5 col0" >1,297,685</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row5_col1" class="data row5 col1" >1,810,670</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row5_col2" class="data row5 col2" >973,821</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row5_col3" class="data row5 col3" >16,818,596</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_784f438ec1c5row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_c5e6d400_6bec_11ed_89c4_7

# %%
print("Latest Position")
print("------------------------------")
print("Capital        ₩", f'{eva.CAP[-1]:,}')
print("Evaluation     ₩", f'{eva.EVA[-1]:,}')
print("Profit         ₩", f'{eva.PROFIT[-1]:,}')
print("Profit%        {:.1f} %".format(eva['PROFIT%'][-1]))
# Out:
# Latest Position
# ------------------------------
# Capital        ₩ 78,514,787
# Evaluation     ₩ 77,144,913
# Profit         ₩ -1,369,874
# Profit%        -1.7 %

# %%
print('EVALUATION BY ACCOUT')
print(' ')
print('ACC   Capital      Evaluation   Profit    Profit%')
print('------------------------------------------------------')
for acc in list(account.values()):
    print(acc, '   ₩', f'{cap_change(acc)[0]:,}', ' ', f'{cap_change(acc)[1]:,}', ' ', f'{cap_change(acc)[2]:,}', ' ',f'{cap_change(acc)[3]:.1f}', '%')
# Out:
# EVALUATION BY ACCOUT
#
# ACC   Capital      Evaluation   Profit    Profit%
# ------------------------------------------------------
# FR    ₩ 2,000,000   1,830,185   -169,815   -8.5 %
# SA    ₩ 2,000,000   1,848,967   -151,033   -7.6 %
# RP    ₩ 2,750,000   2,761,536   11,536   0.4 %
# DC    ₩ 17,100,000   16,124,193   -975,807   -5.7 %
# MA    ₩ 54,664,787   54,580,032   -84,755   -0.2 %

# %%
eva.PROFIT.plot(marker='o', figsize=(12, 3), title = 'PROFIT change - Million ₩')

# %%
eva['PROFIT%'].plot(marker='o', figsize=(12, 3), title = 'PROFIT% change')

# %%
for mycap in account.values():
    eva.loc[eva[mycap] != 0, mycap].plot(kind='line', marker='o', figsize=(12, 3), title= mycap)
    plt.show()

# %% [markdown]
# ## Evaluation with Benchmark

# %%
# 주요 벤치마크 지표와 Performance 비교
bmticker = {'S&P500': '^GSPC', 'Nasdaq': '^IXIC', 'KOSPI':'^KS11'}
bmdf = pd.DataFrame()

for tk in bmticker:
    tk_yahoo = yf.Ticker(bmticker[tk])
    data = tk_yahoo.history(start= eva.index[0])['Close']
    bmdf[tk] = data
    
bmdf = bmdf.dropna().astype('int32')

evabm = eva[['EVA', 'CAP', 'PROFIT', 'PROFIT%']].join(bmdf, how= 'inner', sort= True)

evabm['BM_SP500'] = evabm['S&P500'] / evabm['S&P500'][0] * 100 - 100
evabm['BM_Nasdaq'] = evabm['Nasdaq'] / evabm['Nasdaq'][0] * 100 - 100
evabm['BM_KOSPI'] = evabm['KOSPI'] / evabm['KOSPI'][0] * 100 - 100

evabm['MY_BM'] = evabm['PROFIT%'] - evabm['PROFIT%'][0]

evabm.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EVA</th>        <th class="col_heading level0 col1" >CAP</th>        <th class="col_heading level0 col2" >PROFIT</th>        <th class="col_heading level0 col3" >PROFIT%</th>        <th class="col_heading level0 col4" >S&P500</th>        <th class="col_heading level0 col5" >Nasdaq</th>        <th class="col_heading level0 col6" >KOSPI</th>        <th class="col_heading level0 col7" >BM_SP500</th>        <th class="col_heading level0 col8" >BM_Nasdaq</th>        <th class="col_heading level0 col9" >BM_KOSPI</th>        <th class="col_heading level0 col10" >MY_BM</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5level0_row0" class="row_heading level0 row0" >2021-12-10 00:00:00</th>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col0" class="data row0 col0" >20,600,000</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col1" class="data row0 col1" >20,600,000</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col4" class="data row0 col4" >4,712</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col5" class="data row0 col5" >15,630</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col6" class="data row0 col6" >3,010</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row0_col10" class="data row0 col10" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5level0_row1" class="row_heading level0 row1" >2022-04-01 00:00:00</th>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col0" class="data row1 col0" >21,051,723</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col1" class="data row1 col1" >21,350,000</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col2" class="data row1 col2" >-298,277</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col3" class="data row1 col3" >-1</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col4" class="data row1 col4" >4,545</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col5" class="data row1 col5" >14,261</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col6" class="data row1 col6" >2,739</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col7" class="data row1 col7" >-4</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col8" class="data row1 col8" >-9</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col9" class="data row1 col9" >-9</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row1_col10" class="data row1 col10" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5level0_row2" class="row_heading level0 row2" >2022-04-08 00:00:00</th>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col0" class="data row2 col0" >21,002,620</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col1" class="data row2 col1" >21,350,000</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col2" class="data row2 col2" >-347,380</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col3" class="data row2 col3" >-2</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col4" class="data row2 col4" >4,488</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col5" class="data row2 col5" >13,711</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col6" class="data row2 col6" >2,700</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col7" class="data row2 col7" >-5</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col8" class="data row2 col8" >-12</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col9" class="data row2 col9" >-10</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row2_col10" class="data row2 col10" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5level0_row3" class="row_heading level0 row3" >2022-04-20 00:00:00</th>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col0" class="data row3 col0" >21,006,124</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col1" class="data row3 col1" >21,350,000</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col2" class="data row3 col2" >-343,876</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col3" class="data row3 col3" >-2</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col4" class="data row3 col4" >4,459</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col5" class="data row3 col5" >13,453</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col6" class="data row3 col6" >2,718</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col7" class="data row3 col7" >-5</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col8" class="data row3 col8" >-14</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col9" class="data row3 col9" >-10</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row3_col10" class="data row3 col10" >-2</td>
#             </tr>
#             <tr>
#                         <th id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5level0_row4" class="row_heading level0 row4" >2022-04-26 00:00:00</th>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col0" class="data row4 col0" >20,810,643</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col1" class="data row4 col1" >21,600,000</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col2" class="data row4 col2" >-789,357</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col3" class="data row4 col3" >-4</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col4" class="data row4 col4" >4,175</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col5" class="data row4 col5" >12,490</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col6" class="data row4 col6" >2,668</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col7" class="data row4 col7" >-11</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col8" class="data row4 col8" >-20</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col9" class="data row4 col9" >-11</td>
#                         <td id="T_c7f6b2b0_6bec_11ed_89c4_784f438ec1c5row4_col10" class

# %%
evabm[['MY_BM', 'BM_SP500', 'BM_Nasdaq', 'BM_KOSPI']].plot(marker='o', figsize=(12, 3))

# %% [markdown]
# ## Trading

# %%
position = pd.DataFrame(actions, columns=['DATE', 'TICKER', 'STOCKS', 'PRICE', 'ACCOUNT'])
# position.set_index('TICKER', inplace= True)

# 총 거래 가격. 현금 유출/유입으로 계산하므로 -1로 부호 반전
position['CAP'] = -1 * position.STOCKS * position.PRICE
# 매도 여부를 Boolean 형태로 별도 열 생성
position['SELL'] = position.STOCKS.apply(lambda x: True if x < 0 else False)

# position.tail()

# %%
# 전체 거래횟수
print('Total Transaction:', len(position))
print('    Buy  ', len(position) - position.SELL.sum())
print('    Sell ', position.SELL.sum())

# 거래회전량 계산 - 매도기준
total_buy = position.loc[position.SELL == False, 'CAP'].sum() * -1
rotation_rate_buy = total_buy / eva.CAP[-1] * 100
rotation_days = (pd.Timestamp(position.DATE.iloc[-1]) - capital.index[0]).days

print('-----------------------')
print('  ')
print("Total BUY    ₩", f'{total_buy:,}')
print(" ")
print("Buy Rotation")
print("    {:.1f} %".format(rotation_rate_buy), "over", rotation_days, "days")
print("    {:.1f} %".format(rotation_rate_buy / rotation_days * 365), "/ year    (Target < 100%/year)")

total_sell = position.loc[position.SELL == True, 'CAP'].sum()
rotation_rate_sell = total_sell / eva.CAP[-1] * 100

print('-----------------------')
print('  ')
print("Total SELL    ₩", f'{total_sell:,}')
print(" ")
print("Sell Rotation")
print("    {:.1f} %".format(rotation_rate_sell), "over", rotation_days, "days")
print("    {:.1f} %".format(rotation_rate_sell / rotation_days * 365), "/ year   (Target < 30%/year)")


# rotation_per_year = rotation_rate / rotation_days * 365
# Out:
# Total Transaction: 116
#     Buy   78
#     Sell  38
# -----------------------
#
# Total BUY    ₩ 42,964,599
#
# Buy Rotation
#     54.7 % over 290 days
#     68.9 % / year    (Target < 100%/year)
# -----------------------
#
# Total SELL    ₩ 13,208,272
#
# Sell Rotation
#     16.8 % over 290 days
#     21.2 % / year   (Target < 30%/year)

# %%
# open - 보유 중인 계약, closed - 종료된 거래을 담기 위한 각각의 df 생성
open = pd.DataFrame(columns=['TICKER', 'STOCKS', 'INVEST', 'AVG_PRICE'])
closed = pd.DataFrame(columns=['TICKER', 'DATE', 'BUY', 'SELL', 'DELTA', 'PROFIT%', 'STOCKS', 'CAP_CHANGE'])

# postion df를 loop하면서 SELL여부를 기준으로 open/closed df에 이력 추가 및 계산
for i, row in position.iterrows():
  # 매도일 경우, 1) closed df에 이력 추가. 2) open df에서는 주식수만 삭감하며 투자금액은 기존 평균가로 재산출
  if row['SELL'] == True:
    # print(i, 'SELL', row['TICKER'], row['TICKER'], row['DATE'], row['PRICE'],row['STOCKS'])
    buy = -1 * int(open.loc[open.TICKER == row['TICKER'], 'AVG_PRICE'])
    delta =  row['PRICE'] - buy
    profitper = delta / buy * 100
    capchange = -1 * delta * row['STOCKS']
    closed.loc[len(closed)] = [row['TICKER'], row['DATE'], buy, row['PRICE'], delta, profitper, row['STOCKS'], capchange]
    # print(closed)
    open.loc[i] = [row['TICKER'], row['STOCKS'], row['CAP'], 0]
    open = open.groupby(['TICKER']).sum().reset_index()
    open = open[open.STOCKS != 0]
    open.INVEST = open.STOCKS * open.AVG_PRICE

  # 매수일 경우, 주식수/거래대금을 기재 후 종목으로 합산 후 평균가 재산출
  else:
    # print(i, 'BUY', row['TICKER'], row['STOCKS'], row['CAP'])
    open.loc[i] = [row['TICKER'], row['STOCKS'], row['CAP'], np.nan]
    open = open.groupby(['TICKER']).sum().reset_index()
    # open = open[open.STOCKS != 0]
    open['AVG_PRICE'] = open.INVEST / open.STOCKS
    # print(open)
    # print("***********")
    # print(" ")

# 용이성을 위해 종목명을 병기하고 열 순서 변경
tcknaming(closed)
closed = closed[['DATE', 'TICKER', 'NAME', 'BUY', 'SELL', 'DELTA', 'PROFIT%', 'STOCKS', 'CAP_CHANGE']]
for col in ['BUY', 'SELL', 'DELTA', 'STOCKS', 'CAP_CHANGE']:
    closed[col] = closed[col].astype('int')

tcknaming(open)
open = open[['TICKER', 'NAME', 'STOCKS', 'AVG_PRICE', 'INVEST']]

# %% [markdown]
# ## Closed Position

# %%
sell = position.loc[position.SELL == True].copy()
# tcknaming(sell)
# sell = sell[['DATE', 'TICKER', 'NAME', 'CAP', 'ACCOUNT']]

sellcap = sell[['DATE', 'CAP']].groupby(['DATE']).sum()
# sellcap.index = pd.to_datetime(sellcap.index)
sellcap.plot(kind= 'bar', figsize= (12, 3), title= 'Closed Position by Date - Million ₩')

# %%
sellcap.index = pd.to_datetime(sellcap.index)
sellcap_month = sellcap.groupby([lambda x: x.year, lambda x: x.month]).sum()
sellcap_month.plot(kind= 'bar', figsize= (12, 3), title= 'Closed Position by Month - Million ₩')

# %%
# 실현거래 중 최근 20건 조회
# closed.tail(20).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})

# %%
print('Total Closed Capital    ₩', f'{sell.CAP.sum():,}')
print('Total Closed Profit     ₩' ,f'{closed.CAP_CHANGE.sum():,}')
print('--------------------------')
print('Total Closed Profit     {:.1f} %'.format(closed.CAP_CHANGE.sum() / sell.CAP.sum() * 100))
# Out:
# Total Closed Capital    ₩ 13,208,272
# Total Closed Profit     ₩ -634,820
# --------------------------
# Total Closed Profit     -4.8 %

# %%
closed.DATE = pd.to_datetime(closed.DATE)
closed_month = closed.set_index('DATE').groupby([lambda x: x.year, lambda x: x.month]).sum()
closed_month
# Out:
#            BUY    SELL  DELTA    PROFIT%  STOCKS  CAP_CHANGE
# 2022 1  649869  604710 -45159 -37.875324     -38      -88928
#      2  203536  175677 -27859 -62.872867    -100     -212276
#      3   63834   62453  -1381  -2.294469    -198      -21996
#      5   20884   17190  -3694 -35.694233    -183     -342238
#      6   78312   78505    193   4.888787    -438       18235
#      7    9384    9825    441   8.909419      -2         441
#      8   24471   24795    324  11.077446    -370       25004
#      9   42865   42345   -520  -7.836015    -282      -13062

# %%
closed_month['CAP_CHANGE'].plot(kind= 'bar', figsize= (12, 3), title= 'CLOSED - Monthlys PROFIT%')

# %%
closed_month['PROFIT%'].plot(kind= 'line', marker= 'o', figsize= (12, 3), title= 'CLOSED - Monthlys PROFIT%')

# %%
closed.tail(10)
# Out:
#          DATE  TICKER                        NAME    BUY   SELL  DELTA  \
# 28 2022-07-27  271050         KODEX WTI원유선물인버스(H)   4489   4435    -54
# 29 2022-08-10  500014        신한 인버스 옥수수 선물 ETN(H)   6326   6710    384
# 30 2022-08-10  510018       대신 인버스 알루미늄 선물 ETN(H)   9960  10030     70
# 31 2022-08-10  510004          대신 인버스 아연선물 ETN(H)   6450   6170   -280
# 32 2022-08-10  510006          대신 인버스 니켈선물 ETN(H)   1735   1885    150
# 33 2022-09-08  500014        신한 인버스 옥수수 선물 ETN(H)   6326   6090   -236
# 34 2022-09-13  500014        신한 인버스 옥수수 선물 ETN(H)   6326   5880   -446
# 35 2022-09-13  409810      KODEX 미국나스닥100선물인버스(H)  12563  11915   -648
# 36 2022-09-13  510018       대신 인버스 알루미늄 선물 ETN(H)   9960  10780    820
# 37 2022-09-13  500058  신한 S&P500 VIX S/T 선물 ETN C   7690   7680    -10
#
#      PROFIT%  STOCKS  CAP_CHANGE
# 28 -1.202941      -1         -54
# 29  6.070187      -6        2304
# 30  0.702811      -1          70
# 31 -4.341085     -74      -20720
# 32  8.645533    -289       43350
# 33 -3.730635      -7       -1652
# 34 -7.050269     -59      -26314
# 35 -5.158004     -37      -23976
# 36  8.232932     -49       40180
# 37 -0.130039    -130       -1300

# %%
closed[['DATE', 'NAME', 'PROFIT%', 'CAP_CHANGE']].sort_values('CAP_CHANGE', ascending= False).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >NAME</th>        <th class="col_heading level0 col2" >PROFIT%</th>        <th class="col_heading level0 col3" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row0_col0" class="data row0 col0" >2022-03-10 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row0_col1" class="data row0 col1" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row0_col2" class="data row0 col2" >38.4</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row0_col3" class="data row0 col3" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row1_col0" class="data row1 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row1_col1" class="data row1 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row1_col2" class="data row1 col2" >17.4</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row1_col3" class="data row1 col3" >52,150</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row2" class="row_heading level0 row2" >32</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row2_col0" class="data row2 col0" >2022-08-10 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row2_col1" class="data row2 col1" >대신 인버스 니켈선물 ETN(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row2_col2" class="data row2 col2" >8.6</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row2_col3" class="data row2 col3" >43,350</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row3" class="row_heading level0 row3" >36</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row3_col0" class="data row3 col0" >2022-09-13 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row3_col1" class="data row3 col1" >대신 인버스 알루미늄 선물 ETN(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row3_col2" class="data row3 col2" >8.2</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row3_col3" class="data row3 col3" >40,180</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row4" class="row_heading level0 row4" >22</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row4_col0" class="data row4 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row4_col1" class="data row4 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row4_col2" class="data row4 col2" >7.1</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row4_col3" class="data row4 col3" >39,468</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row5" class="row_heading level0 row5" >21</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row5_col0" class="data row5 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row5_col1" class="data row5 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row5_col2" class="data row5 col2" >17.4</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row5_col3" class="data row5 col3" >35,760</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row6" class="row_heading level0 row6" >24</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row6_col0" class="data row6 col0" >2022-06-23 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row6_col1" class="data row6 col1" >KBSTAR 미국S&P원유생산기업(합성 H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row6_col2" class="data row6 col2" >0.5</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row6_col3" class="data row6 col3" >4,500</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row7" class="row_heading level0 row7" >29</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row7_col0" class="data row7 col0" >2022-08-10 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row7_col1" class="data row7 col1" >신한 인버스 옥수수 선물 ETN(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row7_col2" class="data row7 col2" >6.1</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row7_col3" class="data row7 col3" >2,304</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row8" class="row_heading level0 row8" >27</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row8_col0" class="data row8 col0" >2022-07-27 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row8_col1" class="data row8 col1" >TIGER 인버스</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row8_col2" class="data row8 col2" >10.1</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row8_col3" class="data row8 col3" >495</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row9" class="row_heading level0 row9" >30</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row9_col0" class="data row9 col0" >2022-08-10 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row9_col1" class="data row9 col1" >대신 인버스 알루미늄 선물 ETN(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row9_col2" class="data row9 col2" >0.7</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row9_col3" class="data row9 col3" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row10" class="row_heading level0 row10" >28</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row10_col0" class="data row10 col0" >2022-07-27 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row10_col1" class="data row10 col1" >KODEX WTI원유선물인버스(H)</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row10_col2" class="data row10 col2" >-1.2</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row10_col3" class="data row10 col3" >-54</td>
#             </tr>
#             <tr>
#                         <th id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5level0_row11" class="row_heading level0 row11" >2</th>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row11_col0" class="data row11 col0" >2022-01-06 00:00:00</td>
#                         <td id="T_ca37391e_6bec_11ed_89c4_784f438ec1c5row11_col1" class="data row11 col1" >KODEX 200</td>
#                         <td id="T_ca37391e_6b

# %%
closed[['NAME', 'CAP_CHANGE']].set_index('NAME').sort_values('CAP_CHANGE', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Closed Position - ₩')

# %%
closed[['DATE', 'NAME', 'PROFIT%', 'CAP_CHANGE']].sort_values('PROFIT%', ascending= False).style.format({"PROFIT%": "{:,.1f}", "CAP_CHANGE": "{:,.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >DATE</th>        <th class="col_heading level0 col1" >NAME</th>        <th class="col_heading level0 col2" >PROFIT%</th>        <th class="col_heading level0 col3" >CAP_CHANGE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row0" class="row_heading level0 row0" >11</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row0_col0" class="data row0 col0" >2022-03-10 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row0_col1" class="data row0 col1" >KBSTAR 팔라듐선물(H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row0_col2" class="data row0 col2" >38.4</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row0_col3" class="data row0 col3" >88,255</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row1" class="row_heading level0 row1" >23</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row1_col0" class="data row1 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row1_col1" class="data row1 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row1_col2" class="data row1 col2" >17.4</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row1_col3" class="data row1 col3" >52,150</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row2" class="row_heading level0 row2" >21</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row2_col0" class="data row2 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row2_col1" class="data row2 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row2_col2" class="data row2 col2" >17.4</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row2_col3" class="data row2 col3" >35,760</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row3" class="row_heading level0 row3" >27</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row3_col0" class="data row3 col0" >2022-07-27 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row3_col1" class="data row3 col1" >TIGER 인버스</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row3_col2" class="data row3 col2" >10.1</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row3_col3" class="data row3 col3" >495</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row4" class="row_heading level0 row4" >32</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row4_col0" class="data row4 col0" >2022-08-10 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row4_col1" class="data row4 col1" >대신 인버스 니켈선물 ETN(H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row4_col2" class="data row4 col2" >8.6</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row4_col3" class="data row4 col3" >43,350</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row5" class="row_heading level0 row5" >36</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row5_col0" class="data row5 col0" >2022-09-13 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row5_col1" class="data row5 col1" >대신 인버스 알루미늄 선물 ETN(H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row5_col2" class="data row5 col2" >8.2</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row5_col3" class="data row5 col3" >40,180</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row6" class="row_heading level0 row6" >22</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row6_col0" class="data row6 col0" >2022-06-21 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row6_col1" class="data row6 col1" >KODEX 미국나스닥100선물인버스(H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row6_col2" class="data row6 col2" >7.1</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row6_col3" class="data row6 col3" >39,468</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row7" class="row_heading level0 row7" >29</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row7_col0" class="data row7 col0" >2022-08-10 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row7_col1" class="data row7 col1" >신한 인버스 옥수수 선물 ETN(H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row7_col2" class="data row7 col2" >6.1</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row7_col3" class="data row7 col3" >2,304</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row8" class="row_heading level0 row8" >30</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row8_col0" class="data row8 col0" >2022-08-10 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row8_col1" class="data row8 col1" >대신 인버스 알루미늄 선물 ETN(H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row8_col2" class="data row8 col2" >0.7</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row8_col3" class="data row8 col3" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row9" class="row_heading level0 row9" >24</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row9_col0" class="data row9 col0" >2022-06-23 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row9_col1" class="data row9 col1" >KBSTAR 미국S&P원유생산기업(합성 H)</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row9_col2" class="data row9 col2" >0.5</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row9_col3" class="data row9 col3" >4,500</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row10" class="row_heading level0 row10" >37</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row10_col0" class="data row10 col0" >2022-09-13 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row10_col1" class="data row10 col1" >신한 S&P500 VIX S/T 선물 ETN C</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row10_col2" class="data row10 col2" >-0.1</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row10_col3" class="data row10 col3" >-1,300</td>
#             </tr>
#             <tr>
#                         <th id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5level0_row11" class="row_heading level0 row11" >15</th>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row11_col0" class="data row11 col0" >2022-03-23 00:00:00</td>
#                         <td id="T_caaa14fc_6bec_11ed_89c4_784f438ec1c5row11_col1" class="data row11 col1" >KODEX WTI원유선물인버스(H)</td>

# %%
closed[['NAME', 'PROFIT%']].set_index('NAME').sort_values('PROFIT%', ascending= False).plot(kind= 'bar', figsize= (12, 4))

# %% [markdown]
# ## Trend - Closed

# %%
for i, row in closed.iterrows():
    try:
        data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        print('***', row.NAME, '***')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
#                 y = data.loc[data.index == prow.DATE, 'Close'].item()
                y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY '
                print('  ', sb, prow.DATE, prow.PRICE, stocks)
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        print('   PV             ', int(data.Close[-1]))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** 삼성전자 ***
#    PV              61400
# *** NAVER ***
#    PV              188000
# *** KODEX 200 ***
#    PV              31760
# *** 맥쿼리인프라 ***
#    PV              11100
# *** KODEX 미국메타버스나스닥액티브 ***
#    PV              6420
# *** SK하이닉스 ***
#    PV              86900
# *** TIGER 미국나스닥100 ***
#    PV              70490
# *** 대신 인버스 니켈선물 ETN(H) ***
#    BUY  2022-06-23 1735 289
#    SELL 2022-08-10 1885 -289
#    PV              1620
# *** TIGER 미국S&P500 ***
#    PV              13430
# *** TIGER 미국나스닥100 ***
#    PV              70490
# *** TIGER 미국S&P500 ***
#    PV              13430
# *** KBSTAR 팔라듐선물(H) ***
#    PV              10495
# *** 미래에셋 중국 심천 100 ETN ***
#    PV              14585
# *** ARIRANG 신흥국MSCI(합성 H) ***
#    PV              8895
# *** TIGER 인버스 ***
#    SELL 2022-07-27 5390 -1
#    PV              5380
# *** KODEX WTI원유선물인버스(H) ***
#    SELL 2022-06-15 3860 -17
#    SELL 2022-07-27 4435 -1
#    PV              4965
# *** KODEX 미국나스닥100선물인버스(H) ***
#    SELL 2022-06-21 13460 -44
#    SELL 2022-09-13 11915 -37
#    PV              12710
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***
#    PV              9775
# *** TIGER 글로벌클라우드컴퓨팅INDXX ***
#    PV              7800
# *** TRUE S&P500 양매도 4% OTM ETN(H) ***
#    SELL 2022-06-13 11540 -84
#    PV              10915
# *** KODEX WTI원유선물인버스(H) ***
#    SELL 2022-06-15 3860 -17
#    SELL 2022-07-27 4435 -1
#    PV              4965
# *** 신한 S&P500 VIX S/T 선물 ETN C ***
#    BUY  2022-06-09 8550 24
#    BUY  2022-06-09 8560 35
#    SELL 2022-06-21 10045 -24
#    SELL 2022-06-21 10045 -35
#    BUY  2022-08-10 7690 130
#    SELL 2022-09-13 7680 -130
#    PV              6585
# *** KODEX 미국나스닥100선물인버스(H) ***
#    SELL 2022-06-21 13460 -44
#    SELL 2022-09-13 11915 -37
#    PV              12710
# *** 신한 S&P500 VIX S/T 선물 ETN C ***
#    BUY  2022-06-09 8550 24
#    BUY  2022-06-09 8560 35
#    SELL 2022-06-21 10045 -24
#    SELL 2022-06-21 10045 -35
#    BUY  2022-08-10 7690 130
#    SELL 2022-09-13 7680 -130
#    PV              6585
# *** KBSTAR 미국S&P원유생산기업(합성 H) ***
#    SELL 2022-06-23 5570 -180
#    PV              6925
# *** KODEX 미국S&P에너지(합성) ***
#    BUY  2022-06-15 12555 40
#    SELL 2022-06-23 10900 -40
#    PV              14215
# *** TIGER 골드선물(H) ***
#    SELL 2022-06-29 13085 -14
#    PV              12470
# *** TIGER 인버스 ***
#    SELL 2022-07-27 5390 -1
#    PV              5380
# *** KODEX WTI원유선물인버스(H) ***
#    SELL 2022-06-15 3860 -17
#    SELL 2022-07-27 4435 -1
#    PV              4965
# *** 신한 인버스 옥수수 선물 ETN(H) ***
#    BUY  2022-06-24 6326 72
#    SELL 2022-08-10 6710 -6
#    SELL 2022-09-08 6090 -7
#    SELL 2022-09-13 5880 -59
#    PV              6220
# *** 대신 인버스 알루미늄 선물 ETN(H) ***
#    BUY  2022-06-23 9960 50
#    SELL 2022-08-10 10030 -1
#    SELL 2022-09-13 10780 -49
#    PV              10155
# *** 대신 인버스 아연선물 ETN(H) ***
#    BUY  2022-06-24 6450 74
#    SELL 2022-08-10 6170 -74
#    PV              6945
# *** 대신 인버스 니켈선물 ETN(H) ***
#    BUY  2022-06-23 1735 289
#    SELL 2022-08-10 1885 -289
#    PV              1620
# *** 신한 인버스 옥수수 선물 ETN(H) ***
#    BUY  2022-06-24 6326 72
#    SELL 2022-08-10 6710 -6
#    SELL 2022-09-08 6090 -7
#    SELL 2022-09-13 5880 -59
#    PV              6220
# *** 신한 인버스 옥수수 선물 ETN(H) ***
#    BUY  2022-06-24 6326 72
#    SELL 2022-08-10 6710 -6
#    SELL 2022-09-08 6090 -7
#    SELL 2022-09-13 5880 -59
#    PV              6220
# *** KODEX 미국나스닥100선물인버스(H) ***
#    SELL 2022-06-21 13460 -44
#    SELL 2022-09-13 11915 -37
#    PV              12710
# *** 대신 인버스 알루미늄 선물 ETN(H) ***
#    BUY  2022-06-23 9960 50
#    SELL 2022-08-10 10030 -1
#    SELL 2022-09-13 10780 -49
#    PV              10155
# *** 신한 S&P500 VIX S/T 선물 ETN C ***
#    BUY  2022-06-09 8550 24
#    BUY  2022-06-09 8560 35
#    SELL 2022-06-21 10045 -24
#    SELL 2022-06-21 10045 -35
#    BUY  2022-08-10 7690 130
#    SELL 2022-09-13 7680 -130
#    PV              6585

# %% [markdown]
# ## Open Position

# %%
open
# Out:
#     TICKER                   NAME  STOCKS      AVG_PRICE     INVEST
# 0   133690         TIGER 미국나스닥100       1  -82580.000000   -82580.0
# 1   139280             TIGER 경기방어      99  -10130.000000 -1002870.0
# 2   157490            TIGER 소프트웨어      70  -14325.000000 -1002750.0
# 3   169950           KODEX 차이나A50     141  -20590.921986 -2903320.0
# 4   241180         TIGER 일본니케이225     271  -15498.579336 -4200115.0
# 5   266410            KODEX 필수소비재     127   -7910.000000 -1004570.0
# 6   278530            KODEX 200TR     423  -10184.917258 -4308220.0
# 7   329200         TIGER 리츠부동산인프라     154   -6495.000000 -1000230.0
# 8   332610      ARIRANG 미국단기우량회사채      10 -102840.000000 -1028400.0
# 9   360750         TIGER 미국S&P500      18  -13670.000000  -246060.0
# 10  371460  TIGER 차이나전기차SOLACTIVE      68  -14720.000000 -1000960.0
# 11  373790      KOSEF 미국방어배당성장나스닥      77  -12950.000000  -997150.0
# 12  379800       KODEX 미국S&P500TR     368  -11771.630435 -4331960.0
# 13  379810       KODEX 미국나스닥100TR     496  -10742.610887 -5328335.0
# 14  394350  KOSEF 릭소글로벌퓨처모빌리티MSCI       9  -10984.000000   -98856.0
# 15  530020       삼성 미국 대형 가치주 ETN      33  -17723.424242  -584873.0

# %%
market = open.copy()
market[['AVG_PRICE', 'INVEST']] = market[['AVG_PRICE', 'INVEST']].astype('int')

marketprice = []

for tk in market.TICKER.to_list():
    tk_yahoo = yf.Ticker(tk + '.KS')
    data = tk_yahoo.history().tail(1)['Close'].iloc[0]
    marketprice.append(data)

# CV: 현재평가액 = 현재가 x 보유수, EVA: 평가증감 = 포지션 - 현재평가액
market['MARKET_PRICE'] = marketprice
market['CV'] = market.MARKET_PRICE * market.STOCKS
market['PROFIT'] = market.CV + market.INVEST
market['PROFIT%'] = market.PROFIT / market.INVEST * -100

# %%
print('Current Portfolio Total')
print('-----------------------------')
print('Values    ₩', f'{int(market.CV.sum()):,}')
print('Profit    ₩', f'{int(market.PROFIT.sum()):,}')
print('Profit%   {:.2f} %'.format(market.PROFIT.sum() / market.INVEST.sum() * -100))
# Out:
# Current Portfolio Total
# -----------------------------
# Values    ₩ 28,149,530
# Profit    ₩ -971,719
# Profit%   -3.34 %

# %%
colformat = {"PROFIT%": "{:,.1f}", 
             "AVG_PRICE": "{:,.0f}", "INVEST": "{:,.0f}", "MARKET_PRICE": "{:,.0f}", 
             "CV": "{:,.0f}", "PROFIT": "{:,.0f}"}
market.style.format(colformat)

# 현재 평가액이 큰 순서대로 배열
market.sort_values(by=['CV'], ascending= False, ignore_index=False)
# Out:
#     TICKER                   NAME  STOCKS  AVG_PRICE   INVEST  MARKET_PRICE  \
# 13  379810       KODEX 미국나스닥100TR     496     -10742 -5328335       10395.0
# 6   278530            KODEX 200TR     423     -10184 -4308220       10650.0
# 12  379800       KODEX 미국S&P500TR     368     -11771 -4331960       11930.0
# 4   241180         TIGER 일본니케이225     271     -15498 -4200115       16150.0
# 3   169950           KODEX 차이나A50     141     -20590 -2903320       17785.0
# 8   332610      ARIRANG 미국단기우량회사채      10    -102840 -1028400      108500.0
# 11  373790      KOSEF 미국방어배당성장나스닥      77     -12950  -997150       13750.0
# 1   139280             TIGER 경기방어      99     -10130 -1002870        9300.0
# 5   266410            KODEX 필수소비재     127      -7910 -1004570        7150.0
# 10  371460  TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960       12520.0
# 7   329200         TIGER 리츠부동산인프라     154      -6495 -1000230        4480.0
# 15  530020       삼성 미국 대형 가치주 ETN      33     -17723  -584873       19850.0
# 2   157490            TIGER 소프트웨어      70     -14325 -1002750        9215.0
# 9   360750         TIGER 미국S&P500      18     -13670  -246060       13430.0
# 14  394350  KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856        9775.0
# 0   133690         TIGER 미국나스닥100       1     -82580   -82580       70490.0
#
#            CV    PROFIT    PROFIT%
# 13  5155920.0 -172415.0  -3.235814
# 6   4504950.0  196730.0   4.566387
# 12  4390240.0   58280.0   1.345349
# 4   4376650.0  176535.0   4.203099
# 3   2507685.0 -395635.0 -13.626986
# 8   1085000.0   56600.0   5.503695
# 11  1058750.0   61600.0   6.177606
# 1    920700.0  -82170.0  -8.193485
# 5    908050.0  -96520.0  -9.608091
# 10   851360.0 -149600.0 -14.945652
# 7    689920.0 -310310.0 -31.023865
# 15   655050.0   70177.0  11.998673
# 2    645050.0 -357700.0 -35.671902
# 9    241740.0   -4320.0  -1.755669
# 14    87975.0  -10881.0 -11.006919
# 0     70490.0  -12090.0 -14.640349

# %%
market[['NAME', 'CV']].set_index('NAME').sort_values('CV', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by CV ₩')

# %%
# 투자수익이 큰 순서대로 배열
market.sort_values(by=['PROFIT'], ascending= False, ignore_index=False)
# Out:
#     TICKER                   NAME  STOCKS  AVG_PRICE   INVEST  MARKET_PRICE  \
# 6   278530            KODEX 200TR     423     -10184 -4308220       10650.0
# 4   241180         TIGER 일본니케이225     271     -15498 -4200115       16150.0
# 15  530020       삼성 미국 대형 가치주 ETN      33     -17723  -584873       19850.0
# 11  373790      KOSEF 미국방어배당성장나스닥      77     -12950  -997150       13750.0
# 12  379800       KODEX 미국S&P500TR     368     -11771 -4331960       11930.0
# 8   332610      ARIRANG 미국단기우량회사채      10    -102840 -1028400      108500.0
# 9   360750         TIGER 미국S&P500      18     -13670  -246060       13430.0
# 14  394350  KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856        9775.0
# 0   133690         TIGER 미국나스닥100       1     -82580   -82580       70490.0
# 1   139280             TIGER 경기방어      99     -10130 -1002870        9300.0
# 5   266410            KODEX 필수소비재     127      -7910 -1004570        7150.0
# 10  371460  TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960       12520.0
# 13  379810       KODEX 미국나스닥100TR     496     -10742 -5328335       10395.0
# 7   329200         TIGER 리츠부동산인프라     154      -6495 -1000230        4480.0
# 2   157490            TIGER 소프트웨어      70     -14325 -1002750        9215.0
# 3   169950           KODEX 차이나A50     141     -20590 -2903320       17785.0
#
#            CV    PROFIT    PROFIT%
# 6   4504950.0  196730.0   4.566387
# 4   4376650.0  176535.0   4.203099
# 15   655050.0   70177.0  11.998673
# 11  1058750.0   61600.0   6.177606
# 12  4390240.0   58280.0   1.345349
# 8   1085000.0   56600.0   5.503695
# 9    241740.0   -4320.0  -1.755669
# 14    87975.0  -10881.0 -11.006919
# 0     70490.0  -12090.0 -14.640349
# 1    920700.0  -82170.0  -8.193485
# 5    908050.0  -96520.0  -9.608091
# 10   851360.0 -149600.0 -14.945652
# 13  5155920.0 -172415.0  -3.235814
# 7    689920.0 -310310.0 -31.023865
# 2    645050.0 -357700.0 -35.671902
# 3   2507685.0 -395635.0 -13.626986

# %%
market[['NAME', 'PROFIT']].set_index('NAME').sort_values('PROFIT', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by Profit ₩')

# %%
# 투자수익이 큰 순서대로 배열
market.sort_values(by=['PROFIT%'], ascending= False, ignore_index=False)
# Out:
#     TICKER                   NAME  STOCKS  AVG_PRICE   INVEST  MARKET_PRICE  \
# 15  530020       삼성 미국 대형 가치주 ETN      33     -17723  -584873       19850.0
# 11  373790      KOSEF 미국방어배당성장나스닥      77     -12950  -997150       13750.0
# 8   332610      ARIRANG 미국단기우량회사채      10    -102840 -1028400      108500.0
# 6   278530            KODEX 200TR     423     -10184 -4308220       10650.0
# 4   241180         TIGER 일본니케이225     271     -15498 -4200115       16150.0
# 12  379800       KODEX 미국S&P500TR     368     -11771 -4331960       11930.0
# 9   360750         TIGER 미국S&P500      18     -13670  -246060       13430.0
# 13  379810       KODEX 미국나스닥100TR     496     -10742 -5328335       10395.0
# 1   139280             TIGER 경기방어      99     -10130 -1002870        9300.0
# 5   266410            KODEX 필수소비재     127      -7910 -1004570        7150.0
# 14  394350  KOSEF 릭소글로벌퓨처모빌리티MSCI       9     -10984   -98856        9775.0
# 3   169950           KODEX 차이나A50     141     -20590 -2903320       17785.0
# 0   133690         TIGER 미국나스닥100       1     -82580   -82580       70490.0
# 10  371460  TIGER 차이나전기차SOLACTIVE      68     -14720 -1000960       12520.0
# 7   329200         TIGER 리츠부동산인프라     154      -6495 -1000230        4480.0
# 2   157490            TIGER 소프트웨어      70     -14325 -1002750        9215.0
#
#            CV    PROFIT    PROFIT%
# 15   655050.0   70177.0  11.998673
# 11  1058750.0   61600.0   6.177606
# 8   1085000.0   56600.0   5.503695
# 6   4504950.0  196730.0   4.566387
# 4   4376650.0  176535.0   4.203099
# 12  4390240.0   58280.0   1.345349
# 9    241740.0   -4320.0  -1.755669
# 13  5155920.0 -172415.0  -3.235814
# 1    920700.0  -82170.0  -8.193485
# 5    908050.0  -96520.0  -9.608091
# 14    87975.0  -10881.0 -11.006919
# 3   2507685.0 -395635.0 -13.626986
# 0     70490.0  -12090.0 -14.640349
# 10   851360.0 -149600.0 -14.945652
# 7    689920.0 -310310.0 -31.023865
# 2    645050.0 -357700.0 -35.671902

# %%
market[['NAME', 'PROFIT%']].set_index('NAME').sort_values('PROFIT%', ascending= False).plot(kind= 'bar', figsize= (12, 4), title= 'Open Position by Profit%')

# %% [markdown]
# ## Trend - Open

# %%
today = datetime.today()

start = (today + timedelta(days= -180)).strftime('%Y-%m-%d')
end = today.strftime('%Y-%m-%d')

# start = datetime.now() - relativedelta(days=7)
# end = datetime.now()

# %%
for i, row in open.iterrows():
    try:
        data = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        print('***', row.NAME, '***')
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
#                 y = data.loc[data.index == prow.DATE, 'Close'].item()
                y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY '
                print('  ', sb, prow.DATE, prow.PRICE, stocks)
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        print('   PV             ', int(data.Close[-1]))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** TIGER 미국나스닥100 ***
#    PV              70490
# *** TIGER 경기방어 ***
#    PV              9300
# *** TIGER 소프트웨어 ***
#    PV              9215
# *** KODEX 차이나A50 ***
#    BUY  2022-07-21 21200 47
#    BUY  2022-09-07 20430 49
#    BUY  2022-09-21 20130 45
#    PV              17785
# *** TIGER 일본니케이225 ***
#    BUY  2022-07-21 15490 65
#    BUY  2022-09-26 15405 13
#    BUY  2022-09-07 15525 64
#    BUY  2022-09-21 15600 64
#    BUY  2022-09-26 15400 65
#    PV              16150
# *** KODEX 필수소비재 ***
#    PV              7150
# *** KODEX 200TR ***
#    BUY  2022-07-21 10675 10
#    BUY  2022-07-21 10620 94
#    BUY  2022-09-26 9745 21
#    BUY  2022-09-07 10270 97
#    BUY  2022-09-21 10190 98
#    BUY  2022-09-26 9745 103
#    PV              10650
# *** TIGER 리츠부동산인프라 ***
#    PV              4480
# *** ARIRANG 미국단기우량회사채 ***
#    PV              108500
# *** TIGER 미국S&P500 ***
#    PV              13430
# *** TIGER 차이나전기차SOLACTIVE ***
#    PV              12520
# *** KOSEF 미국방어배당성장나스닥 ***
#    PV              13750
# *** KODEX 미국S&P500TR ***
#    BUY  2022-07-21 11530 9
#    BUY  2022-07-21 11530 87
#    BUY  2022-09-26 11650 18
#    BUY  2022-09-07 12000 84
#    BUY  2022-09-21 11970 84
#    BUY  2022-09-26 11650 86
#    PV              11930
# *** KODEX 미국나스닥100TR ***
#    BUY  2022-07-21 10730 10
#    BUY  2022-07-21 10730 93
#    BUY  2022-09-26 10595 19
#    BUY  2022-09-07 10935 92
#    BUY  2022-09-21 10910 92
#    BUY  2022-09-26 10590 190
#    PV              10395
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***
#    PV              9775
# *** 삼성 미국 대형 가치주 ETN ***
#    BUY  2022-06-15 17775 17
#    PV              19850

# %% [markdown]
# ## Trend with Benchmark

# %%
# KODEX200 : 069500, TIGER 미국S&P500 : 360750, TIGER 미국나스닥100 : 133690

kospi = web.naver.NaverDailyReader('069500', start= start, end= end).read().astype('int')
kospi = kospi / kospi.Close[0] * 100

sp500 = web.naver.NaverDailyReader('360750', start= start, end= end).read().astype('int')
sp500 = sp500 / sp500.Close[0] * 100

ref = pd.concat([kospi.Close, sp500.Close], axis= 1)
ref.columns = ['KOSPI', 'SP500']

# %%
for i, row in open.iterrows():
    try:
        record = web.naver.NaverDailyReader(row.TICKER, start= start, end= end).read().astype('int')
        data = record / record.Close[0] * 100
        print('***', row.NAME, '***  vs. KOSPI(blue), SP500(orange)')
        
#         if ticker[row.TICKER][1] == 'KR':
#             apdict = mpf.make_addplot(kospi.Close, type='line')
#             bmindex = 'KOSPI'
#         else:
#             apdict = mpf.make_addplot(sp500.Close)
#             bmindex = 'S&P500'
        apdict = mpf.make_addplot(ref, linestyle='dotted')
            
        fig, axlist = mpf.plot(data, type='candle', style= s, figsize= (12, 3), returnfig= True, addplot= apdict)

        # Annotation
        for pi, prow in position.loc[position.TICKER == row.TICKER].iterrows():
            if data.index[0] < pd.to_datetime(prow.DATE):
                x = data.reset_index().index[data.index == prow.DATE].item()
                y = data.loc[data.index == prow.DATE, 'Close'].item()
#                 y = prow.PRICE
                cap = str(prow.CAP * -1)
                stocks = str(prow.STOCKS)
                sb = 'SELL' if prow.SELL else 'BUY'
                print('  ', sb, prow.DATE, prow.PRICE, stocks)
                axlist[0].annotate(sb + ', ' + stocks, (x, y), xytext=(x, y*0.95), arrowprops= dict(arrowstyle='->'))
        plt.show()
    except:
        print('************* ERROR on', row.NAME)
        pass
# Out:
# *** TIGER 미국나스닥100 ***  vs. KOSPI(blue), SP500(orange)
# *** TIGER 경기방어 ***  vs. KOSPI(blue), SP500(orange)
# *** TIGER 소프트웨어 ***  vs. KOSPI(blue), SP500(orange)
# *** KODEX 차이나A50 ***  vs. KOSPI(blue), SP500(orange)
#    BUY 2022-07-21 21200 47
#    BUY 2022-09-07 20430 49
#    BUY 2022-09-21 20130 45
# *** TIGER 일본니케이225 ***  vs. KOSPI(blue), SP500(orange)
#    BUY 2022-07-21 15490 65
#    BUY 2022-09-26 15405 13
#    BUY 2022-09-07 15525 64
#    BUY 2022-09-21 15600 64
#    BUY 2022-09-26 15400 65
# *** KODEX 필수소비재 ***  vs. KOSPI(blue), SP500(orange)
# *** KODEX 200TR ***  vs. KOSPI(blue), SP500(orange)
#    BUY 2022-07-21 10675 10
#    BUY 2022-07-21 10620 94
#    BUY 2022-09-26 9745 21
#    BUY 2022-09-07 10270 97
#    BUY 2022-09-21 10190 98
#    BUY 2022-09-26 9745 103
# *** TIGER 리츠부동산인프라 ***  vs. KOSPI(blue), SP500(orange)
# *** ARIRANG 미국단기우량회사채 ***  vs. KOSPI(blue), SP500(orange)
# *** TIGER 미국S&P500 ***  vs. KOSPI(blue), SP500(orange)
# *** TIGER 차이나전기차SOLACTIVE ***  vs. KOSPI(blue), SP500(orange)
# *** KOSEF 미국방어배당성장나스닥 ***  vs. KOSPI(blue), SP500(orange)
# *** KODEX 미국S&P500TR ***  vs. KOSPI(blue), SP500(orange)
#    BUY 2022-07-21 11530 9
#    BUY 2022-07-21 11530 87
#    BUY 2022-09-26 11650 18
#    BUY 2022-09-07 12000 84
#    BUY 2022-09-21 11970 84
#    BUY 2022-09-26 11650 86
# *** KODEX 미국나스닥100TR ***  vs. KOSPI(blue), SP500(orange)
#    BUY 2022-07-21 10730 10
#    BUY 2022-07-21 10730 93
#    BUY 2022-09-26 10595 19
#    BUY 2022-09-07 10935 92
#    BUY 2022-09-21 10910 92
#    BUY 2022-09-26 10590 190
# *** KOSEF 릭소글로벌퓨처모빌리티MSCI ***  vs. KOSPI(blue), SP500(orange)
# *** 삼성 미국 대형 가치주 ETN ***  vs. KOSPI(blue), SP500(orange)
#    BUY 2022-06-15 17775 17
